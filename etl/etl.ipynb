# %% [markdown]
# # Extraction of models from DeciContas.br Dataset

# %%
import os
import json
import pymssql

import pandas as pd
import numpy as np


from pprint import pprint
from langchain_openai import  AzureChatOpenAI, ChatOpenAI
from dotenv import load_dotenv
from sqlalchemy import (
    create_engine, Column, Integer, String, Float, Date, Boolean, Text, JSON
)
from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy.schema import DDL, CheckConstraint
from tools.prompt import generate_few_shot_ner_prompts
from tools.schema import (
    NERDecisao,
    Obrigacao
)

from datetime import timedelta


load_dotenv()


gpt4turbo = AzureChatOpenAI(
    deployment_name="gpt-4-turbo",
    model_name="gpt-4",
)

'''
gpt4turbo = ChatOpenAI(
    model="gpt-4-turbo",
    temperature=0.0
)
'''

extractor_gpt4turbo = gpt4turbo.with_structured_output(NERDecisao, include_raw=False, method="json_schema")
extractor_obrigacao_gpt4turbo = gpt4turbo.with_structured_output(
    Obrigacao, include_raw=False, method="json_schema")


def safe_int(value):
    if pd.isna(value):
        return None
    return int(value)

def get_connection(db: str = 'processo'):
    server = os.getenv("SQL_SERVER_HOST")
    user = os.getenv("SQL_SERVER_USER")
    password = os.getenv("SQL_SERVER_PASS")
    port = os.getenv("SQL_SERVER_PORT", "1433")  # default MSSQL port
    database = db

    return pymssql.connect(server, user, password, database, port)
# Out:
# c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1927: UserWarning: Cannot use method='json_schema' with model gpt-4 since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %% [markdown]
# # From DB Processo

# %%
meses = (7,8,9)
sql_decisoes = f'''
SELECT *
FROM processo.dbo.vw_ia_votos_acordaos_decisoes d
WHERE YEAR(DataSessao) = 2025
AND MONTH(DataSessao) IN {meses}
AND NOT EXISTS(
	SELECT *
	FROM BdDIP.dbo.Obrigacao o 
	WHERE d.IdComposicaoPauta = o.IdComposicaoPauta
	AND d.idVotoPauta = o.idVotoPauta 
)
AND NOT EXISTS(
	SELECT *
	FROM BdDIP.dbo.Recomendacao r 
	WHERE d.IdComposicaoPauta = r.IdComposicaoPauta
	AND d.idVotoPauta = r.idVotoPauta 
)


'''
df_decisoes = pd.read_sql(sql_decisoes, get_connection())
df_decisoes['ner_decisao'] = ''
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_22084\3551352073.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_decisoes = pd.read_sql(sql_decisoes, get_connection())

# %%
resultados = []
errors = []
for index, row in df_decisoes.iterrows():
    if index % 10 == 0 and index > 0:
        print(f"Processando instância {index} de {len(df_decisoes)}")
        df_decisoes.to_pickle("decisoes_ner_3T2025.pkl", index=True)

    try:
        prompt_with_few_shot = generate_few_shot_ner_prompts(row['texto_acordao'])
        
        result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
        df_decisoes.at[index, 'ner_decisao'] = result
        resultados.append(result)
    except Exception as e:
        errors.append({
            'index': index,
            'error': str(e),
            'row': row.to_dict()
        })

# %%
import re

def slugify(s):
    s = s.lower()
    s = re.sub(r'[^\w\s-]', '', s)
    s = re.sub(r'[\s]+', '_', s)
    return s

df_decisoes.columns = [slugify(col) for col in df_decisoes.columns]
df_decisoes.to_pickle("decisoes_ner_3T2025.pkl")

# %% [markdown]
# ## Carregando pickle

# %%
df_decisoes = pd.read_pickle("decisoes_ner_3T2025.pkl")

# %%
len(df_decisoes)
# Out:
# 978

# %%
sql_orgaos = f'''
SELECT p.idprocesso,
CONCAT(p.numero_processo, '/', p.ano_processo) as processo,
o.nome as orgao_responsavel, 
o.IdOrgao as id_orgao_responsavel,
gp.Nome as nome_responsavel,
gp.Documento as documento_responsavel,
gp.TipoPessoa  as tipo_responsavel,
gp.IdPessoa as id_pessoa
FROM processo.dbo.Processos p
INNER JOIN processo.dbo.Orgaos o ON p.IdOrgaoEnvolvido = o.IdOrgao 
INNER JOIN processo.dbo.Pro_ProcessosResponsavelDespesa pprd ON pprd.IdProcesso = p.IdProcesso 
INNER JOIN processo.dbo.GenPessoa gp ON gp.IdPessoa = pprd.IdPessoa 
WHERE p.idprocesso IN ({', '.join([f"{proc}" for proc in df_decisoes['idprocesso'].unique()])})
'''
df_orgaos = pd.read_sql(sql_orgaos, get_connection())
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_11388\4281826205.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_orgaos = pd.read_sql(sql_orgaos, get_connection())

# %%
df_decisoes = df_decisoes.merge(df_orgaos, how='left', left_on='idprocesso', right_on='idprocesso', suffixes=('', '_y'))

# %%
Base = declarative_base()
engine = create_engine(
    f"mssql+pymssql://{os.getenv("SQL_SERVER_USER")}:{os.getenv("SQL_SERVER_PASS")}@{os.getenv("SQL_SERVER_HOST")}/{os.getenv("SQL_SERVER_DB")}",
    echo=True
)
#engine = create_engine("sqlite:///dataset/sqlite/obrigacoes.db", echo=True)
SessionLocal = sessionmaker(bind=engine)

class ObrigacaoORM(Base):
    __tablename__ = "Obrigacao"

    IdObrigacao = Column(Integer, primary_key=True, index=True)
    IdProcesso = Column(Integer, nullable=False)
    IdComposicaoPauta = Column(Integer, nullable=False)
    IdVotoPauta = Column(Integer, nullable=False)
    DescricaoObrigacao = Column(Text, nullable=False)
    DeFazer = Column(Boolean, default=True)
    Prazo = Column(String, nullable=True)
    DataCumprimento = Column(Date, nullable=True)
    OrgaoResponsavel = Column(String, nullable=True)
    IdOrgaoResponsavel = Column(Integer, nullable=True)
    TemMultaCominatoria = Column(Boolean, default=False)
    NomeResponsavelMultaCominatoria = Column(String, nullable=True)
    DocumentoResponsavelMultaCominatoria = Column(String, nullable=True)
    IdPessoaMultaCominatoria = Column(Integer, nullable=True)
    ValorMultaCominatoria = Column(Float, nullable=True)
    PeriodoMultaCominatoria = Column(String, nullable=True)
    EMultaCominatoriaSolidaria = Column(Boolean, default=False)
    SolidariosMultaCominatoria = Column(JSON, nullable=True)

def find_obrigacao_by_descricao(df_ob, descricao):
    return [i for i,r in df_ob.iterrows() if descricao in r['obrigacoes'][0].descricao_obrigacao][0]

def get_id_pessoa_multa_cominatoria(row, result_obrigacao):
    """
    Obtém o ID da pessoa responsável pela multa cominatória.
    """
    if result_obrigacao.documento_responsavel_multa_cominatoria:
        try:
            return [p['id_pessoa'] for p in row['responsaveis'] if p['documento_responsavel'] == result_obrigacao.documento_responsavel_multa_cominatoria][0]
        except:
            return None
    return None

def get_pessoas_str(pessoas):    
    pessoas_str = []
    for pessoa in pessoas:
        nome = pessoa.get('nome_responsavel', 'Desconhecido')
        documento = pessoa.get('documento_responsavel', 'Desconhecido')
        tipo = pessoa.get('tipo_responsavel', 'Desconhecido')
        if tipo == 'F':
            tipo = 'Física'
        elif tipo == 'J':
            tipo = 'Jurídica'
        pessoas_str.append(f"{nome} ({tipo} - {documento})")
    
    return ", ".join(pessoas_str)

def get_prompt_obrigacao(row, obrigacao):
    data_sessao = row['datasessao']
    texto_acordao = row['texto_acordao']
    orgao_responsavel = row['orgao_responsavel']
    pessoas_responsaveis = row['responsaveis']


    return f"""
    Você é um Auditor de Controle Externo do TCE/RN. Sua tarefa é analisar o voto e extrair a obrigação imposta, preenchendo os campos do objeto Obrigacao.

    Data da Sessão: {data_sessao.strftime('%d/%m/%Y')}
    Obrigação detectada: {obrigacao.descricao_obrigacao}
    Texto do Acordão: {texto_acordao}
    Órgão Responsável: {orgao_responsavel}
    Pessoas Responsáveis: {get_pessoas_str(pessoas_responsaveis)}

    Dado esse contexto, preencha os campos da seguinte forma:
    - descricao_obrigacao: Descrição da obrigação imposta.
    - tipo: Tipo da obrigação (fazer/não fazer).
    - prazo: Prazo estipulado para cumprimento. Extraia o texto indicando o prazo, se houver. Exemplo: "90 dias".
    - data_cumprimento: Extraia do prazo do acórdão como data de início e faça o cálculo da data de cumprimento. Exemplo: 2025-09-13
    - orgao_responsavel: Órgão responsável pelo cumprimento da obrigação. Pessoa jurídica.
    - tem_multa_cominatoria: Indique se há multa cominatória associada à obrigação.
    - nome_responsavel_multa_cominatoria: Nome do responsável pela obrigação, se houver multa cominatória. Pessoa física responsável.
    - documento_responsavel_multa_cominatoria: Documento do responsável pela obrigação, se houver multa cominatória.
    - valor_multa_cominatoria: Se houver multa cominatória, preencha o valor.
    - periodo_multa_cominatoria: Período da multa cominatória, se houver.
    - e_multa_cominatoria_solidaria: Indique se a multa cominatória é solidária.
    - solidarios_multa_cominatoria: Lista de responsáveis solidários da multa cominatória.

    Use somente as informações do texto do acórdão e dos dados fornecidos. Não inclua informações adicionais ou suposições.
    Se o órgão responsável não estiver disponível, preencha o campo orgão_responsavel com "Desconhecido".
    """

def extract_obrigacao(row, obrigacao):
    prompt_obrigacao = get_prompt_obrigacao(row, obrigacao)
    return extractor_obrigacao_gpt4turbo.invoke(prompt_obrigacao)

def insert_obrigacao(db_session, obrigacao: Obrigacao, row):
    orm_obj = ObrigacaoORM(
        IdProcesso=safe_int(row['idprocesso']),
        IdComposicaoPauta=safe_int(row['idcomposicaopauta']),
        IdVotoPauta=safe_int(row['idvotopauta']),
        DescricaoObrigacao=obrigacao.descricao_obrigacao,
        DeFazer=obrigacao.de_fazer,
        Prazo=obrigacao.prazo,
        DataCumprimento=obrigacao.data_cumprimento,
        OrgaoResponsavel=obrigacao.orgao_responsavel,
        IdOrgaoResponsavel=safe_int(row['id_orgao_responsavel']),
        TemMultaCominatoria=obrigacao.tem_multa_cominatoria,
        NomeResponsavelMultaCominatoria=obrigacao.nome_responsavel_multa_cominatoria,
        DocumentoResponsavelMultaCominatoria=obrigacao.documento_responsavel_multa_cominatoria,
        IdPessoaMultaCominatoria=get_id_pessoa_multa_cominatoria(row, obrigacao),
        ValorMultaCominatoria=obrigacao.valor_multa_cominatoria,
        PeriodoMultaCominatoria=obrigacao.periodo_multa_cominatoria,
        EMultaCominatoriaSolidaria=obrigacao.e_multa_cominatoria_solidaria,
        SolidariosMultaCominatoria=obrigacao.solidarios_multa_cominatoria
    )
    db_session.add(orm_obj)
    db_session.commit()
    return orm_obj

# %%
df_decisoes.columns
# Out:
# Index(['idvoto', 'monocratica', 'codigo_tipo_processo', 'descricao',
#        'tipovoto', 'votoescolhido', 'idinformacao_voto', 'info_arquivo_voto',
#        'idcomposicaopauta', 'codigocamara', 'numero_sessao', 'ano_sessao',
#        'datasessao', 'datadecisaomonocratica', 'dataencerramentosessao',
#        'numeroresultado', 'anoresultado', 'resultadotipo', 'idapreciacao',
#        'idtiporecurso', 'idtipovotacao', 'decisao', 'idvotopauta',
#        'idvotodecisao', 'nomerelator', 'setor', 'ementa', 'assunto',
#        'numeroprocesso', 'anoprocesso', 'nomerelatorprocesso', 'idprocesso',
#        'interessado', 'orgaoorigem', 'divergente_de_idvoto',
#        'isvotodivergente', 'idvotoconcordado', 'relatorio',
#        'fundamentacaovoto', 'conclusao', 'artigo', 'texto_acordao',
#        'setorvoto', 'descricaotipovoto', 'ner_decisao', 'processo',
#        'orgao_responsavel', 'id_orgao_responsavel', 'nome_responsavel',
#        'documento_responsavel', 'tipo_responsavel', 'id_pessoa'],
#       dtype='object')

# %%
obrigacoes = [(d.idcomposicaopauta, d.idvoto, d.idvotopauta, d.datasessao, d['ner_decisao'].obrigacoes) 
              for _,d in df_decisoes[['idcomposicaopauta', 'idvotopauta', 'idvoto', 'datasessao', 'ner_decisao']].iterrows() if d['ner_decisao'].obrigacoes != []]
df_ob = pd.DataFrame(obrigacoes, columns=['idcomposicaopauta', 'idvoto', 'idvotopauta', 'datasessao', 'obrigacoes'])
df_ob['idvotopauta'] = df_ob['idvotopauta'].astype('int64')

# %%
df_ob
# Out:
#      idcomposicaopauta  idvoto  idvotopauta           datasessao  \
# 0               120308   44102        44102  2025-07-09 00:00:00
# 1               120655   44618        44618  2025-07-09 00:00:00
# 2               120655   44618        44618  2025-07-09 00:00:00
# 3               120655   44618        44618  2025-07-09 00:00:00
# 4               120288   44261        44261  2025-07-09 00:00:00
# ..                 ...     ...          ...                  ...
# 163             123076   45875        45875  2025-09-22 10:00:00
# 164             122819   45763        45763  2025-09-22 10:00:00
# 165             122819   45763        45763  2025-09-22 10:00:00
# 166             122811   44369        44369  2025-09-22 10:00:00
# 167             122811   44369        44369  2025-09-22 10:00:00
#
#                                             obrigacoes
# 0    [descricao_obrigacao='DETERMINAÇÃO ao órgão pr...
# 1    [descricao_obrigacao='NOTIFICAÇÃO do Fundo de ...
# 2    [descricao_obrigacao='NOTIFICAÇÃO do Fundo de ...
# 3    [descricao_obrigacao='NOTIFICAÇÃO do Fundo de ...
# 4    [descricao_obrigacao='DETERMINAÇÃO ao Órgão Pr...
# ..                                                 ...
# 163  [descricao_obrigacao='após o trânsito em julga...
# 164  [descricao_obrigacao='determinam à autoridade ...
# 165  [descricao_obrigacao='determinam à autoridade ...
# 166  [descricao_obrigacao='intimação do atual gesto...
# 167  [descricao_obrigacao='intimação do atual gesto...
#
# [168 rows x 5 columns]

# %%
group_cols = [
        'idprocesso', 'numeroprocesso', 'anoprocesso', 'idcomposicaopauta', 
        'idvotopauta', 'numero_sessao', 'ano_sessao', 'datasessao', 'relatorio',
        'fundamentacaovoto', 'conclusao', 'texto_acordao', 'orgao_responsavel', 'id_orgao_responsavel',
]
person_cols = ['nome_responsavel', 'documento_responsavel', 'tipo_responsavel', 'id_pessoa']

# %%
df_decisoes_aug = df_decisoes.groupby(group_cols, dropna=False).apply(
    lambda x: pd.Series({'responsaveis': x[person_cols].apply(
        lambda y: y.dropna().to_dict(), axis=1
    ).tolist()})
).reset_index()
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_11388\1014293047.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decisoes_aug = df_decisoes.groupby(group_cols, dropna=False).apply(

# %%
df_decisoes_aug.columns
# Out:
# Index(['idprocesso', 'numeroprocesso', 'anoprocesso', 'idcomposicaopauta',
#        'idvotopauta', 'numero_sessao', 'ano_sessao', 'datasessao', 'relatorio',
#        'fundamentacaovoto', 'conclusao', 'texto_acordao', 'orgao_responsavel',
#        'id_orgao_responsavel', 'responsaveis'],
#       dtype='object')

# %%
df_ob = df_ob[['idcomposicaopauta', 'idvotopauta', 'obrigacoes']].merge(df_decisoes_aug, on=['idcomposicaopauta', 'idvotopauta'], how='left')
df_ob['datasessao'] = pd.to_datetime(df_ob['datasessao'], errors='coerce')
df_ob['n_obrigacoes'] = df_ob['obrigacoes'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
df_ob['n_obrigacoes'].sum()
# Out:
# np.int64(290)

# %%
row
# Out:
# idcomposicaopauta                                                  120308
# idvotopauta                                                         44102
# obrigacoes              [descricao_obrigacao='DETERMINAÇÃO ao órgão pr...
# idprocesso                                                         570151
# numeroprocesso                                                     101070
# anoprocesso                                                          2022
# numero_sessao                                                       00011
# ano_sessao                                                           2025
# datasessao                                            2025-07-09 00:00:00
# relatorio               Cuidam-se os autos da análise da pensão por mo...
# fundamentacaovoto       Conforme se depreende dos autos, o cerne da qu...
# conclusao               Diante do exposto, acatando o pronunciamento d...
# texto_acordao           \r\nDECIDEM os Conselheiros do Tribunal de Con...
# orgao_responsavel                                                     NaN
# id_orgao_responsavel                                                  NaN
# responsaveis                                                         [{}]
# n_obrigacoes                                                            1
# Name: 0, dtype: object

# %%
sql_obrigacoes_cadastradas = f'''
SELECT IdComposicaoPauta, IdVotoPauta, IdObrigacao
FROM BdDIP.dbo.Obrigacao o
WHERE o.IdComposicaoPauta IN ({', '.join([f"{proc}" for proc in df_ob['idcomposicaopauta'].unique()])})
AND o.IdVotoPauta IN ({', '.join([f"{proc}" for proc in df_ob['idvotopauta'].unique()])})
'''
df_obrigacoes_cadastradas = pd.read_sql(sql_obrigacoes_cadastradas, get_connection('BdDIP'))
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_11388\3574598914.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_obrigacoes_cadastradas = pd.read_sql(sql_obrigacoes_cadastradas, get_connection('BdDIP'))

# %%
df_obrigacoes_cadastradas
# Out:
#    IdComposicaoPauta  IdVotoPauta  IdObrigacao
# 0             120655        44618         1037
# 1             120655        44618         1038
# 2             120425        43553         1040
# 3             120425        43553         1041
# 4             120613        44598         1042
# 5             120613        44598         1043
# 6             120982        44820         1119
# 7             120379        44419         1122

# %%
df_ob_old = df_ob.copy()
df_ob = df_ob[~df_ob['idcomposicaopauta'].isin(df_obrigacoes_cadastradas['IdComposicaoPauta']) & ~df_ob['idvotopauta'].isin(df_obrigacoes_cadastradas['IdVotoPauta'])]

# %%
len(df_ob), len(df_ob_old)
# Out:
# (193, 203)

# %%
errors
# Out:
# [(570151,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário municipal (MACAUPREV), na pessoa de seu atual gestor, para que, após o trânsito em julgado desta decisão, proceda à regularização da situação noticiada nos autos, no prazo de 30 (trinta) dias, sob pena de aplicação da sanção pecuniária prevista no artigo 107, inciso II, alínea “f”, da Lei Complementar Estadual nº 464/2012.'),
#   "'documento_responsavel'"),
#  (570737,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao Órgão Previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, promova as seguintes medidas de regularização do ato concessivo e do respectivo cálculo dos proventos: c.1) Adequação da documentação comprobatória, em conformidade com os requisitos previstos na Resolução nº 08/2012-TC, com a juntada dos seguintes documentos: a) Ato de aposentadoria do instituidor da pensão e respectiva publicação oficial; b) Ato concessivo da pensão devidamente fundamentado e assinado pelo gestor competente; c) Comprovação da publicação do ato concessivo da pensão em meio oficial de divulgação; d) Fichas financeiras referentes à última remuneração do instituidor e aos pagamentos realizados no primeiro e no último mês da implantação do benefício; e) Certidão de regularidade emitida pelo controle interno; f) Documento que comprove o ingresso regular do instituidor no serviço público; g) Documentação comprobatória acerca da informação de encerramento da pensão em junho de 2023'),
#   "'documento_responsavel'")]

# %%
row
# Out:
# idcomposicaopauta                                                  120288
# idvotopauta                                                         44261
# obrigacoes              [descricao_obrigacao='DETERMINAÇÃO ao Órgão Pr...
# idprocesso                                                         570737
# numeroprocesso                                                     101227
# anoprocesso                                                          2022
# numero_sessao                                                       00011
# ano_sessao                                                           2025
# datasessao                                            2025-07-09 00:00:00
# relatorio               Trata-se de apreciação da legalidade da conces...
# fundamentacaovoto       Inicialmente, assinalo que ainda não se operou...
# conclusao               Diante do exposto, em consonância com o posici...
# texto_acordao           \r\nDECIDEM os Conselheiros do Tribunal de Con...
# orgao_responsavel                                                     NaN
# id_orgao_responsavel                                                  NaN
# responsaveis                                                         [{}]
# n_obrigacoes                                                            2
# Name: 4, dtype: object

# %%
obrigacoes
# Out:
# [(120308,
#   44102,
#   44102,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário municipal (MACAUPREV), na pessoa de seu atual gestor, para que, após o trânsito em julgado desta decisão, proceda à regularização da situação noticiada nos autos, no prazo de 30 (trinta) dias, sob pena de aplicação da sanção pecuniária prevista no artigo 107, inciso II, alínea “f”, da Lei Complementar Estadual nº 464/2012.')]),
#  (120655,
#   44618,
#   44618,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='NOTIFICAÇÃO do Fundo de Previdência Social do Município de Passa e Fica, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, proceda à adequação do ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informe a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis')]),
#  (120655,
#   44618,
#   44618,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='NOTIFICAÇÃO do Fundo de Previdência Social do Município de Passa e Fica, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, proceda à adequação do ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informe a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis')]),
#  (120655,
#   44618,
#   44618,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='NOTIFICAÇÃO do Fundo de Previdência Social do Município de Passa e Fica, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, proceda à adequação do ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informe a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis')]),
#  (120288,
#   44261,
#   44261,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao Órgão Previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, promova as seguintes medidas de regularização do ato concessivo e do respectivo cálculo dos proventos: c.1) Adequação da documentação comprobatória, em conformidade com os requisitos previstos na Resolução nº 08/2012-TC, com a juntada dos seguintes documentos: a) Ato de aposentadoria do instituidor da pensão e respectiva publicação oficial; b) Ato concessivo da pensão devidamente fundamentado e assinado pelo gestor competente; c) Comprovação da publicação do ato concessivo da pensão em meio oficial de divulgação; d) Fichas financeiras referentes à última remuneração do instituidor e aos pagamentos realizados no primeiro e no último mês da implantação do benefício; e) Certidão de regularidade emitida pelo controle interno; f) Documento que comprove o ingresso regular do instituidor no serviço público; g) Documentação comprobatória acerca da informação de encerramento da pensão em junho de 2023'),
#    NERObrigacao(descricao_obrigacao='Em caso de descumprimento da presente decisão, a imposição de multa diária ao gestor responsável, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado no item `c`, com base no art. 110 da LCE nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, inciso II, alínea “f”, da mesma norma, valor este passível de revisão, observando-se o teto previsto no art. 323, inciso II, alínea “f”, do Regimento Interno, a ser apurado em eventual constatação de mora.')]),
#  (120425,
#   43553,
#   43553,
#   '2025-07-09 00:00:00',
#   [NERObrigacao(descricao_obrigacao='expedição de determinação ao atual gestor do Instituto de Previdência do Município de São José do Seridó – IPREV-SJS, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta decisão, corrija o ato aposentador, a apostila de cálculos e a implantação dos proventos, a fim de corrigir o valor do adicional por tempo de serviço/quinquênio, nos termos do art. 134, alínea “e”, da Lei Municipal nº 199/99, no percentual de 15%.'),
#    NERObrigacao(descricao_obrigacao='Determinar que o gestor responsável, no prazo de 05 (cinco) dias úteis após ultimado o prazo fixado no item b, comprove o implemento da obrigação imposta, sendo certo que, no caso de descumprimento da Decisão, impõe-se multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado no item “b”, com base no art. 110, da Lei Complementar Estadual n.º 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#    NERObrigacao(descricao_obrigacao='intimação do Instituto de Previdência do Município de São José do Seridó – IPREV-SJS, por seu atual gestor, a fim de que possa promover a devida compensação financeira junto ao Regime Geral de Previdência Social.'),
#    NERObrigacao(descricao_obrigacao='intimação da parte interessada, nos termos do artigo 46, combinado com o artigo 47, parágrafo, único, alínea “g” Lei Complementar Estadual nº 464/2012.')]),
#  (120613,
#   44598,
#   44598,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Doutor Cleodon Carlos de Andrade, para que providencie o envio das informações devidas relativas ao 2º bimestre de 2017, no prazo de 40 (quarenta) dias')]),
#  (120613,
#   44598,
#   44598,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Doutor Cleodon Carlos de Andrade, para que providencie o envio das informações devidas relativas ao 2º bimestre de 2017, no prazo de 40 (quarenta) dias')]),
#  (120712,
#   44652,
#   44652,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para que o Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas, podendo, em caso de descumprimento da determinação contida no item anterior, ser aplicada ao responsável a sanção administrativa prevista no art. 107, inciso II, alínea “f”, da LCE nº 464/2012.')]),
#  (120712,
#   44774,
#   44652,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para que o Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas, podendo, em caso de descumprimento da determinação contida no item anterior, ser aplicada ao responsável a sanção administrativa prevista no art. 107, inciso II, alínea “f”, da LCE nº 464/2012.')]),
#  (120645,
#   44605,
#   44605,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as providências indicadas (juntar aos autos os documentos listados), sob pena de responsabilização administrativa: b.1) Junte aos autos os documentos abaixo relacionados: Histórico funcional completo; Mapeamento do tempo de contribuição; Ato concessivo original, com indicação específica do fundamento jurídico que ampara a aposentadoria, discriminando as vantagens a que a parte interessada tem direito, com o respectivo fundamento legal; Comprovação das remunerações utilizadas como base de contribuição; Apostila detalhada de cálculo do benefício; Fichas financeiras referentes à última remuneração percebida na ativa, bem como ao primeiro e ao último mês subsequentes à implantação do benefício.'),
#    NERObrigacao(descricao_obrigacao='Determinar a intimação da autoridade competente do MACAUPREV, para ciência integral desta Decisão.')]),
#  (120645,
#   44773,
#   44605,
#   '2025-07-14 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as seguintes providências, sob pena de responsabilização administrativa: b.1) Junte aos autos os documentos abaixo relacionados: histórico funcional completo; mapeamento do tempo de contribuição; ato concessivo original, com indicação específica do fundamento jurídico que ampara a aposentadoria, discriminando as vantagens a que a parte interessada tem direito, com o respectivo fundamento legal; comprovação das remunerações utilizadas como base de contribuição; apostila detalhada de cálculo do benefício; fichas financeiras referentes à última remuneração percebida na ativa, bem como ao primeiro e ao último mês subsequentes à implantação do benefício;')]),
#  (120869,
#   44733,
#   44733,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, após o trânsito em julgado desta decisão e sob pena da sanção pecuniária prevista no artigo 107, inciso II, alínea “f”, da Lei Complementar Estadual nº 464/2012, promova a cessação do benefício ou apresente nestes autos os documentos necessários à análise de mérito, a saber: mapeamento do tempo de contribuição da parte interessada e histórico funcional completo; homologação do resultado do concurso de aprovação da servidora; ato concessivo original e sua publicação em meio oficial de divulgação; comprovação das remunerações de contribuição; apostila de cálculo do benefício previdenciário de forma detalhada, especificando o resultado do cálculo da média aritmética; fichas financeiras relativas à última remuneração, ao primeiro e ao último dos meses após a implantação do benefício; e certidão de regularidade emitida pelo controle interno.')]),
#  (120870,
#   44732,
#   44732,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, após o trânsito em julgado desta decisão e sob pena da sanção pecuniária prevista no artigo 107, inciso II, alínea “f”, da Lei Complementar Estadual nº 464/2012, promova a cessação do benefício ou apresente nestes autos os documentos necessários à análise de mérito, a saber: 1) histórico funcional completo; 2) mapeamento do tempo de contribuição; 3) parecer jurídico na íntegra; 4) base legal que permitiu a servidora passar do emprego de auxiliar de escrita (página 11, evento 01) para auxiliar de secretaria escolar (página 78, evento 01); 5) apostila de cálculo do benefício previdenciário de forma detalhada; 6) ato original e comprovação da publicação do ato concessivo em meio oficial de divulgação; 7) comprovação das remunerações de contribuição; 8) fichas financeiras relativas ao primeiro e ao último dos meses após a implantação do benefício; 9) certidão de regularidade emitida pelo controle interno'),
#    NERObrigacao(descricao_obrigacao='IMPOSIÇÃO de multa diária ao(à) gestor(a) atual responsável, em caso de descumprimento da presente decisão, desde já fixada no valor de R$ 100,00 (cem reais) por dia de atraso, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, valor passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea “f”, do Regimento Interno, a ser apurado em eventual persistência de mora')]),
#  (120982,
#   44820,
#   44820,
#   '2025-07-24 00:00:00',
#   [NERObrigacao(descricao_obrigacao='pela suspensão de fornecimento da Certidão de Adimplência do Município de João Dias junto ao Tribunal de Contas, nos termos do art. 33, inciso II, da Resolução nº 011/2016 – TC, até que seja regularizada a situação do seu Portal da Transparência')]),
#  (120982,
#   44820,
#   44820,
#   '2025-07-24 00:00:00',
#   [NERObrigacao(descricao_obrigacao='pela suspensão de fornecimento da Certidão de Adimplência do Município de João Dias junto ao Tribunal de Contas, nos termos do art. 33, inciso II, da Resolução nº 011/2016 – TC, até que seja regularizada a situação do seu Portal da Transparência')]),
#  (120982,
#   44820,
#   44820,
#   '2025-07-24 00:00:00',
#   [NERObrigacao(descricao_obrigacao='pela suspensão de fornecimento da Certidão de Adimplência do Município de João Dias junto ao Tribunal de Contas, nos termos do art. 33, inciso II, da Resolução nº 011/2016 – TC, até que seja regularizada a situação do seu Portal da Transparência')]),
#  (120378,
#   44370,
#   44370,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as seguintes correções necessárias para regularização do ato, com a apresentação da seguinte documentação: i. A correção do ato aposentador, com a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou')]),
#  (120378,
#   44370,
#   44370,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as seguintes correções necessárias para regularização do ato, com a apresentação da seguinte documentação: i. A correção do ato aposentador, com a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou')]),
#  (120378,
#   44370,
#   44370,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as seguintes correções necessárias para regularização do ato, com a apresentação da seguinte documentação: i. A correção do ato aposentador, com a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou')]),
#  (120379,
#   44419,
#   44419,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao gestor atual, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as seguintes correções necessárias para regularização do ato concessivo: c.1) A adequação de todos os documentos comprobatórios exigidos, conforme apurado pelo Corpo Técnico, com a juntada dos seguintes documentos: Atestado de saúde do nomeado; Certidão negativa de antecedentes criminais e cíveis estaduais; e Quitação com as obrigações militares.'),
#    NERObrigacao(descricao_obrigacao='Determinação, ao gestor responsável atual, da cessação dos pagamentos, caso após o prazo concedido na letra “c”, seja descumprida a entrega dos documentos e o ressarcimento ao erário das quantias pagas após essa data, conforme art. 313, parágrafo 1º do Regimento Interno deste Tribunal, aprovado pela Resolução nº. 09/12 – TCERN')]),
#  (121872,
#   45277,
#   45277,
#   '2025-08-06 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Estabelecer o prazo de 60 (sessenta) dias, contados a partir do trânsito em julgado da presente Decisão, com base no art. 1º, inciso VII, da referida Lei Complementar, para que o órgão de origem responsável junte aos autos a documentação solicitada, conforme consignado no voto do Relator e nas manifestações do Corpo Técnico e do Ministério Público Especial, sob pena de aplicação de sanção administrativa ao responsável, devendo o processo, após o cumprimento, ser devolvido a este Tribunal de Contas.')]),
#  (121872,
#   45277,
#   45277,
#   '2025-08-06 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Estabelecer o prazo de 60 (sessenta) dias, contados a partir do trânsito em julgado da presente Decisão, com base no art. 1º, inciso VII, da referida Lei Complementar, para que o órgão de origem responsável junte aos autos a documentação solicitada, conforme consignado no voto do Relator e nas manifestações do Corpo Técnico e do Ministério Público Especial, sob pena de aplicação de sanção administrativa ao responsável, devendo o processo, após o cumprimento, ser devolvido a este Tribunal de Contas.')]),
#  (120978,
#   45414,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determine que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='determinação à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120978,
#   45414,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determine que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='determinação à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120978,
#   45414,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determine que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='determinação à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120978,
#   44721,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120978,
#   44721,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120978,
#   44721,
#   44721,
#   '2025-07-28 10:00:00',
#   [NERObrigacao(descricao_obrigacao='que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vínculos funcionais apresentados, mediante a instauração de processo administrativo, com esteio no regime jurídico próprio e observância aos princípios do contraditório e da ampla defesa, fixação do prazo de 150 (cento e cinquenta) dias para a conclusão dos processos administrativos disciplinares, determinando que, em até 10 (dez) dias após esse interregno, o Tribunal de Contas seja comunicado sobre o término, especificando os resultados alcançados e as providências adotadas pelo Poder Público local para sanear as ilicitudes verificadas em cada caso concreto, se for o caso, com a publicação da pertinente portaria de exoneração ou da aplicação da penalidade de demissão, em face do acúmulo irregular de cargos por parte dos servidores elencados na Representação da DDP, sob pena de, não o fazendo no prazo acima, incidir pena de multa diária e pessoal, desde já arbitrada no valor de 100,00 (cem reais), por dia que superar o interregno fixado, com fulcro no art. 110, da LOTCE/RN c.c o art. 326, do Regimento Interno'),
#    NERObrigacao(descricao_obrigacao='à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, no prazo de 120 (cento e vinte) dias úteis, comunicando o resultado a esta Corte,no prazo de 05 (cinco) dias úteis após a conclusão da apuração, sob pena de multa pessoal e diária, ao gestor responsável, no valor de R$ 500,00 (quinhentos reais) por dia de atraso, limitada à quantia de R$ 20.585,16 (vinte mil, quinhentos e oitenta e cinco reais e dezesseis centavos), nos termos do artigo 110 da Lei Complementar Estadual nº 464/2012')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   44801,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120966,
#   45518,
#   45518,
#   '2025-07-23 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Expedição de determinação ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte – IPERN, por meio de seu atual gestor, para que, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, adote as providências necessárias à retificação da concessão da aposentadoria da interessada, implantando-a na Classe “J”, em cumprimento à decisão judicial, sem que tal medida implique alteração nos valores das rubricas “Remuneração Pecuniária” e “Gratificação de Título”'),
#    NERObrigacao(descricao_obrigacao='gestor responsável deverá, no prazo de 05 (cinco) dias úteis após expirado o prazo fixado no item “b”, comprovar o cumprimento da obrigação imposta, sob pena de aplicação de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia de atraso além do interregno estabelecido no referido item “b”, com fundamento no art. 110 da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da mesma Lei Complementar. O valor da multa poderá ser revisto, observando-se o teto estabelecido no art. 323, II, “f”, do Regimento Interno, a ser apurado em caso de eventual subsistência da mora.')]),
#  (120873,
#   44433,
#   44433,
#   '2025-08-07 00:00:00',
#   [NERObrigacao(descricao_obrigacao='assinatura do prazo de 18 (dezoito) meses, a contar da intimação da presente decisão, ao município de Vila Flor/RN e ao atual gestor responsável, para saneamento das infrações constatadas nestes autos, sob pena de multa diária ao atual gestor no valor de R$ 1.000,00 (LOTCE/RN, art. 110)'),
#    NERObrigacao(descricao_obrigacao='assinatura do prazo de 60 (sessenta) dias, a contar da intimação desta decisão, ao Município de Vila Flor/RN e ao seu atual gestor, para que apresentem a este Tribunal um plano para enfrentamento e eliminação das irregularidades em questão, contendo cronograma que deve observar o prazo máximo fixado na alínea “b” para solução definitiva, sob pena de multa diária ao gestor responsável no importe de R$ 1.000,00 (LOTCE/RN, art. 110)')]),
#  (121431,
#   45170,
#   45170,
#   '2025-08-11 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Tarcísio Maia, para que, no prazo de 40 (quarenta) dias, providencie o envio das prestações de contas pendentes, sob pena de aplicação da multa cabível.')]),
#  (121431,
#   45170,
#   45170,
#   '2025-08-11 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Tarcísio Maia, para que, no prazo de 40 (quarenta) dias, providencie o envio das prestações de contas pendentes, sob pena de aplicação da multa cabível.')]),
#  (121430,
#   45171,
#   45171,
#   '2025-08-11 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinar a intimação do atual gestor da Secretaria de Estado da Saúde Pública, para que providencie o envio das devidas prestações de contas ausentes, no prazo de 40 (quarenta) dias, sob pena de aplicação de multa.')]),
#  (121430,
#   45171,
#   45171,
#   '2025-08-11 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinar a intimação do atual gestor da Secretaria de Estado da Saúde Pública, para que providencie o envio das devidas prestações de contas ausentes, no prazo de 40 (quarenta) dias, sob pena de aplicação de multa.')]),
#  (122017,
#   44284,
#   44284,
#   '2025-08-19 00:00:00',
#   [NERObrigacao(descricao_obrigacao='expedição de determinação de fazer à Câmara Municipal Japi, por meio do seu atual gestor, a fim de que, no prazo de 30 (trinta) dias, adote as providências necessárias ao exato cumprimento do art. 48, caput¸ da Lei Complementar n° 101/2000 e art. 8º, caput e §2º, da Lei 12.527/2011, procedendo à adequada divulgação das informações faltantes, sob pena de: multa pessoal, desde já, estabelecida em R$ 100,00 (cem reais), por dia que ultrapassar o prazo, nos moldes do art. 110 da Lei Complementar Estadual nº 464/2012; e suspensão de fornecimento da Certidão de Adimplência junto ao Tribunal de Contas, nos termos do art. 35 da Resolução nº 028/2012 - TCE')]),
#  (122017,
#   44284,
#   44284,
#   '2025-08-19 00:00:00',
#   [NERObrigacao(descricao_obrigacao='expedição de determinação de fazer à Câmara Municipal Japi, por meio do seu atual gestor, a fim de que, no prazo de 30 (trinta) dias, adote as providências necessárias ao exato cumprimento do art. 48, caput¸ da Lei Complementar n° 101/2000 e art. 8º, caput e §2º, da Lei 12.527/2011, procedendo à adequada divulgação das informações faltantes, sob pena de: multa pessoal, desde já, estabelecida em R$ 100,00 (cem reais), por dia que ultrapassar o prazo, nos moldes do art. 110 da Lei Complementar Estadual nº 464/2012; e suspensão de fornecimento da Certidão de Adimplência junto ao Tribunal de Contas, nos termos do art. 35 da Resolução nº 028/2012 - TCE')]),
#  (122017,
#   44284,
#   44284,
#   '2025-08-19 00:00:00',
# ...
#    NERObrigacao(descricao_obrigacao='intimar a parte interessada, no prazo de 20 dias úteis, com o fito de esta apresentar, se entender de direito, suas razões de defesa, com esteio na Súmula Vinculante nº 03, do Supremo Tribunal Federal.')]),
#  (123103,
#   45719,
#   45719,
#   '2025-09-17 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinado ao atual gestor do Instituto de Previdência do Estado do RN a obrigação de não fazer, consistente em abster-se de utilizar os recursos alocados em aplicações financeiras de investimentos de médio e longo prazo, bem como aqueles advindos de seus respectivos rendimentos, para cobrir eventual déficit financeiro mensal do pagamento de benefícios previdenciários, enquanto o montante de ativos garantidores do plano permanecerem inferiores à Provisão Matemática de Benefícios Concedidos (PMBC), sob pena de multa de R$ 10.000,00 (dez mil reais) por cada ato de descumprimento'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN a obrigação de fazer, consistente no ato de realizar a cobertura da insuficiência financeira do RPPS, na hipótese dos recursos regularmente arrecadados das contribuições ordinárias e extraordinárias não serem suficientes para o pagamento dos benefícios previdenciários, em atenção ao disposto no artigo 2º, § 1º, da Lei 9717/98, sob pena de multa de R$ 10.000,00 (dez mil reais) por cada ato de descumprimento'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN e ao atual gestor do Instituto de Previdência do Estado do RN que, no prazo de 60 (sessenta) dias úteis, apresentem um plano de ação visando à amortização do déficit atuarial e à adequação da relação entre os ativos garantidores e as provisões matemáticas dos benefícios concedidos. O plano deverá, necessariamente, contemplar um estudo atuarial com avaliação das sugestões indicadas na fundamentação do voto-vista condutor deste Acórdão e determinação de encaminhamento de um projeto de lei à Assembleia Legislativa do Estado do RN com a formalização do Plano de Amortização do déficit atuarial e revisão do plano de custeio e de benefícios de modo a contemplar a formação de reservas suficientes a serem devidamente capitalizadas para cobertura da Provisão Matemática de Benefícios Concedidos (PMBC), sob pena da aplicação de multa pessoal e diária aos responsáveis no valor de R$ 1.000,00 (mil reais), com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor este passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea b, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN a obrigação de fazer, consistente no ato de adotar as medidas do plano de ação previstas no Projeto de Lei a ser apresentado à Assembleia Legislativa, em harmonia com o ordenamento jurídico já referenciado, as quais deverão ser iniciadas imediatamente após o esgotamento do prazo de 60 (sessenta) dias úteis para a apresentação do plano de ação, sob pena de multa de R$ 1.000,00 (mil reais) por dia que superar o interregno previsto, com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor este passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea b, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora')]),
#  (123103,
#   45719,
#   45719,
#   '2025-09-17 00:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinado ao atual gestor do Instituto de Previdência do Estado do RN a obrigação de não fazer, consistente em abster-se de utilizar os recursos alocados em aplicações financeiras de investimentos de médio e longo prazo, bem como aqueles advindos de seus respectivos rendimentos, para cobrir eventual déficit financeiro mensal do pagamento de benefícios previdenciários, enquanto o montante de ativos garantidores do plano permanecerem inferiores à Provisão Matemática de Benefícios Concedidos (PMBC), sob pena de multa de R$ 10.000,00 (dez mil reais) por cada ato de descumprimento'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN a obrigação de fazer, consistente no ato de realizar a cobertura da insuficiência financeira do RPPS, na hipótese dos recursos regularmente arrecadados das contribuições ordinárias e extraordinárias não serem suficientes para o pagamento dos benefícios previdenciários, em atenção ao disposto no artigo 2º, § 1º, da Lei 9717/98, sob pena de multa de R$ 10.000,00 (dez mil reais) por cada ato de descumprimento'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN e ao atual gestor do Instituto de Previdência do Estado do RN que, no prazo de 60 (sessenta) dias úteis, apresentem um plano de ação visando à amortização do déficit atuarial e à adequação da relação entre os ativos garantidores e as provisões matemáticas dos benefícios concedidos. O plano deverá, necessariamente, contemplar um estudo atuarial com avaliação das sugestões indicadas na fundamentação do voto-vista condutor deste Acórdão e determinação de encaminhamento de um projeto de lei à Assembleia Legislativa do Estado do RN com a formalização do Plano de Amortização do déficit atuarial e revisão do plano de custeio e de benefícios de modo a contemplar a formação de reservas suficientes a serem devidamente capitalizadas para cobertura da Provisão Matemática de Benefícios Concedidos (PMBC), sob pena da aplicação de multa pessoal e diária aos responsáveis no valor de R$ 1.000,00 (mil reais), com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor este passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea b, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora'),
#    NERObrigacao(descricao_obrigacao='Determinado à Exma. Sra. Governadora do Estado do RN a obrigação de fazer, consistente no ato de adotar as medidas do plano de ação previstas no Projeto de Lei a ser apresentado à Assembleia Legislativa, em harmonia com o ordenamento jurídico já referenciado, as quais deverão ser iniciadas imediatamente após o esgotamento do prazo de 60 (sessenta) dias úteis para a apresentação do plano de ação, sob pena de multa de R$ 1.000,00 (mil reais) por dia que superar o interregno previsto, com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor este passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea b, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (122582,
#   45680,
#   45680,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinar à Secretaria de Estado de Administração e Recursos Humanos, por seu atual gestor, que, no prazo de 60 dias, remeta a esta Corte de Contas todos os processos de admissões efetuadas em razão do Edital nº 001/2015 – SEARH/SEEC-RN, a fim de que sejam submetidos à análise de legalidade, para fins de registro, sob pena de multa pessoal e diária de R$200,00 (duzentos reais) por processo não enviado, aplicável ao atual gestor.')]),
#  (123027,
#   45840,
#   45840,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='Determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias, após do trânsito em julgado desta Decisão, adote as correções necessárias para regularização do ato concessivo, do cálculo dos proventos e da sua implantação; c) Responsabilização do gestor responsável por seu atendimento, no caso de descumprimento da presente Decisão, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado no item b, com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea f, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.')]),
#  (122657,
#   45702,
#   45702,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='cientificar o atual responsável pelo instituto previdenciário estadual para que, existindo pleito de pensão por morte aberto, remeta-o ao TCE/RN no prazo de sessenta (60) dias, nos termos do art. 96, IV, da LC nº 464/2012')]),
#  (122657,
#   45702,
#   45702,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='cientificar o atual responsável pelo instituto previdenciário estadual para que, existindo pleito de pensão por morte aberto, remeta-o ao TCE/RN no prazo de sessenta (60) dias, nos termos do art. 96, IV, da LC nº 464/2012')]),
#  (122657,
#   45702,
#   45702,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='cientificar o atual responsável pelo instituto previdenciário estadual para que, existindo pleito de pensão por morte aberto, remeta-o ao TCE/RN no prazo de sessenta (60) dias, nos termos do art. 96, IV, da LC nº 464/2012')]),
#  (122105,
#   44714,
#   44714,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='expedição de determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta decisão, adote as seguintes correções necessárias para regularização do ato concessivo, e do cálculo dos proventos: b.1) Para que conste no ato aposentador o artigo 3º da Emenda Constitucional 47/2005; b.2) De forma que o montante na apostila corresponda o direito material da interessada; b.3) Para que na implantação reflita e respeite a Lei Complementar n° 084/2020, de 30 de janeiro de 2020, consequentemente, o montante correspondente aos quinquênios siga a correta aplicação; b.4) Que cumpra corretamente o art. 135, do Plano de Carreira Cargos e Salários do Município de São José do Seridó e apresente nos autos os documentos necessários para demonstrar como foi realizado o cálculo.')]),
#  (123076,
#   45875,
#   45875,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='após o trânsito em julgado, pela determinação à autoridade responsável pela Instituto de Previdência dos Servidores do Estado do RN – IPERN, para que, prazo de 60 (sessenta) dias úteis, de acordo com o inteiro teor desta Decisão, adote as providências abaixo descritas, sob pena de responsabilidade da autoridade administrativa, para: -  elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.')]),
#  (123076,
#   45875,
#   45875,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='após o trânsito em julgado, pela determinação à autoridade responsável pela Instituto de Previdência dos Servidores do Estado do RN – IPERN, para que, prazo de 60 (sessenta) dias úteis, de acordo com o inteiro teor desta Decisão, adote as providências abaixo descritas, sob pena de responsabilidade da autoridade administrativa, para: -  elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.')]),
#  (123076,
#   45875,
#   45875,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='após o trânsito em julgado, pela determinação à autoridade responsável pela Instituto de Previdência dos Servidores do Estado do RN – IPERN, para que, prazo de 60 (sessenta) dias úteis, de acordo com o inteiro teor desta Decisão, adote as providências abaixo descritas, sob pena de responsabilidade da autoridade administrativa, para: -  elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.')]),
#  (122819,
#   45763,
#   45763,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinam à autoridade responsável pelo Instituto de Previdência dos Servidores do Município de São Miguel – IPSAM, que, no prazo de 60 dias úteis após o trânsito em julgado, proceda à correção do ato de aposentadoria, sanando a omissão quanto à fundamentação legal do adicional por tempo de serviço, bem como acoste aos autos o laudo pericial exarado por junta médica oficial, sob pena de responsabilidade da autoridade administrativa')]),
#  (122819,
#   45763,
#   45763,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='determinam à autoridade responsável pelo Instituto de Previdência dos Servidores do Município de São Miguel – IPSAM, que, no prazo de 60 dias úteis após o trânsito em julgado, proceda à correção do ato de aposentadoria, sanando a omissão quanto à fundamentação legal do adicional por tempo de serviço, bem como acoste aos autos o laudo pericial exarado por junta médica oficial, sob pena de responsabilidade da autoridade administrativa')]),
#  (122811,
#   44369,
#   44369,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Deoclécio Marques de Lucena, para que providencie o envio das devidas informações, relativas ao 2º bimestre de 2017, no prazo de 40 (quarenta) dias.')]),
#  (122811,
#   44369,
#   44369,
#   '2025-09-22 10:00:00',
#   [NERObrigacao(descricao_obrigacao='intimação do atual gestor do Hospital Regional Deoclécio Marques de Lucena, para que providencie o envio das devidas informações, relativas ao 2º bimestre de 2017, no prazo de 40 (quarenta) dias.')])]

# %%
def remover_obrigacoes_duplicadas(obrigacoes_list):
    """
    Remove obrigações duplicadas de uma lista de NERObrigacao.

    Args:
        obrigacoes_list (list): A lista de objetos NERObrigacao.

    Returns:
        list: Uma nova lista com as obrigações únicas.
    """
    obrigacoes_vistas = set()
    obrigacoes_sem_duplicatas = []
    
    for obrigacao in obrigacoes_list:
        # Pega a descrição, remove espaços em branco e a converte para lowercase
        # para garantir que strings como 'Texto ' e 'texto' sejam tratadas como a mesma.
        descricao_limpa = obrigacao.descricao_obrigacao.strip().lower()
        
        if descricao_limpa not in obrigacoes_vistas:
            obrigacoes_vistas.add(descricao_limpa)
            obrigacoes_sem_duplicatas.append(obrigacao)
            
    return obrigacoes_sem_duplicatas

# %%
from sqlalchemy.exc import IntegrityError
from sqlalchemy.orm import Session
# Assuming these are your imports

errors = []
k = 0

for _, row in df_ob.iterrows():
    print(f"Processando instância {row.name} de {len(df_ob)}")

    # Remove duplicatas da lista de obrigações antes de iniciar o loop
    obrigacoes_unicas = remover_obrigacoes_duplicadas(row['obrigacoes'])

    for obrigacao in obrigacoes_unicas:
        db_session = SessionLocal() # Create the session inside the loop to ensure a fresh connection for each row
        try:
            result_obrigacao = extract_obrigacao(row, obrigacao)
            insert_obrigacao(db_session, result_obrigacao, row)
            db_session.commit() # Commit the transaction here
        except IntegrityError:
            # This block handles the duplicate key error specifically
            print(f"Registro duplicado. Não será inserido: {row['idprocesso']}")
            db_session.rollback() # Rollback the transaction to clear the session state
        except Exception as e:
            # This block handles all other potential errors
            print(f"Erro ao processar obrigação: {e}")
            db_session.rollback() # Rollback on other errors as well
            errors.append((row['idprocesso'], obrigacao, str(e)))
        finally:
            db_session.close() # Always close the session to release the connection
# Out:
# Processando instância 0 de 193
# 2025-10-07 13:56:31,584 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:31,584 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:31,584 INFO sqlalchemy.engine.Engine [cached since 423.8s ago] {'IdProcesso': 570151, 'IdComposicaoPauta': 120308, 'IdVotoPauta': 44102, 'DescricaoObrigacao': 'Regularizar a situação noticiada nos autos.', 'DeFazer': 1, 'Prazo': '30 dias', 'DataCumprimento': datetime.datetime(2025, 8, 8, 0, 0), 'OrgaoResponsavel': 'MACAUPREV', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 1100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:31,584 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 4 de 193
# 2025-10-07 13:56:34,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:34,441 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:34,442 INFO sqlalchemy.engine.Engine [cached since 426.7s ago] {'IdProcesso': 570737, 'IdComposicaoPauta': 120288, 'IdVotoPauta': 44261, 'DescricaoObrigacao': 'Promover, no prazo de 60 (sessenta) dias úteis, contados do trânsito em julgado desta decisão, medidas de regularização do ato concessivo e do respectivo cálculo dos proventos, incluindo adequação da documentação comprobatória, conforme requisitos da Resolução nº 08/2012-TC.', 'DeFazer': 1, 'Prazo': '60 (sessenta) dias úteis contados do trânsito em julgado desta decisão', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:34,446 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:56:36,857 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:36,857 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:36,857 INFO sqlalchemy.engine.Engine [cached since 429.1s ago] {'IdProcesso': 570737, 'IdComposicaoPauta': 120288, 'IdVotoPauta': 44261, 'DescricaoObrigacao': 'Promoção das medidas de regularização do ato concessivo e do respectivo cálculo dos proventos, conforme itens indicados no acórdão.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 10, 1, 0, 0), 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:36,857 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 8 de 193
# 2025-10-07 13:56:40,318 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:40,319 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:40,319 INFO sqlalchemy.engine.Engine [cached since 432.6s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:40,323 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 9 de 193
# 2025-10-07 13:56:42,072 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:42,073 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:42,074 INFO sqlalchemy.engine.Engine [cached since 434.3s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas, nos termos do art. 101, parágrafo único, da LCE nº 464/2012.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:42,078 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 10 de 193
# 2025-10-07 13:56:45,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:45,100 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:45,101 INFO sqlalchemy.engine.Engine [cached since 437.3s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:45,105 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 11 de 193
# 2025-10-07 13:56:47,419 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:47,420 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:47,421 INFO sqlalchemy.engine.Engine [cached since 439.7s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas no prazo de 90 dias contados do trânsito em julgado da decisão.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:47,425 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 12 de 193
# 2025-10-07 13:56:49,700 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:49,705 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:49,705 INFO sqlalchemy.engine.Engine [cached since 441.9s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as provi ... (84 characters truncated) ... completo, mapeamento do tempo de contribuição, atos concessivos, comprovações de remunerações, apostila de cálculo do benefício e fichas financeiras.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:49,705 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:56:51,722 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:51,723 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:51,724 INFO sqlalchemy.engine.Engine [cached since 444s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar a intimação da autoridade competente do MACAUPREV, para ciência integral desta Decisão.', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:51,726 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 13 de 193
# 2025-10-07 13:56:54,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:54,146 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:54,146 INFO sqlalchemy.engine.Engine [cached since 446.4s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as providências indicadas (juntar aos autos os documentos listados).', 'DeFazer': 1, 'Prazo': '60 dias úteis após o trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:54,157 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:56:56,389 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:56,390 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:56,391 INFO sqlalchemy.engine.Engine [cached since 448.6s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar a intimação da autoridade competente do MACAUPREV, para ciência integral desta Decisão.', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:56,393 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 14 de 193
# 2025-10-07 13:56:58,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:56:58,894 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:56:58,894 INFO sqlalchemy.engine.Engine [cached since 451.1s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as segui ... (242 characters truncated) ... a de cálculo do benefício; fichas financeiras referentes à última remuneração percebida na ativa e aos meses subsequentes à implantação do benefício.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:56:58,918 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 15 de 193
# 2025-10-07 13:57:02,180 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:02,180 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:02,180 INFO sqlalchemy.engine.Engine [cached since 454.4s ago] {'IdProcesso': 570304, 'IdComposicaoPauta': 120645, 'IdVotoPauta': 44605, 'DescricaoObrigacao': 'Determinar à autoridade responsável pelo MACAUPREV que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta Decisão, adote as segui ... (134 characters truncated) ... al, fundamentos jurídicos da aposentadoria, remunerações utilizadas como base de contribuição, apostila de cálculo de benefício e fichas financeiras.', 'DeFazer': 1, 'Prazo': '60 dias úteis após o trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:02,180 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 16 de 193
# 2025-10-07 13:57:05,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:05,470 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:05,471 INFO sqlalchemy.engine.Engine [cached since 457.7s ago] {'IdProcesso': 571230, 'IdComposicaoPauta': 120869, 'IdVotoPauta': 44733, 'DescricaoObrigacao': 'Determinação ao órgão previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, após o trânsito em julga ... (475 characters truncated) ... as à última remuneração, ao primeiro e ao último dos meses após a implantação do benefício; e certidão de regularidade emitida pelo controle interno.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Atual gestor(a) responsável pelo órgão previdenciário', 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:05,471 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 17 de 193
# 2025-10-07 13:57:08,040 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:08,041 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:08,041 INFO sqlalchemy.engine.Engine [cached since 460.3s ago] {'IdProcesso': 570159, 'IdComposicaoPauta': 120870, 'IdVotoPauta': 44732, 'DescricaoObrigacao': 'DETERMINAÇÃO ao órgão previdenciário responsável pela concessão do benefício para que, no prazo de 60 (sessenta) dias úteis, após o trânsito em julgado desta decisão promova a cessação do benefício ou apresente os documentos necessários à análise de mérito.', 'DeFazer': 1, 'Prazo': '60 dias úteis após trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:08,046 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:57:10,305 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:10,321 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:10,321 INFO sqlalchemy.engine.Engine [cached since 462.6s ago] {'IdProcesso': 570159, 'IdComposicaoPauta': 120870, 'IdVotoPauta': 44732, 'DescricaoObrigacao': 'Determinação ao órgão previdenciário responsável para que promova a cessação do benefício ou apresente documentos necessários à análise de mérito.', 'DeFazer': 1, 'Prazo': '60 dias úteis a partir do trânsito em julgado.', 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Desconhecido', 'DocumentoResponsavelMultaCominatoria': 'Desconhecido', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:10,326 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 21 de 193
# 2025-10-07 13:57:14,293 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:14,293 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:14,293 INFO sqlalchemy.engine.Engine [cached since 466.5s ago] {'IdProcesso': 533923, 'IdComposicaoPauta': 120378, 'IdVotoPauta': 44370, 'DescricaoObrigacao': 'Expedição de determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trân ... (98 characters truncated) ... esentação da seguinte documentação: a correção do ato aposentador, com a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou.', 'DeFazer': 1, 'Prazo': '60 dias úteis após trânsito em julgado', 'DataCumprimento': datetime.datetime(2025, 10, 21, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DE JUCURUTU', 'IdOrgaoResponsavel': 1308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Maria Aparecida Batista Pereira de Araújo', 'DocumentoResponsavelMultaCominatoria': '53814924487', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["25344040000181", "53814924487", "76204715453"]'}
# 2025-10-07 13:57:14,293 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 22 de 193
# 2025-10-07 13:57:17,162 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:17,162 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:17,162 INFO sqlalchemy.engine.Engine [cached since 469.4s ago] {'IdProcesso': 533923, 'IdComposicaoPauta': 120378, 'IdVotoPauta': 44370, 'DescricaoObrigacao': 'Adotar as correções necessárias para regularização do ato, com a apresentação da seguinte documentação: i. A correção do ato aposentador, com a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou.', 'DeFazer': 1, 'Prazo': '60 dias úteis após o trânsito em julgado', 'DataCumprimento': datetime.datetime(2025, 10, 22, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DE JUCURUTU', 'IdOrgaoResponsavel': 1308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Maria Aparecida Batista Pereira de Araújo', 'DocumentoResponsavelMultaCominatoria': '53814924487', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["INSTITUTO DE PREVID\\u00caNCIA SOCIAL DE JUCURUTU", "Maria Aparecida Batista Pereira de Ara\\u00fajo", "MARIA DA PAZ DE ARAUJO"]'}
# 2025-10-07 13:57:17,162 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 23 de 193
# 2025-10-07 13:57:20,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:20,116 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:20,116 INFO sqlalchemy.engine.Engine [cached since 472.4s ago] {'IdProcesso': 533923, 'IdComposicaoPauta': 120378, 'IdVotoPauta': 44370, 'DescricaoObrigacao': 'Determinação ao Órgão Previdenciário responsável pela concessão do benefício para que, no prazo de 60 dias úteis após o trânsito em julgado da decisã ... (51 characters truncated) ... o do ato, com a apresentação da correção do ato aposentador, incluindo a indicação da Classe/Grupo do cargo em que a parte beneficiária se aposentou.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DE JUCURUTU', 'IdOrgaoResponsavel': 1308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Maria Aparecida Batista Pereira de Araújo', 'DocumentoResponsavelMultaCominatoria': '53814924487', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:20,116 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 25 de 193
# 2025-10-07 13:57:22,836 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:22,836 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:22,836 INFO sqlalchemy.engine.Engine [cached since 475.1s ago] {'IdProcesso': 535003, 'IdComposicaoPauta': 121872, 'IdVotoPauta': 45277, 'DescricaoObrigacao': 'Estabelecer o prazo de 60 (sessenta) dias, contados a partir do trânsito em julgado da presente Decisão, para que o órgão de origem responsável junte aos autos a documentação solicitada.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2025, 10, 5, 0, 0), 'OrgaoResponsavel': 'TRIBUNAL DE JUSTIÇA', 'IdOrgaoResponsavel': 535, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'MARIA NAIDE DE GOES BAY.', 'DocumentoResponsavelMultaCominatoria': '46622012415', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:22,851 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 26 de 193
# 2025-10-07 13:57:26,542 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:26,542 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:26,542 INFO sqlalchemy.engine.Engine [cached since 478.8s ago] {'IdProcesso': 535003, 'IdComposicaoPauta': 121872, 'IdVotoPauta': 45277, 'DescricaoObrigacao': 'Estabelecer o prazo de 60 (sessenta) dias, contados a partir do trânsito em julgado da presente Decisão, com base no art. 1º, inciso VII, da referida ... (205 characters truncated) ... cial, sob pena de aplicação de sanção administrativa ao responsável, devendo o processo, após o cumprimento, ser devolvido a este Tribunal de Contas.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2025, 10, 5, 0, 0), 'OrgaoResponsavel': 'TRIBUNAL DE JUSTIÇA', 'IdOrgaoResponsavel': 535, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:26,555 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 27 de 193
# 2025-10-07 13:57:29,176 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:29,176 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:29,176 INFO sqlalchemy.engine.Engine [cached since 481.4s ago] {'IdProcesso': 540928, 'IdComposicaoPauta': 120978, 'IdVotoPauta': 44721, 'DescricaoObrigacao': 'A Prefeitura Municipal de Cruzeta, por meio de seu atual gestor, deve apurar a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, e adotar providências para saneamento da situação irregular.', 'DeFazer': 1, 'Prazo': '120 dias úteis', 'DataCumprimento': datetime.datetime(2025, 12, 16, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CRUZETA', 'IdOrgaoResponsavel': 369, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'JOAQUIM JOSÉ DE MEDEIROS', 'DocumentoResponsavelMultaCominatoria': '53592689487', 'IdPessoaMultaCominatoria': 4001.0, 'ValorMultaCominatoria': 500.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:29,191 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:57:32,462 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:32,462 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:32,462 INFO sqlalchemy.engine.Engine [cached since 484.7s ago] {'IdProcesso': 540928, 'IdComposicaoPauta': 120978, 'IdVotoPauta': 44721, 'DescricaoObrigacao': 'Determinação à Prefeitura Municipal de Cruzeta, por seu atual Prefeito, para que apure a legalidade da acumulação de cargos públicos protagonizada pelo servidor JOÃO NICÁCIO FEITOSA DA SILVA, com a adoção de providências para saneamento de situação irregular, comunicando o resultado a esta Corte.', 'DeFazer': 1, 'Prazo': '120 dias úteis', 'DataCumprimento': datetime.datetime(2026, 1, 14, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CRUZETA', 'IdOrgaoResponsavel': 369, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Joaquim José de Medeiros', 'DocumentoResponsavelMultaCominatoria': '53592689487', 'IdPessoaMultaCominatoria': 4001.0, 'ValorMultaCominatoria': 500.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:32,462 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 28 de 193
# 2025-10-07 13:57:35,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 13:57:35,547 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 13:57:35,548 INFO sqlalchemy.engine.Engine [cached since 487.8s ago] {'IdProcesso': 540928, 'IdComposicaoPauta': 120978, 'IdVotoPauta': 44721, 'DescricaoObrigacao': 'Determine que a Prefeitura Municipal de Pendências, na pessoa de seu atual gestor, promova a apuração dos fatos e a verificação da legalidade dos vín ... (185 characters truncated) ... uenta) dias para conclusão dos processos administrativos disciplinares e comunicação ao Tribunal de Contas em até 10 (dez) dias após esse interregno.', 'DeFazer': 1, 'Prazo': '150 dias', 'DataCumprimento': datetime.datetime(2025, 12, 25, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE PENDÊNCIAS', 'IdOrgaoResponsavel': 369, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'PREFEITURA MUNICIPAL DE PENDÊNCIAS', 'DocumentoResponsavelMultaCominatoria': '08122657000133', 'IdPessoaMultaCominatoria': 12417.0, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 13:57:35,548 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-07 13:57:38,435 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
# 2025-10-07 14:09:26,695 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 195 de 193
# 2025-10-07 14:09:29,440 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:29,440 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:29,440 INFO sqlalchemy.engine.Engine [cached since 1202s ago] {'IdProcesso': 534126, 'IdComposicaoPauta': 122105, 'IdVotoPauta': 44714, 'DescricaoObrigacao': 'Determinação ao Órgão Previdenciário responsável pela concessão do benefício para adotar medidas corretivas na regularização do ato concessivo e do cálculo dos proventos, nos termos do voto.', 'DeFazer': 1, 'Prazo': '60 dias úteis a partir do trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DO MUNICÍPIO DE SÃO JOSÉ DO SERIDÓ', 'IdOrgaoResponsavel': 1249, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'ALICE FRANCISCA DE ARAUJO', 'DocumentoResponsavelMultaCominatoria': '63116219400', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 14:09:30,128 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 196 de 193
# 2025-10-07 14:09:33,753 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:33,753 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:33,753 INFO sqlalchemy.engine.Engine [cached since 1206s ago] {'IdProcesso': 536738, 'IdComposicaoPauta': 123076, 'IdVotoPauta': 45875, 'DescricaoObrigacao': 'Elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 12, 18, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'DEBORA AGUIAR DE BARROS DIAS', 'DocumentoResponsavelMultaCominatoria': '02998047203', 'IdPessoaMultaCominatoria': 65664.0, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["ANTONIO DE FREITAS LEAO"]'}
# 2025-10-07 14:09:34,377 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 197 de 193
# 2025-10-07 14:09:36,955 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:36,955 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:36,955 INFO sqlalchemy.engine.Engine [cached since 1209s ago] {'IdProcesso': 536738, 'IdComposicaoPauta': 123076, 'IdVotoPauta': 45875, 'DescricaoObrigacao': 'Elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 12, 17, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'DEBORA AGUIAR DE BARROS DIAS', 'DocumentoResponsavelMultaCominatoria': '02998047203', 'IdPessoaMultaCominatoria': 65664.0, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["ANTONIO DE FREITAS LEAO"]'}
# 2025-10-07 14:09:37,451 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 198 de 193
# 2025-10-07 14:09:40,283 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:40,283 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:40,283 INFO sqlalchemy.engine.Engine [cached since 1213s ago] {'IdProcesso': 536738, 'IdComposicaoPauta': 123076, 'IdVotoPauta': 45875, 'DescricaoObrigacao': 'Elaborar novo ato aposentador, apostila de cálculos e implantação dos proventos, excluindo a referida Vantagem Pessoal da Lei nº 6.192/1991 dos proventos.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 12, 17, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Estado do RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'DEBORA AGUIAR DE BARROS DIAS', 'DocumentoResponsavelMultaCominatoria': '02998047203', 'IdPessoaMultaCominatoria': 65664.0, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["DEBORA AGUIAR DE BARROS DIAS", "ANTONIO DE FREITAS LEAO"]'}
# 2025-10-07 14:09:40,642 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 199 de 193
# 2025-10-07 14:09:43,253 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:43,254 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:43,255 INFO sqlalchemy.engine.Engine [cached since 1216s ago] {'IdProcesso': 537220, 'IdComposicaoPauta': 122819, 'IdVotoPauta': 45763, 'DescricaoObrigacao': 'Proceder à correção do ato de aposentadoria, sanando a omissão quanto à fundamentação legal do adicional por tempo de serviço e acostando aos autos o laudo pericial exarado por junta médica oficial.', 'DeFazer': 1, 'Prazo': '60 dias úteis após o trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DO MUNICÍPIO DE SÃO MIGUEL', 'IdOrgaoResponsavel': 1252, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'MARIA JOSE DA SILVA FARIAS', 'DocumentoResponsavelMultaCominatoria': '77955790430', 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["MARIA JOSE DA SILVA FARIAS", "I P S DO MUNIC\\u00cdPIO DE S\\u00c3O MIGUEL"]'}
# 2025-10-07 14:09:43,354 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 200 de 193
# 2025-10-07 14:09:45,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:45,986 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:45,986 INFO sqlalchemy.engine.Engine [cached since 1218s ago] {'IdProcesso': 537220, 'IdComposicaoPauta': 122819, 'IdVotoPauta': 45763, 'DescricaoObrigacao': 'Proceder à correção do ato de aposentadoria, sanando a omissão quanto à fundamentação legal do adicional por tempo de serviço, bem como acostar aos autos o laudo pericial exarado por junta médica oficial.', 'DeFazer': 1, 'Prazo': '60 dias úteis após o trânsito em julgado', 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DO MUNICÍPIO DE SÃO MIGUEL', 'IdOrgaoResponsavel': 1252, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 14:09:46,613 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 201 de 193
# 2025-10-07 14:09:48,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:48,768 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:48,768 INFO sqlalchemy.engine.Engine [cached since 1221s ago] {'IdProcesso': 546188, 'IdComposicaoPauta': 122811, 'IdVotoPauta': 44369, 'DescricaoObrigacao': 'Providenciar o envio das devidas informações, relativas ao 2º bimestre de 2017.', 'DeFazer': 1, 'Prazo': '40 dias', 'DataCumprimento': datetime.datetime(2025, 11, 1, 0, 0), 'OrgaoResponsavel': 'HOSPITAL REGIONAL DEOCLÉCIO MARQUES DE LUCENA', 'IdOrgaoResponsavel': 296, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 14:09:49,299 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 202 de 193
# 2025-10-07 14:09:51,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-07 14:09:51,205 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-07 14:09:51,205 INFO sqlalchemy.engine.Engine [cached since 1223s ago] {'IdProcesso': 546188, 'IdComposicaoPauta': 122811, 'IdVotoPauta': 44369, 'DescricaoObrigacao': 'Providenciar o envio das devidas informações relativas ao 2º bimestre de 2017.', 'DeFazer': 1, 'Prazo': '40 dias', 'DataCumprimento': datetime.datetime(2025, 11, 1, 0, 0), 'OrgaoResponsavel': 'HOSPITAL REGIONAL DEOCLÉCIO MARQUES DE LUCENA', 'IdOrgaoResponsavel': 296, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-07 14:09:51,221 INFO sqlalchemy.engine.Engine COMMIT

# %%
errors = []
k = 0
for _, row in df_ob.iterrows():
    k += 1
    if k % 10 == 0 and k > 0:
        print(f"Processando instância {k} de {len(df_ob)}")

    for obrigacao in row['obrigacoes']:
        try:
            result_obrigacao = extract_obrigacao(row, obrigacao)
            db_session = SessionLocal()
            insert_obrigacao(db_session, result_obrigacao, row)
            db_session.close()
        except Exception as e:
            print(f"Erro ao processar obrigação: {e}")
            errors.append((row['idprocesso'], obrigacao, str(e)))
# Out:
# Erro ao processar obrigação: 'documento_responsavel'
# 2025-10-06 16:26:24,036 INFO sqlalchemy.engine.Engine select @@version
# 2025-10-06 16:26:24,036 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-06 16:26:24,051 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2025-10-06 16:26:24,051 INFO sqlalchemy.engine.Engine [generated in 0.00089s] {}
# 2025-10-06 16:26:24,051 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2025-10-06 16:26:24,051 INFO sqlalchemy.engine.Engine [generated in 0.00083s] {}
# 2025-10-06 16:26:24,068 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2025-10-06 16:26:24,069 INFO sqlalchemy.engine.Engine [generated in 0.00099s] {}
# 2025-10-06 16:26:24,184 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:24,184 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:24,184 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {'IdProcesso': 532601, 'IdComposicaoPauta': 120655, 'IdVotoPauta': 44618, 'DescricaoObrigacao': 'Adequação do ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informar a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 10, 2, 0, 0), 'OrgaoResponsavel': 'FUNDO DE PREVIDÊNCIA SOCIAL DO MUNICÍPIO DE PASSA E FICA', 'IdOrgaoResponsavel': 1235, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'BRUNO LIMA DE SENA', 'DocumentoResponsavelMultaCominatoria': '08195843476', 'IdPessoaMultaCominatoria': 55700.0, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:26:24,184 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:26:26,775 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:26,788 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:26,788 INFO sqlalchemy.engine.Engine [cached since 2.601s ago] {'IdProcesso': 532601, 'IdComposicaoPauta': 120655, 'IdVotoPauta': 44618, 'DescricaoObrigacao': 'Adequar o ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informar a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 10, 1, 0, 0), 'OrgaoResponsavel': 'FUNDO DE PREVIDÊNCIA SOCIAL DO MUNICÍPIO DE PASSA E FICA', 'IdOrgaoResponsavel': 1235, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'BRUNO LIMA DE SENA', 'DocumentoResponsavelMultaCominatoria': '08195843476', 'IdPessoaMultaCominatoria': 55700.0, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["SEVERINA TARGINO DA SILVA", "FUNDO DE PREVID\\u00caNCIA SOCIAL DO MUNIC\\u00cdPIO DE PASSA E FICA"]'}
# 2025-10-06 16:26:26,789 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:26:29,389 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:29,389 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:29,404 INFO sqlalchemy.engine.Engine [cached since 5.217s ago] {'IdProcesso': 532601, 'IdComposicaoPauta': 120655, 'IdVotoPauta': 44618, 'DescricaoObrigacao': 'Adequação do ato aposentador, fazendo constar o nível e o padrão remuneratório devidos à interessada à época da passagem para a inatividade, bem como informe a legislação que embasa o valor atualmente percebido, inserindo a respectiva norma no Sistema Legis.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 12, 1, 0, 0), 'OrgaoResponsavel': 'FUNDO DE PREVIDÊNCIA SOCIAL DO MUNICÍPIO DE PASSA E FICA', 'IdOrgaoResponsavel': 1235, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'BRUNO LIMA DE SENA', 'DocumentoResponsavelMultaCominatoria': '08195843476', 'IdPessoaMultaCominatoria': 55700.0, 'ValorMultaCominatoria': 50.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["SEVERINA TARGINO DA SILVA", "FUNDO DE PREVID\\u00caNCIA SOCIAL DO MUNIC\\u00cdPIO DE PASSA E FICA"]'}
# 2025-10-06 16:26:29,406 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: 'documento_responsavel'
# Erro ao processar obrigação: 'documento_responsavel'
# Erro ao processar obrigação: 'documento_responsavel'
# Erro ao processar obrigação: 'documento_responsavel'
# 2025-10-06 16:26:43,187 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:43,187 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:43,187 INFO sqlalchemy.engine.Engine [cached since 19.01s ago] {'IdProcesso': 562189, 'IdComposicaoPauta': 120425, 'IdVotoPauta': 43553, 'DescricaoObrigacao': 'Intimação do Instituto de Previdência do Município de São José do Seridó – IPREV-SJS, por seu atual gestor, a fim de que possa promover a devida compensação financeira junto ao Regime Geral de Previdência Social.', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:26:43,204 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:26:45,658 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:45,658 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:45,658 INFO sqlalchemy.engine.Engine [cached since 21.47s ago] {'IdProcesso': 562189, 'IdComposicaoPauta': 120425, 'IdVotoPauta': 43553, 'DescricaoObrigacao': "Pela intimação da parte interessada, nos termos do artigo 46, combinado com o artigo 47, parágrafo, único, alínea 'g' Lei Complementar Estadual nº 464/2012.", 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:26:45,662 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:26:48,401 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:48,401 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:48,401 INFO sqlalchemy.engine.Engine [cached since 24.22s ago] {'IdProcesso': 544545, 'IdComposicaoPauta': 120613, 'IdVotoPauta': 44598, 'DescricaoObrigacao': 'Providenciar o envio das informações devidas relativas ao 2º bimestre de 2017.', 'DeFazer': 1, 'Prazo': '40 dias', 'DataCumprimento': datetime.datetime(2025, 8, 23, 0, 0), 'OrgaoResponsavel': 'HOSPITAL REGIONAL DOUTOR CLEODON CARLOS DE ANDRADE', 'IdOrgaoResponsavel': 276, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:26:48,405 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:26:51,602 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:26:51,602 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:26:51,602 INFO sqlalchemy.engine.Engine [cached since 27.42s ago] {'IdProcesso': 544545, 'IdComposicaoPauta': 120613, 'IdVotoPauta': 44598, 'DescricaoObrigacao': 'Intimação do atual gestor do Hospital Regional Doutor Cleodon Carlos de Andrade, para que providencie o envio das informações devidas relativas ao 2º bimestre de 2017.', 'DeFazer': 1, 'Prazo': '40 dias', 'DataCumprimento': datetime.datetime(2025, 8, 23, 0, 0), 'OrgaoResponsavel': 'Hospital Regional Doutor Cleodon Carlos de Andrade', 'IdOrgaoResponsavel': 276, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:26:51,602 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: 'documento_responsavel'
# Processando instância 10 de 693
# 2025-10-06 16:27:00,153 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:00,153 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:00,153 INFO sqlalchemy.engine.Engine [cached since 35.97s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas no prazo de 90 (noventa) dias contados do trânsito em julgado desta Decisão.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:00,153 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:05,141 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:05,141 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:05,141 INFO sqlalchemy.engine.Engine [cached since 40.97s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:05,141 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:09,015 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:09,015 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:09,015 INFO sqlalchemy.engine.Engine [cached since 44.83s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, para que o Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV), por meio de seu atual gestor, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:09,015 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:11,381 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:11,381 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:11,381 INFO sqlalchemy.engine.Engine [cached since 47.21s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas no prazo estabelecido.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Atual gestor do Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:11,400 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:14,478 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:14,478 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:14,479 INFO sqlalchemy.engine.Engine [cached since 50.29s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:14,483 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:16,796 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:16,796 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:16,796 INFO sqlalchemy.engine.Engine [cached since 52.61s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promoção, pelo Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV), por meio de seu atual gestor, da correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:16,800 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:19,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:19,506 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:19,506 INFO sqlalchemy.engine.Engine [cached since 55.32s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas, nos termos do art. 101, parágrafo único, da LCE nº 464/2012.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:19,506 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: 'documento_responsavel'
# 2025-10-06 16:27:24,912 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:24,912 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:24,912 INFO sqlalchemy.engine.Engine [cached since 60.74s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'O Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV) deve, por meio de seu atual gestor, corrigir as imprecisões apontadas no prazo fixado.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:24,933 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:28,049 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:28,050 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:28,050 INFO sqlalchemy.engine.Engine [cached since 63.87s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:28,050 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 20 de 693
# 2025-10-06 16:27:30,517 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:30,517 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:30,517 INFO sqlalchemy.engine.Engine [cached since 66.34s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas no prazo de 90 (noventa) dias, contados do trânsito em julgado da decisão.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:30,517 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:32,519 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:32,519 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:32,519 INFO sqlalchemy.engine.Engine [cached since 68.35s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas no prazo de 90 dias, contando do trânsito em julgado da decisão.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:32,536 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:34,756 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:34,756 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:34,756 INFO sqlalchemy.engine.Engine [cached since 70.58s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:34,756 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: 'documento_responsavel'
# 2025-10-06 16:27:42,137 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:42,138 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:42,138 INFO sqlalchemy.engine.Engine [cached since 77.95s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 dias, contados do trânsito em julgado desta Decisão, para que o Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV), por meio de seu atual gestor, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': None, 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:42,141 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:45,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:45,097 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:45,097 INFO sqlalchemy.engine.Engine [cached since 80.93s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:45,112 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:48,319 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:48,319 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:48,319 INFO sqlalchemy.engine.Engine [cached since 84.14s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Fixação de prazo de 90 (noventa) dias, contados do trânsito em julgado desta Decisão, com fundamento no art. 1º, inciso VII, da LCE nº 464/2012, para ... (72 characters truncated) ... (MACAUPREV), por meio de seu atual gestor, nos termos do art. 101, parágrafo único, da LCE nº 464/2012, promova a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:48,319 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:50,737 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:50,737 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-10-06 16:27:50,737 INFO sqlalchemy.engine.Engine [cached since 86.57s ago] {'IdProcesso': 571287, 'IdComposicaoPauta': 120712, 'IdVotoPauta': 44652, 'DescricaoObrigacao': 'Promover a correção das imprecisões apontadas.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 10, 12, 0, 0), 'OrgaoResponsavel': 'Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Atual gestor do Instituto de Previdência dos Servidores do Município de Macau/RN (MACAUPREV)', 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-10-06 16:27:50,753 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-06 16:27:53,489 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-06 16:27:53,489 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# ...
#    3078 with set_config_context(config) as context:
#    3079     if i == 0:
# -> 3080         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3081     else:
#    3082         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_core\runnables\base.py:5495, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5488 @override
#    5489 def invoke(
#    5490     self,
#    (...)   5493     **kwargs: Optional[Any],
#    5494 ) -> Output:
# -> 5495     return self.bound.invoke(
#    5496         input,
#    5497         self._merge_configs(config),
#    5498         **{**self.kwargs, **kwargs},
#    5499     )
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:393, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)    388     **kwargs: Any,
#     389 ) -> BaseMessage:
#     390     config = ensure_config(config)
#     391     return cast(
#     392         "ChatGeneration",
# --> 393         self.generate_prompt(
#     394             [self._convert_input(input)],
#     395             stop=stop,
#     396             callbacks=config.get("callbacks"),
#     397             tags=config.get("tags"),
#     398             metadata=config.get("metadata"),
#     399             run_name=config.get("run_name"),
#     400             run_id=config.pop("run_id", None),
#     401             **kwargs,
#     402         ).generations[0][0],
#     403     ).message
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1019, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1010 @override
#    1011 def generate_prompt(
#    1012     self,
#    (...)   1016     **kwargs: Any,
#    1017 ) -> LLMResult:
#    1018     prompt_messages = [p.to_messages() for p in prompts]
# -> 1019     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:837, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     834 for i, m in enumerate(input_messages):
#     835     try:
#     836         results.append(
# --> 837             self._generate_with_cache(
#     838                 m,
#     839                 stop=stop,
#     840                 run_manager=run_managers[i] if run_managers else None,
#     841                 **kwargs,
#     842             )
#     843         )
#     844     except BaseException as e:
#     845         if run_managers:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1085, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1083     result = generate_from_stream(iter(chunks))
#    1084 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1085     result = self._generate(
#    1086         messages, stop=stop, run_manager=run_manager, **kwargs
#    1087     )
#    1088 else:
#    1089     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1178, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1171         return _construct_lc_result_from_responses_api(
#    1172             response,
#    1173             schema=original_schema_obj,
#    1174             metadata=generation_info,
#    1175             output_version=self.output_version,
#    1176         )
#    1177     else:
# -> 1178         raw_response = self.client.with_raw_response.create(**payload)
#    1179         response = raw_response.parse()
#    1180 except Exception as e:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
_
# Out:
# 301

# %%
result_obrigacao
# Out:
# Obrigacao(descricao_obrigacao='Proceder à regularização da situação noticiada nos autos.', de_fazer=True, prazo='30 (trinta) dias', data_cumprimento=datetime.date(2025, 8, 8), orgao_responsavel='MACAUPREV', tem_multa_cominatoria=True, nome_responsavel_multa_cominatoria='Desconhecido', documento_responsavel_multa_cominatoria='Desconhecido', valor_multa_cominatoria=1100.0, periodo_multa_cominatoria='diário', e_multa_cominatoria_solidaria=False, solidarios_multa_cominatoria=None)

# %% [markdown]
# # From File

# %%
all_decisions = pd.read_csv("dataset/all_decisions.csv")
all_decisions['year'] = pd.to_datetime(all_decisions['datasessao']).dt.year
all_decisions_2023 = all_decisions[all_decisions['year'] >= 2023]

# %%
len(all_decisions_2023), len(all_decisions)

# %%
resultados = []
errors = []
for index, row in all_decisions_2023.iterrows():
    if index % 10 == 0 and index > 0:
        print(f"Processando instância {index} de {len(all_decisions_2023)}")
        all_decisions_2023.to_csv("dataset/all_decisions_2023_ner.csv", index=True)

    try:
        prompt_with_few_shot = generate_few_shot_ner_prompts(row['texto_acordao'])
        
        result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
        all_decisions_2023.at[index, 'ner_decisao'] = result
        resultados.append(result)
    except Exception as e:
        errors.append({
            'index': index,
            'error': str(e),
            'row': row.to_dict()
        })
# Out:
# /tmp/ipykernel_12742/1431655093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_decisions_2023.at[index, 'ner_decisao'] = result
# Processando instância 690 de 8728
# Processando instância 700 de 8728
# Processando instância 710 de 8728
# Processando instância 720 de 8728
# Processando instância 730 de 8728
# Processando instância 740 de 8728
# Processando instância 750 de 8728
# Processando instância 760 de 8728
# Processando instância 770 de 8728
# Processando instância 780 de 8728
# Processando instância 790 de 8728
# Processando instância 800 de 8728
# Processando instância 810 de 8728
# Processando instância 820 de 8728
# Processando instância 1360 de 8728
# Processando instância 1370 de 8728
# Processando instância 1380 de 8728
# Processando instância 1390 de 8728
# Processando instância 1400 de 8728
# Processando instância 1410 de 8728
# Processando instância 1420 de 8728
# Processando instância 1430 de 8728
# Processando instância 1440 de 8728
# Processando instância 1450 de 8728
# Processando instância 1460 de 8728
# Processando instância 1470 de 8728
# Processando instância 1480 de 8728
# Processando instância 1490 de 8728
# Processando instância 1500 de 8728
# Processando instância 1510 de 8728
# Processando instância 1520 de 8728
# Processando instância 1530 de 8728
# Processando instância 1540 de 8728
# Processando instância 1550 de 8728
# Processando instância 1560 de 8728
# Processando instância 1570 de 8728
# Processando instância 1580 de 8728
# Processando instância 1590 de 8728
# Processando instância 1600 de 8728
# Processando instância 1610 de 8728
# Processando instância 1620 de 8728
# Processando instância 1630 de 8728
# Processando instância 1640 de 8728
# Processando instância 1650 de 8728
# Processando instância 1660 de 8728
# Processando instância 1670 de 8728
# Processando instância 2890 de 8728
# Processando instância 2900 de 8728
# Processando instância 2910 de 8728
# Processando instância 2920 de 8728
# Processando instância 2930 de 8728
# Processando instância 2940 de 8728
# Processando instância 2950 de 8728
# Processando instância 2960 de 8728
# Processando instância 2970 de 8728
# Processando instância 2980 de 8728
# Processando instância 2990 de 8728
# Processando instância 3000 de 8728
# Processando instância 3010 de 8728
# Processando instância 3020 de 8728
# Processando instância 3030 de 8728
# Processando instância 3040 de 8728
# Processando instância 3050 de 8728
# Processando instância 3060 de 8728
# Processando instância 3070 de 8728
# Processando instância 3080 de 8728
# Processando instância 3090 de 8728
# Processando instância 3100 de 8728
# Processando instância 3110 de 8728
# Processando instância 3120 de 8728
# Processando instância 3130 de 8728
# Processando instância 3140 de 8728
# Processando instância 3150 de 8728
# Processando instância 3160 de 8728
# Processando instância 3170 de 8728
# Processando instância 3180 de 8728
# Processando instância 3190 de 8728
# Processando instância 3200 de 8728
# Processando instância 3210 de 8728
# Processando instância 3220 de 8728
# Processando instância 3230 de 8728
# Processando instância 3240 de 8728
# Processando instância 3250 de 8728
# Processando instância 3260 de 8728
# Processando instância 3270 de 8728
# Processando instância 3280 de 8728
# Processando instância 3290 de 8728
# Processando instância 3300 de 8728
# Processando instância 3310 de 8728
# Processando instância 3320 de 8728
# Processando instância 3330 de 8728
# Processando instância 3340 de 8728
# Processando instância 3350 de 8728
# Processando instância 3360 de 8728
# Processando instância 3370 de 8728
# Processando instância 6060 de 8728
# Processando instância 6070 de 8728
# Processando instância 6080 de 8728
# Processando instância 6090 de 8728
# Processando instância 6100 de 8728
# Processando instância 6110 de 8728
# Processando instância 6120 de 8728
# Processando instância 6130 de 8728
# Processando instância 6140 de 8728
# Processando instância 6150 de 8728
# Processando instância 6160 de 8728
# Processando instância 6170 de 8728
# Processando instância 6180 de 8728
# Processando instância 6190 de 8728
# Processando instância 6200 de 8728
# Processando instância 6210 de 8728
# Processando instância 6220 de 8728
# Processando instância 6230 de 8728
# Processando instância 6240 de 8728
# Processando instância 6250 de 8728
# Processando instância 6260 de 8728
# Processando instância 6270 de 8728
# Processando instância 6280 de 8728
# Processando instância 6290 de 8728
# Processando instância 6300 de 8728
# Processando instância 6310 de 8728
# Processando instância 6320 de 8728
# Processando instância 6330 de 8728
# Processando instância 6340 de 8728
# Processando instância 6350 de 8728
# Processando instância 6360 de 8728
# Processando instância 6370 de 8728
# Processando instância 6380 de 8728
# Processando instância 6390 de 8728
# Processando instância 6400 de 8728
# Processando instância 6410 de 8728
# Processando instância 6420 de 8728
# Processando instância 6430 de 8728
# Processando instância 6440 de 8728
# Processando instância 6450 de 8728
# Processando instância 6460 de 8728
# Processando instância 6470 de 8728
# Processando instância 6480 de 8728
# Processando instância 6490 de 8728
# Processando instância 6500 de 8728
# Processando instância 6510 de 8728
# Processando instância 6520 de 8728
# Processando instância 6530 de 8728
# Processando instância 6540 de 8728
# Processando instância 6550 de 8728
# Processando instância 6560 de 8728
# Processando instância 6570 de 8728
# Processando instância 6580 de 8728
# Processando instância 6590 de 8728
# Processando instância 6600 de 8728
# Processando instância 6610 de 8728
# Processando instância 6620 de 8728
# Processando instância 6630 de 8728
# Processando instância 6640 de 8728
# Processando instância 6650 de 8728
# Processando instância 6660 de 8728
# Processando instância 6670 de 8728
# Processando instância 6680 de 8728
# Processando instância 6690 de 8728
# Processando instância 6700 de 8728
# Processando instância 6710 de 8728
# Processando instância 6720 de 8728
# Processando instância 6730 de 8728
# Processando instância 6740 de 8728
# Processando instância 11490 de 8728
# Processando instância 11500 de 8728
# Processando instância 11510 de 8728
# Processando instância 11520 de 8728
# Processando instância 11530 de 8728
# Processando instância 11540 de 8728
# Processando instância 11550 de 8728
# Processando instância 11560 de 8728
# Processando instância 11570 de 8728
# Processando instância 11580 de 8728
# Processando instância 11590 de 8728
# Processando instância 11600 de 8728
# Processando instância 11610 de 8728
# Processando instância 11620 de 8728
# Processando instância 11630 de 8728
# Processando instância 11640 de 8728
# Processando instância 11650 de 8728
# Processando instância 11660 de 8728
# Processando instância 11670 de 8728
# Processando instância 11680 de 8728
# Processando instância 11690 de 8728
# Processando instância 11700 de 8728
# Processando instância 11710 de 8728
# Processando instância 11720 de 8728
# Processando instância 11730 de 8728
# Processando instância 11740 de 8728
# Processando instância 11750 de 8728
# Processando instância 11760 de 8728
# Processando instância 11770 de 8728
# Processando instância 11780 de 8728
# Processando instância 11790 de 8728
# Processando instância 11800 de 8728
# Processando instância 11810 de 8728
# Processando instância 11820 de 8728
# Processando instância 11830 de 8728
# Processando instância 11840 de 8728
# Processando instância 11850 de 8728
# Processando instância 11860 de 8728
# Processando instância 11870 de 8728
# Processando instância 11880 de 8728
# Processando instância 11890 de 8728
# Processando instância 11900 de 8728
# Processando instância 11910 de 8728
# Processando instância 11920 de 8728
# Processando instância 11930 de 8728
# Processando instância 11940 de 8728
# Processando instância 11950 de 8728
# Processando instância 11960 de 8728
# Processando instância 11970 de 8728
# Processando instância 11980 de 8728
# Processando instância 11990 de 8728
# Processando instância 12000 de 8728
# Processando instância 12010 de 8728
# Processando instância 12020 de 8728
# Processando instância 12030 de 8728
# Processando instância 12040 de 8728
# Processando instância 12050 de 8728
# Processando instância 12060 de 8728
# Processando instância 12070 de 8728
# Processando instância 12080 de 8728
# Processando instância 12090 de 8728
# Processando instância 12100 de 8728
# Processando instância 12110 de 8728
# Processando instância 12120 de 8728
# Processando instância 12130 de 8728
# Processando instância 12140 de 8728
# Processando instância 12150 de 8728
# Processando instância 12160 de 8728
# Processando instância 12170 de 8728
# Processando instância 12180 de 8728
# Processando instância 12190 de 8728
# Processando instância 12200 de 8728
# Processando instância 12210 de 8728
# Processando instância 12220 de 8728
# Processando instância 12230 de 8728
# Processando instância 12240 de 8728
# Processando instância 12250 de 8728
# Processando instância 12260 de 8728
# Processando instância 12270 de 8728
# Processando instância 12280 de 8728
# Processando instância 12290 de 8728
# Processando instância 12300 de 8728
# Processando instância 12310 de 8728
# Processando instância 12320 de 8728
# Processando instância 12330 de 8728
# Processando instância 12340 de 8728
# Processando instância 12350 de 8728
# Processando instância 12360 de 8728
# Processando instância 12370 de 8728
# Processando instância 12380 de 8728
# Processando instância 12390 de 8728
# Processando instância 12400 de 8728
# Processando instância 12410 de 8728
# Processando instância 12420 de 8728
# Processando instância 12430 de 8728
# Processando instância 12440 de 8728
# Processando instância 12450 de 8728
# Processando instância 12460 de 8728
# Processando instância 12470 de 8728
# Processando instância 12480 de 8728
# Processando instância 12490 de 8728
# Processando instância 12500 de 8728
# Processando instância 12510 de 8728
# Processando instância 12520 de 8728
# Processando instância 12530 de 8728
# Processando instância 12540 de 8728
# Processando instância 12550 de 8728
# Processando instância 12560 de 8728
# Processando instância 12570 de 8728
# Processando instância 12580 de 8728
# Processando instância 12590 de 8728
# Processando instância 12600 de 8728
# Processando instância 12610 de 8728
# Processando instância 12620 de 8728
# Processando instância 12630 de 8728
# Processando instância 12640 de 8728
# Processando instância 12650 de 8728
# Processando instância 12660 de 8728
# Processando instância 12670 de 8728
# Processando instância 12680 de 8728
# Processando instância 12690 de 8728
# Processando instância 12700 de 8728
# Processando instância 12710 de 8728
# Processando instância 12720 de 8728
# Processando instância 12730 de 8728
# Processando instância 12740 de 8728
# Processando instância 12750 de 8728
# Processando instância 12760 de 8728
# Processando instância 12770 de 8728
# Processando instância 12780 de 8728
# Processando instância 12790 de 8728
# Processando instância 12800 de 8728
# Processando instância 17650 de 8728
# Processando instância 17660 de 8728
# Processando instância 17670 de 8728
# Processando instância 17680 de 8728
# Processando instância 17690 de 8728
# Processando instância 17700 de 8728
# Processando instância 17710 de 8728
# Processando instância 17720 de 8728
# Processando instância 17730 de 8728
# Processando instância 17740 de 8728
# Processando instância 17750 de 8728
# Processando instância 17760 de 8728
# Processando instância 17770 de 8728
# Processando instância 17780 de 8728
# Processando instância 17790 de 8728
# Processando instância 17800 de 8728
# Processando instância 17810 de 8728
# Processando instância 17820 de 8728
# Processando instância 17830 de 8728
# Processando instância 17840 de 8728
# Processando instância 17850 de 8728
# Processando instância 17860 de 8728
# Processando instância 17870 de 8728
# Processando instância 17880 de 8728
# Processando instância 17890 de 8728
# Processando instância 17900 de 8728
# Processando instância 17910 de 8728
# Processando instância 17920 de 8728
# Processando instância 17930 de 8728
# Processando instância 17940 de 8728
# Processando instância 17950 de 8728
# Processando instância 17960 de 8728
# Processando instância 17970 de 8728
# Processando instância 17980 de 8728
# Processando instância 17990 de 8728
# Processando instância 18000 de 8728
# Processando instância 18010 de 8728
# Processando instância 18020 de 8728
# Processando instância 18030 de 8728
# Processando instância 18040 de 8728
# Processando instância 18050 de 8728
# Processando instância 18060 de 8728
# Processando instância 18070 de 8728
# Processando instância 18080 de 8728
# Processando instância 18090 de 8728
# Processando instância 18100 de 8728
# Processando instância 18110 de 8728
# Processando instância 18120 de 8728
# Processando instância 18130 de 8728
# Processando instância 18140 de 8728
# Processando instância 18150 de 8728
# Processando instância 18160 de 8728
# Processando instância 18170 de 8728
# Processando instância 18180 de 8728
# Processando instância 18190 de 8728
# Processando instância 18200 de 8728
# Processando instância 18210 de 8728
# Processando instância 18220 de 8728
# Processando instância 18230 de 8728
# Processando instância 18240 de 8728
# Processando instância 18250 de 8728
# Processando instância 18260 de 8728
# Processando instância 18270 de 8728
# Processando instância 18280 de 8728
# Processando instância 18290 de 8728
# Processando instância 18300 de 8728
# Processando instância 18310 de 8728
# Processando instância 18320 de 8728
# Processando instância 18330 de 8728
# Processando instância 18340 de 8728
# Processando instância 18350 de 8728
# Processando instância 18360 de 8728
# Processando instância 18370 de 8728
# Processando instância 18380 de 8728
# Processando instância 18390 de 8728
# Processando instância 18400 de 8728
# Processando instância 18410 de 8728
# Processando instância 18420 de 8728
# Processando instância 18430 de 8728
# Processando instância 18440 de 8728
# Processando instância 18450 de 8728
# Processando instância 18460 de 8728
# Processando instância 18470 de 8728
# Processando instância 18480 de 8728
# Processando instância 18490 de 8728
# Processando instância 18500 de 8728
# Processando instância 18510 de 8728
# Processando instância 18520 de 8728
# Processando instância 18530 de 8728
# Processando instância 18540 de 8728
# Processando instância 18550 de 8728
# Processando instância 18560 de 8728
# Processando instância 18570 de 8728
# Processando instância 18580 de 8728
# Processando instância 18590 de 8728
# Processando instância 18600 de 8728
# Processando instância 18610 de 8728
# Processando instância 18620 de 8728
# Processando instância 18630 de 8728
# Processando instância 18640 de 8728
# Processando instância 18650 de 8728
# Processando instância 18660 de 8728
# Processando instância 18670 de 8728
# Processando instância 18680 de 8728
# Processando instância 18690 de 8728
# Processando instância 18700 de 8728
# Processando instância 18710 de 8728
# Processando instância 18720 de 8728
# Processando instância 18730 de 8728
# Processando instância 18740 de 8728
# Processando instância 18750 de 8728
# Processando instância 18760 de 8728
# Processando instância 18770 de 8728
# Processando instância 18780 de 8728
# Processando instância 18790 de 8728
# Processando instância 18800 de 8728
# Processando instância 18810 de 8728
# Processando instância 18820 de 8728
# Processando instância 18830 de 8728
# Processando instância 18840 de 8728
# Processando instância 18850 de 8728
# Processando instância 18860 de 8728
# Processando instância 23980 de 8728
# Processando instância 23990 de 8728
# Processando instância 24000 de 8728
# Processando instância 24010 de 8728
# Processando instância 24020 de 8728
# Processando instância 24030 de 8728
# Processando instância 24040 de 8728
# Processando instância 24050 de 8728
# Processando instância 24060 de 8728
# Processando instância 24070 de 8728
# Processando instância 24080 de 8728
# Processando instância 24090 de 8728
# Processando instância 24100 de 8728
# Processando instância 24110 de 8728
# Processando instância 24120 de 8728
# Processando instância 24130 de 8728
# Processando instância 24140 de 8728
# Processando instância 24150 de 8728
# Processando instância 24160 de 8728
# Processando instância 24170 de 8728
# Processando instância 24180 de 8728
# Processando instância 24190 de 8728
# Processando instância 24200 de 8728
# Processando instância 24210 de 8728
# Processando instância 24220 de 8728
# Processando instância 24230 de 8728
# Processando instância 24240 de 8728
# Processando instância 24250 de 8728
# Processando instância 24260 de 8728
# Processando instância 24270 de 8728
# Processando instância 24280 de 8728
# Processando instância 24290 de 8728
# Processando instância 24300 de 8728
# Processando instância 24310 de 8728
# Processando instância 24320 de 8728
# Processando instância 24330 de 8728
# Processando instância 24340 de 8728
# Processando instância 24350 de 8728
# Processando instância 24360 de 8728
# Processando instância 24370 de 8728
# Processando instância 24380 de 8728
# Processando instância 24390 de 8728
# Processando instância 24400 de 8728
# Processando instância 24410 de 8728
# Processando instância 24420 de 8728
# Processando instância 24430 de 8728
# Processando instância 24440 de 8728
# Processando instância 24450 de 8728
# Processando instância 24460 de 8728
# Processando instância 24470 de 8728
# Processando instância 24480 de 8728
# Processando instância 24490 de 8728
# Processando instância 24500 de 8728
# Processando instância 24510 de 8728
# Processando instância 24520 de 8728
# Processando instância 24530 de 8728
# Processando instância 24540 de 8728
# Processando instância 24550 de 8728
# Processando instância 24560 de 8728
# Processando instância 24570 de 8728
# Processando instância 24580 de 8728
# Processando instância 24590 de 8728
# Processando instância 24600 de 8728
# Processando instância 24610 de 8728
# Processando instância 24620 de 8728
# Processando instância 24630 de 8728
# Processando instância 24640 de 8728
# Processando instância 24650 de 8728
# Processando instância 24660 de 8728
# Processando instância 24670 de 8728
# Processando instância 24680 de 8728
# Processando instância 24690 de 8728
# Processando instância 24700 de 8728
# Processando instância 24710 de 8728
# Processando instância 24720 de 8728
# Processando instância 24730 de 8728
# Processando instância 24740 de 8728
# Processando instância 24750 de 8728
# Processando instância 24760 de 8728
# Processando instância 24770 de 8728
# Processando instância 24780 de 8728
# Processando instância 24790 de 8728
# Processando instância 24800 de 8728
# Processando instância 24810 de 8728
# Processando instância 24820 de 8728
# Processando instância 24830 de 8728
# Processando instância 24840 de 8728
# Processando instância 24850 de 8728
# Processando instância 24860 de 8728
# Processando instância 24870 de 8728
# Processando instância 24880 de 8728
# Processando instância 24890 de 8728
# Processando instância 24900 de 8728
# Processando instância 24910 de 8728
# Processando instância 24920 de 8728
# Processando instância 24930 de 8728
# Processando instância 24940 de 8728
# Processando instância 29680 de 8728
# Processando instância 29690 de 8728
# Processando instância 29700 de 8728
# Processando instância 29710 de 8728
# Processando instância 29720 de 8728
# Processando instância 29730 de 8728
# Processando instância 29740 de 8728
# Processando instância 29750 de 8728
# Processando instância 29760 de 8728
# Processando instância 29770 de 8728
# Processando instância 29780 de 8728
# Processando instância 29790 de 8728
# Processando instância 29800 de 8728
# Processando instância 29810 de 8728
# Processando instância 29820 de 8728
# Processando instância 29830 de 8728
# Processando instância 29840 de 8728
# Processando instância 29850 de 8728
# Processando instância 29860 de 8728
# Processando instância 29870 de 8728
# Processando instância 29880 de 8728
# Processando instância 29890 de 8728
# Processando instância 29900 de 8728
# Processando instância 29910 de 8728
# Processando instância 29920 de 8728
# Processando instância 29930 de 8728
# Processando instância 29940 de 8728
# Processando instância 29950 de 8728
# Processando instância 29960 de 8728
# Processando instância 29970 de 8728
# Processando instância 29980 de 8728
# Processando instância 29990 de 8728
# Processando instância 30000 de 8728
# Processando instância 30010 de 8728
# Processando instância 30020 de 8728
# Processando instância 30030 de 8728
# Processando instância 30040 de 8728
# Processando instância 30050 de 8728
# Processando instância 30060 de 8728
# Processando instância 30070 de 8728
# Processando instância 30080 de 8728
# Processando instância 30090 de 8728
# Processando instância 30100 de 8728
# Processando instância 30110 de 8728
# Processando instância 30120 de 8728
# Processando instância 30130 de 8728
# Processando instância 30140 de 8728
# Processando instância 30150 de 8728
# Processando instância 30160 de 8728
# Processando instância 30170 de 8728
# Processando instância 30180 de 8728
# Processando instância 30190 de 8728
# Processando instância 30200 de 8728
# Processando instância 30210 de 8728
# Processando instância 30220 de 8728
# Processando instância 30230 de 8728
# Processando instância 30240 de 8728
# Processando instância 30250 de 8728
# Processando instância 30260 de 8728
# Processando instância 30270 de 8728
# Processando instância 30280 de 8728
# Processando instância 30290 de 8728
# Processando instância 30300 de 8728
# Processando instância 30310 de 8728
# Processando instância 30320 de 8728
# Processando instância 30330 de 8728
# Processando instância 30340 de 8728
# Processando instância 30350 de 8728
# Processando instância 30360 de 8728
# Processando instância 30370 de 8728
# Processando instância 30380 de 8728
# Processando instância 30390 de 8728
# Processando instância 30400 de 8728
# Processando instância 30410 de 8728
# Processando instância 30420 de 8728
# Processando instância 30430 de 8728
# Processando instância 30440 de 8728
# Processando instância 30450 de 8728
# Processando instância 30460 de 8728
# Processando instância 30470 de 8728
# Processando instância 30480 de 8728
# Processando instância 30490 de 8728
# Processando instância 30500 de 8728
# Processando instância 30510 de 8728
# Processando instância 30520 de 8728
# Processando instância 30530 de 8728
# Processando instância 30540 de 8728
# Processando instância 30550 de 8728
# Processando instância 30560 de 8728
# Processando instância 30570 de 8728
# Processando instância 30580 de 8728
# Processando instância 30590 de 8728
# Processando instância 30600 de 8728
# Processando instância 30610 de 8728
# Processando instância 30620 de 8728
# Processando instância 30630 de 8728
# Processando instância 30640 de 8728
# Processando instância 30650 de 8728
# Processando instância 30660 de 8728
# Processando instância 30670 de 8728
# Processando instância 30680 de 8728
# Processando instância 30690 de 8728
# Processando instância 30700 de 8728
# Processando instância 30710 de 8728
# Processando instância 30720 de 8728
# Processando instância 30730 de 8728
# Processando instância 30740 de 8728
# Processando instância 30750 de 8728
# Processando instância 30760 de 8728
# Processando instância 30770 de 8728
# Processando instância 30780 de 8728
# Processando instância 30790 de 8728
# Processando instância 30800 de 8728
# Processando instância 30810 de 8728
# Processando instância 30820 de 8728
# Processando instância 30830 de 8728
# Processando instância 30840 de 8728
# Processando instância 30850 de 8728
# Processando instância 30860 de 8728
# Processando instância 30870 de 8728
# Processando instância 30880 de 8728
# Processando instância 30890 de 8728
# Processando instância 30900 de 8728
# Processando instância 30910 de 8728
# Processando instância 30920 de 8728
# Processando instância 30930 de 8728
# Processando instância 30940 de 8728
# Processando instância 30950 de 8728
# Processando instância 30960 de 8728
# Processando instância 30970 de 8728
# Processando instância 30980 de 8728
# Processando instância 30990 de 8728
# Processando instância 35950 de 8728
# Processando instância 35960 de 8728
# Processando instância 35970 de 8728
# Processando instância 35980 de 8728
# Processando instância 35990 de 8728
# Processando instância 36000 de 8728
# Processando instância 36010 de 8728
# Processando instância 36020 de 8728
# Processando instância 36030 de 8728
# Processando instância 36040 de 8728
# Processando instância 36050 de 8728
# Processando instância 36060 de 8728
# Processando instância 36070 de 8728
# Processando instância 36080 de 8728
# Processando instância 36090 de 8728
# Processando instância 36100 de 8728
# Processando instância 36110 de 8728
# Processando instância 36120 de 8728
# Processando instância 36130 de 8728
# Processando instância 36140 de 8728
# Processando instância 36150 de 8728
# Processando instância 36160 de 8728
# Processando instância 36170 de 8728
# Processando instância 36180 de 8728
# Processando instância 36190 de 8728
# Processando instância 36200 de 8728
# Processando instância 36210 de 8728
# Processando instância 36220 de 8728
# Processando instância 36230 de 8728
# Processando instância 36240 de 8728
# Processando instância 36250 de 8728
# Processando instância 36260 de 8728
# Processando instância 36270 de 8728
# Processando instância 36280 de 8728
# Processando instância 36290 de 8728
# Processando instância 36300 de 8728
# Processando instância 36310 de 8728
# Processando instância 36320 de 8728
# Processando instância 36330 de 8728
# Processando instância 36340 de 8728
# Processando instância 36350 de 8728
# Processando instância 36360 de 8728
# Processando instância 36370 de 8728
# Processando instância 36380 de 8728
# Processando instância 36390 de 8728
# Processando instância 36400 de 8728
# Processando instância 36410 de 8728
# Processando instância 36420 de 8728
# Processando instância 36430 de 8728
# Processando instância 36440 de 8728
# Processando instância 36450 de 8728
# Processando instância 36460 de 8728
# Processando instância 36470 de 8728
# Processando instância 36480 de 8728
# Processando instância 36490 de 8728
# Processando instância 36500 de 8728
# Processando instância 36510 de 8728
# Processando instância 36520 de 8728
# Processando instância 36530 de 8728
# Processando instância 36540 de 8728
# Processando instância 36550 de 8728
# Processando instância 36560 de 8728
# Processando instância 36570 de 8728
# Processando instância 36580 de 8728
# Processando instância 36590 de 8728
# Processando instância 36600 de 8728
# Processando instância 36610 de 8728
# Processando instância 36620 de 8728
# Processando instância 36630 de 8728
# Processando instância 36640 de 8728
# Processando instância 36650 de 8728
# Processando instância 36660 de 8728
# Processando instância 36670 de 8728
# Processando instância 36680 de 8728
# Processando instância 36690 de 8728
# Processando instância 36700 de 8728
# Processando instância 36710 de 8728
# Processando instância 36720 de 8728
# Processando instância 36730 de 8728
# Processando instância 36740 de 8728
# Processando instância 36750 de 8728
# Processando instância 36760 de 8728
# Processando instância 36770 de 8728
# Processando instância 36780 de 8728
# Processando instância 36790 de 8728
# Processando instância 36800 de 8728
# Processando instância 36810 de 8728
# Processando instância 36820 de 8728
# Processando instância 36830 de 8728
# Processando instância 36840 de 8728
# Processando instância 36850 de 8728
# Processando instância 36860 de 8728
# Processando instância 36870 de 8728
# Processando instância 36880 de 8728
# Processando instância 36890 de 8728
# Processando instância 36900 de 8728
# Processando instância 36910 de 8728
# Processando instância 36920 de 8728
# Processando instância 36930 de 8728
# Processando instância 36940 de 8728
# Processando instância 36950 de 8728
# Processando instância 36960 de 8728
# Processando instância 36970 de 8728
# Processando instância 36980 de 8728
# Processando instância 36990 de 8728
# Processando instância 37000 de 8728
# Processando instância 37010 de 8728
# Processando instância 37020 de 8728
# Processando instância 37030 de 8728
# Processando instância 37040 de 8728
# Processando instância 39030 de 8728
# Processando instância 39040 de 8728
# Processando instância 39050 de 8728
# Processando instância 39060 de 8728
# Processando instância 39070 de 8728
# Processando instância 39080 de 8728
# Processando instância 39090 de 8728
# Processando instância 39100 de 8728
# Processando instância 39110 de 8728
# Processando instância 39120 de 8728
# Processando instância 39130 de 8728
# Processando instância 39140 de 8728
# Processando instância 39150 de 8728
# Processando instância 39160 de 8728
# Processando instância 39170 de 8728
# Processando instância 39180 de 8728
# Processando instância 39190 de 8728
# Processando instância 39200 de 8728
# Processando instância 39210 de 8728
# Processando instância 39220 de 8728
# Processando instância 39230 de 8728
# Processando instância 39240 de 8728
# Processando instância 39250 de 8728
# Processando instância 39260 de 8728
# Processando instância 39270 de 8728
# Processando instância 39280 de 8728
# Processando instância 39290 de 8728
# Processando instância 39300 de 8728
# Processando instância 39310 de 8728
# Processando instância 39320 de 8728
# Processando instância 39330 de 8728
# Processando instância 39340 de 8728
# Processando instância 39350 de 8728
# Processando instância 39360 de 8728
# Processando instância 39370 de 8728
# Processando instância 39380 de 8728
# Processando instância 39390 de 8728
# Processando instância 39400 de 8728
# Processando instância 39410 de 8728
# Processando instância 39420 de 8728
# Processando instância 39430 de 8728
# Processando instância 39440 de 8728
# Processando instância 39450 de 8728
# Processando instância 39460 de 8728
# Processando instância 39470 de 8728
# Processando instância 39480 de 8728
# Processando instância 39490 de 8728
# Processando instância 39500 de 8728
# Processando instância 39510 de 8728
# Processando instância 39520 de 8728
# Processando instância 39530 de 8728
# Processando instância 39540 de 8728
# Processando instância 39550 de 8728
# Processando instância 39560 de 8728
# Processando instância 39570 de 8728
# Processando instância 39580 de 8728
# Processando instância 39590 de 8728
# Processando instância 39600 de 8728
# Processando instância 39610 de 8728
# Processando instância 39620 de 8728
# Processando instância 39630 de 8728
# Processando instância 39640 de 8728
# Processando instância 39650 de 8728
# Processando instância 39660 de 8728
# Processando instância 39670 de 8728
# Processando instância 39680 de 8728
# Processando instância 39690 de 8728
# Processando instância 39700 de 8728
# Processando instância 39710 de 8728
# Processando instância 39720 de 8728
# Processando instância 39730 de 8728
# Processando instância 39740 de 8728
# Processando instância 39750 de 8728
# Processando instância 39760 de 8728
# Processando instância 39770 de 8728
# Processando instância 39780 de 8728
# Processando instância 39790 de 8728
# Processando instância 39800 de 8728
# Processando instância 39810 de 8728
# Processando instância 39820 de 8728
# Processando instância 39830 de 8728
# Processando instância 39840 de 8728
# Processando instância 39850 de 8728
# Processando instância 39860 de 8728
# Processando instância 39870 de 8728
# Processando instância 39880 de 8728
# Processando instância 39890 de 8728
# Processando instância 39900 de 8728
# Processando instância 39910 de 8728
# Processando instância 39920 de 8728
# Processando instância 39930 de 8728
# Processando instância 39940 de 8728
# Processando instância 39950 de 8728
# Processando instância 39960 de 8728
# Processando instância 39970 de 8728
# Processando instância 39980 de 8728
# Processando instância 39990 de 8728
# Processando instância 40000 de 8728
# Processando instância 40010 de 8728
# Processando instância 40020 de 8728
# Processando instância 40030 de 8728
# Processando instância 40040 de 8728
# Processando instância 40050 de 8728
# Processando instância 40060 de 8728
# Processando instância 40070 de 8728
# Processando instância 40080 de 8728
# Processando instância 40090 de 8728
# Processando instância 40100 de 8728
# Processando instância 40110 de 8728
# Processando instância 40120 de 8728
# Processando instância 40130 de 8728
# Processando instância 40140 de 8728
# Processando instância 40150 de 8728
# Processando instância 40160 de 8728
# Processando instância 40170 de 8728

# %%
for e in errors:
    prompt_with_few_shot = generate_few_shot_ner_prompts(e['row']['texto_acordao'])
    result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
    all_decisions_2023.at[e['index'], 'ner_decisao'] = result
    resultados.append(result)

# %%
all_decisions_2023.to_pickle("dataset/all_decisions_2023_ner.pkl")

# %% [markdown]
# # Creating Obrigacao database in local sqlite

# %%
Base = declarative_base()
engine = create_engine(
    f"mssql+pymssql://{os.getenv("SQL_SERVER_USER")}:{os.getenv("SQL_SERVER_PASS")}@{os.getenv("SQL_SERVER_HOST")}/{os.getenv("SQL_SERVER_DB")}",
    echo=True
)
#engine = create_engine("sqlite:///dataset/sqlite/obrigacoes.db", echo=True)
SessionLocal = sessionmaker(bind=engine)

# %%
class ObrigacaoORM(Base):
    __tablename__ = "Obrigacao"

    IdObrigacao = Column(Integer, primary_key=True, index=True)
    IdProcesso = Column(Integer, nullable=False)
    IdComposicaoPauta = Column(Integer, nullable=False)
    IdVotoPauta = Column(Integer, nullable=False)
    DescricaoObrigacao = Column(Text, nullable=False)
    DeFazer = Column(Boolean, default=True)
    Prazo = Column(String, nullable=True)
    DataCumprimento = Column(Date, nullable=True)
    OrgaoResponsavel = Column(String, nullable=True)
    IdOrgaoResponsavel = Column(Integer, nullable=True)
    TemMultaCominatoria = Column(Boolean, default=False)
    NomeResponsavelMultaCominatoria = Column(String, nullable=True)
    DocumentoResponsavelMultaCominatoria = Column(String, nullable=True)
    IdPessoaMultaCominatoria = Column(Integer, nullable=True)
    ValorMultaCominatoria = Column(Float, nullable=True)
    PeriodoMultaCominatoria = Column(String, nullable=True)
    EMultaCominatoriaSolidaria = Column(Boolean, default=False)
    SolidariosMultaCominatoria = Column(JSON, nullable=True)

# %%
class RecomendacaoORM(Base):
    __tablename__ = "Recomendacao"

    IdRecomendacao = Column(Integer, primary_key=True, index=True)
    IdProcesso = Column(Integer, nullable=False)
    IdComposicaoPauta = Column(Integer, nullable=False)
    IdVotoPauta = Column(Integer, nullable=False)
    DescricaoRecomendacao = Column(Text, nullable=True)
    PrazoCumprimentoRecomendacao = Column(String, nullable=True)
    DataCumprimentoRecomendacao = Column(Date, nullable=True)
    NomeResponsavel = Column(String, nullable=True)
    IdPessoaResponsavel = Column(Integer, nullable=True)
    OrgaoResponsavel = Column(String, nullable=True)
    IdOrgaoResponsavel = Column(Integer, nullable=True)

    def __repr__(self):
        return f"<Recomendacao(IdRecomendacao={self.IdRecomendacao}, descricao_recomendacao='{self.descricao_recomendacao[:30]}...')>"

# %%
#Base.metadata.drop_all(bind=engine)
Base.metadata.create_all(bind=engine)
# Out:
# 2025-07-27 16:37:03,274 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:37:03,274 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(%(table_type_1)s AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(%(table_type_2)s AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(%(table_name_1)s AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(%(table_schema_1)s AS NVARCHAR(max))
# 2025-07-27 16:37:03,275 INFO sqlalchemy.engine.Engine [cached since 10.51s ago] {'table_type_1': 'BASE TABLE', 'table_type_2': 'VIEW', 'table_name_1': 'Obrigacao', 'table_schema_1': 'dbo'}
# 2025-07-27 16:37:03,313 INFO sqlalchemy.engine.Engine
# CREATE TABLE [Obrigacao] (
# 	[IdObrigacao] INTEGER NOT NULL IDENTITY,
# 	[IdProcesso] INTEGER NOT NULL,
# 	[IdComposicaoPauta] INTEGER NOT NULL,
# 	[IdVotoPauta] INTEGER NOT NULL,
# 	[DescricaoObrigacao] VARCHAR(max) NOT NULL,
# 	[DeFazer] BIT NULL,
# 	[Prazo] VARCHAR(max) NULL,
# 	[DataCumprimento] DATE NULL,
# 	[OrgaoResponsavel] VARCHAR(max) NULL,
# 	[IdOrgaoResponsavel] INTEGER NULL,
# 	[TemMultaCominatoria] BIT NULL,
# 	[NomeResponsavelMultaCominatoria] VARCHAR(max) NULL,
# 	[DocumentoResponsavelMultaCominatoria] VARCHAR(max) NULL,
# 	[IdPessoaMultaCominatoria] INTEGER NULL,
# 	[ValorMultaCominatoria] FLOAT NULL,
# 	[PeriodoMultaCominatoria] VARCHAR(max) NULL,
# 	[EMultaCominatoriaSolidaria] BIT NULL,
# 	[SolidariosMultaCominatoria] NVARCHAR(max) NULL,
# 	PRIMARY KEY ([IdObrigacao])
# )
#
#
# 2025-07-27 16:37:03,313 INFO sqlalchemy.engine.Engine [no key 0.00038s] {}
# 2025-07-27 16:37:03,390 INFO sqlalchemy.engine.Engine CREATE INDEX [ix_Obrigacao_IdObrigacao] ON [Obrigacao] ([IdObrigacao])
# 2025-07-27 16:37:03,391 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2025-07-27 16:37:03,430 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # Extracting Obrigacoes using GPT4 Turbo

# %%
decisoes_json = json.load(open("dataset/decisoes_raw_2020_062025.json", "r", encoding="utf-8"))

# %%
def find_obrigacao_by_descricao(df_ob, descricao):
    return [i for i,r in df_ob.iterrows() if descricao in r['obrigacoes'][0].descricao_obrigacao][0]

def get_id_pessoa_multa_cominatoria(row, result_obrigacao):
    """
    Obtém o ID da pessoa responsável pela multa cominatória.
    """
    if result_obrigacao.documento_responsavel_multa_cominatoria:
        return [p['id_pessoa'] for p in row['responsaveis'] if p['documento_responsavel'] == result_obrigacao.documento_responsavel_multa_cominatoria][0]
    return None

def get_pessoas_str(pessoas):    
    pessoas_str = []
    for pessoa in pessoas:
        nome = pessoa.get('nome_responsavel', 'Desconhecido')
        documento = pessoa.get('documento_responsavel', 'Desconhecido')
        tipo = pessoa.get('tipo_responsavel', 'Desconhecido')
        if tipo == 'F':
            tipo = 'Física'
        elif tipo == 'J':
            tipo = 'Jurídica'
        pessoas_str.append(f"{nome} ({tipo} - {documento})")
    
    return ", ".join(pessoas_str)

def get_prompt_obrigacao(row, obrigacao):
    data_sessao = row['data_sessao']
    texto_acordao = row['texto_acordao']
    orgao_responsavel = row['orgao_responsavel']
    pessoas_responsaveis = row['responsaveis']


    return f"""
    Você é um Auditor de Controle Externo do TCE/RN. Sua tarefa é analisar o voto e extrair a obrigação imposta, preenchendo os campos do objeto Obrigacao.

    Data da Sessão: {data_sessao.strftime('%d/%m/%Y')}
    Obrigação detectada: {obrigacao.descricao_obrigacao}
    Texto do Acordão: {texto_acordao}
    Órgão Responsável: {orgao_responsavel}
    Pessoas Responsáveis: {get_pessoas_str(pessoas_responsaveis)}

    Dado esse contexto, preencha os campos da seguinte forma:
    - descricao_obrigacao: Descrição da obrigação imposta.
    - tipo: Tipo da obrigação (fazer/não fazer).
    - prazo: Prazo estipulado para cumprimento. Extraia o texto indicando o prazo, se houver. Exemplo: "90 dias".
    - data_cumprimento: Extraia do prazo do acórdão como data de início e faça o cálculo da data de cumprimento. Exemplo: 2025-09-13
    - orgao_responsavel: Órgão responsável pelo cumprimento da obrigação. Pessoa jurídica.
    - tem_multa_cominatoria: Indique se há multa cominatória associada à obrigação.
    - nome_responsavel_multa_cominatoria: Nome do responsável pela obrigação, se houver multa cominatória. Pessoa física responsável.
    - documento_responsavel_multa_cominatoria: Documento do responsável pela obrigação, se houver multa cominatória.
    - valor_multa_cominatoria: Se houver multa cominatória, preencha o valor.
    - periodo_multa_cominatoria: Período da multa cominatória, se houver.
    - e_multa_cominatoria_solidaria: Indique se a multa cominatória é solidária.
    - solidarios_multa_cominatoria: Lista de responsáveis solidários da multa cominatória.

    Use somente as informações do texto do acórdão e dos dados fornecidos. Não inclua informações adicionais ou suposições.
    Se o órgão responsável não estiver disponível, preencha o campo orgão_responsavel com "Desconhecido".
    """

def extract_obrigacao(row, obrigacao):
    prompt_obrigacao = get_prompt_obrigacao(row, obrigacao)
    return extractor_obrigacao_gpt4turbo.invoke(prompt_obrigacao)

def insert_obrigacao(db_session, obrigacao: Obrigacao, row):
    orm_obj = ObrigacaoORM(
        IdProcesso=safe_int(row['id_processo']),
        IdComposicaoPauta=safe_int(row['id_composicao_pauta']),
        IdVotoPauta=safe_int(row['id_voto_pauta']),
        DescricaoObrigacao=obrigacao.descricao_obrigacao,
        DeFazer=obrigacao.de_fazer,
        Prazo=obrigacao.prazo,
        DataCumprimento=obrigacao.data_cumprimento,
        OrgaoResponsavel=obrigacao.orgao_responsavel,
        IdOrgaoResponsavel=safe_int(row['id_orgao_responsavel']),
        TemMultaCominatoria=obrigacao.tem_multa_cominatoria,
        NomeResponsavelMultaCominatoria=obrigacao.nome_responsavel_multa_cominatoria,
        DocumentoResponsavelMultaCominatoria=obrigacao.documento_responsavel_multa_cominatoria,
        IdPessoaMultaCominatoria=get_id_pessoa_multa_cominatoria(row, obrigacao),
        ValorMultaCominatoria=obrigacao.valor_multa_cominatoria,
        PeriodoMultaCominatoria=obrigacao.periodo_multa_cominatoria,
        EMultaCominatoriaSolidaria=obrigacao.e_multa_cominatoria_solidaria,
        SolidariosMultaCominatoria=obrigacao.solidarios_multa_cominatoria
    )
    db_session.add(orm_obj)
    db_session.commit()
    return orm_obj

# %%
keys = [k for k in decisoes_json.keys()]
decisoes = decisoes_json[keys[0]]
df_decisoes_raw = pd.DataFrame(decisoes)

df_decisoes_raw.columns = [c.lower() for c in df_decisoes_raw.columns]

all_ner = pd.read_pickle("dataset/all_decisions_2023_ner.pkl")
all_ner['idvotopauta'] = all_ner['idvotopauta'].astype(str).str.replace('.0', '')
obrigacoes = [(d.idcomposicaopauta, d.idvoto, d.idvotopauta, d['ner_decisao'].obrigacoes) for _,d in all_ner.iterrows() if d['ner_decisao'].obrigacoes != []]
df_ob = pd.DataFrame(obrigacoes, columns=['id_composicao_pauta', 'id_voto', 'id_voto_pauta', 'obrigacoes'])
df_ob['id_voto_pauta'] = df_ob['id_voto_pauta'].astype('int64')

# %%
group_cols = [
        'id_processo', 'numero_processo', 'ano_processo', 'id_composicao_pauta', 
        'id_voto_pauta', 'numero_sessao', 'ano_sessao', 'data_sessao', 'relatorio',
        'fundamentacao_voto', 'conclusao', 'texto_acordao', 'orgao_responsavel', 'id_orgao_responsavel',
]

# Define as colunas para criar o dicionário de pessoas
person_cols = ['nome_responsavel', 'documento_responsavel', 'tipo_responsavel', 'id_pessoa']

# Agrupa o DataFrame e aplica uma função lambda para criar a lista de dicionários
df_decisoes = df_decisoes_raw.groupby(group_cols, dropna=False).apply(
    lambda x: pd.Series({'responsaveis': x[person_cols].apply(
        lambda y: y.dropna().to_dict(), axis=1
    ).tolist()})
).reset_index()


df_ob = df_ob[['id_composicao_pauta', 'id_voto_pauta', 'obrigacoes']].merge(df_decisoes, on=['id_composicao_pauta', 'id_voto_pauta'], how='left')
df_ob['data_sessao'] = pd.to_datetime(df_ob['data_sessao'], errors='coerce')
df_ob['n_obrigacoes'] = df_ob['obrigacoes'].apply(lambda x: len(x) if isinstance(x, list) else 0)
# Out:
# /var/folders/39/p0t9g2qn1gbcvnwqyz79d34c0000gn/T/ipykernel_1200/3350572719.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decisoes = df_decisoes_raw.groupby(group_cols, dropna=False).apply(

# %%
errors = []
k = 0
for _, row in df_ob.iterrows():
    k += 1
    if k % 10 == 0 and k > 0:
        print(f"Processando instância {k} de {len(df_ob)}")

    for obrigacao in row['obrigacoes']:
        try:
            result_obrigacao = extract_obrigacao(row, obrigacao)
            db_session = SessionLocal()
            insert_obrigacao(db_session, result_obrigacao, row)
            db_session.close()
        except Exception as e:
            print(f"Erro ao processar obrigação: {e}")
            errors.append((row['id_processo'], obrigacao, str(e)))
# Out:
# 2025-07-27 16:39:07,877 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:07,879 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:07,879 INFO sqlalchemy.engine.Engine [generated in 0.00053s] {'IdProcesso': 375519, 'IdComposicaoPauta': 106841, 'IdVotoPauta': 33811, 'DescricaoObrigacao': 'notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:07,940 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:18,648 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:18,650 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:18,651 INFO sqlalchemy.engine.Engine [cached since 10.77s ago] {'IdProcesso': 564793, 'IdComposicaoPauta': 107122, 'IdVotoPauta': 33493, 'DescricaoObrigacao': 'Atualizar as informações necessárias ao SIAI-análise, notadamente o anexo 38, relativamente aos dados do Processo Licitatório - Concorrência nº 01/20 ... (50 characters truncated) ... mentação relativa às fases já executadas, e proceder da mesma forma em relação a todos os processos licitatórios e contratações celebradas pelo ente.', 'DeFazer': 1, 'Prazo': '15 dias úteis', 'DataCumprimento': datetime.datetime(2023, 2, 14, 0, 0), 'OrgaoResponsavel': 'Consórcio Intermunicipal Multifinalitário Potiguar', 'IdOrgaoResponsavel': 1294, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Fernando Luiz Teixeira de Carvalho', 'DocumentoResponsavelMultaCominatoria': '47611278487', 'IdPessoaMultaCominatoria': 21905, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:18,733 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:25,542 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:25,543 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:25,544 INFO sqlalchemy.engine.Engine [cached since 17.67s ago] {'IdProcesso': 564793, 'IdComposicaoPauta': 107122, 'IdVotoPauta': 33493, 'DescricaoObrigacao': 'Atualizar as informações necessárias ao SIAI-análise, notadamente o anexo 38, relativamente aos dados do Processo Licitatório - Concorrência nº 01/20 ... (64 characters truncated) ... ão relativa às fases já executadas, devendo proceder da mesma forma em relação a todos os processos licitatórios e contratações celebradas pelo ente.', 'DeFazer': 1, 'Prazo': '15 dias úteis', 'DataCumprimento': datetime.datetime(2023, 2, 14, 0, 0), 'OrgaoResponsavel': 'CONSÓRCIO INTERMUNICIPAL MULTIFINALITARIO POTIGUAR', 'IdOrgaoResponsavel': 1294, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Fernando Luiz Teixeira de Carvalho', 'DocumentoResponsavelMultaCominatoria': '47611278487', 'IdPessoaMultaCominatoria': 21905, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:25,623 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:29,745 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:29,746 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:29,748 INFO sqlalchemy.engine.Engine [cached since 21.87s ago] {'IdProcesso': 541083, 'IdComposicaoPauta': 112916, 'IdVotoPauta': 37873, 'DescricaoObrigacao': 'Regularizar a situação noticiada nos autos, corrigindo o ato aposentador, a apostila de cálculo e a implantação dos proventos, no sentido de excluir as citadas vantagens transitórias.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RN - IPERN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:29,833 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:33,707 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:33,708 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:33,708 INFO sqlalchemy.engine.Engine [cached since 25.83s ago] {'IdProcesso': 408739, 'IdComposicaoPauta': 112917, 'IdVotoPauta': 37874, 'DescricaoObrigacao': 'RENOVAÇÃO DA DETERMINAÇÃO para que o IPERN, no seu atual gestor, regularize a situação noticiada nos autos.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RN', 'IdOrgaoResponsavel': 521, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Nereu Batista Linhares', 'DocumentoResponsavelMultaCominatoria': '13006444434', 'IdPessoaMultaCominatoria': 11672, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:33,799 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:39,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:39,053 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:39,054 INFO sqlalchemy.engine.Engine [cached since 31.18s ago] {'IdProcesso': 512738, 'IdComposicaoPauta': 113124, 'IdVotoPauta': 38047, 'DescricaoObrigacao': 'Providenciar, no prazo de 30 (trinta) dias úteis, a alimentação das informações necessárias no Portal da Transparência, incluindo a divulgação da Lista de Exigibilidades por Ordem Cronológica de Pagamentos, atinentes ao exercício de 2019.', 'DeFazer': 1, 'Prazo': '30 dias úteis', 'DataCumprimento': datetime.datetime(2024, 3, 4, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE BOM JESUS', 'IdOrgaoResponsavel': 351, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'CLÉCIO DA CÂMARA AZEVEDO', 'DocumentoResponsavelMultaCominatoria': '30806062487', 'IdPessoaMultaCominatoria': 3771, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:39,126 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:43,440 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:43,441 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:43,442 INFO sqlalchemy.engine.Engine [cached since 35.56s ago] {'IdProcesso': 481787, 'IdComposicaoPauta': 113129, 'IdVotoPauta': 37892, 'DescricaoObrigacao': 'NOTIFICAÇÃO do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, na pessoa de seu atual gestor, para que, em havendo processo ... (40 characters truncated) ... nteressada, providencie a sua remessa no prazo de 60 (sessenta) dias, em atenção ao disposto no art. 96, IV da Lei Complementar Estadual nº 464/2012.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:43,524 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:48,884 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:48,887 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:48,888 INFO sqlalchemy.engine.Engine [cached since 41.01s ago] {'IdProcesso': 449448, 'IdComposicaoPauta': 113130, 'IdVotoPauta': 37891, 'DescricaoObrigacao': 'NOTIFICAÇÃO do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, na pessoa de seu atual gestor, para que, em havendo processo ... (40 characters truncated) ... nteressada, providencie a sua remessa no prazo de 60 (sessenta) dias, em atenção ao disposto no art. 96, IV da Lei Complementar Estadual nº 464/2012.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:48,955 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:53,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:53,508 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:53,509 INFO sqlalchemy.engine.Engine [cached since 45.63s ago] {'IdProcesso': 455206, 'IdComposicaoPauta': 113131, 'IdVotoPauta': 37837, 'DescricaoObrigacao': 'NOTIFICAÇÃO do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, na pessoa de seu atual gestor, para que, em havendo processo ... (40 characters truncated) ... nteressada, providencie a sua remessa no prazo de 60 (sessenta) dias, em atenção ao disposto no art. 96, IV da Lei Complementar Estadual nº 464/2012.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RN - IPERN', 'IdOrgaoResponsavel': 521, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:53,577 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:39:57,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:39:57,669 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:39:57,670 INFO sqlalchemy.engine.Engine [cached since 49.79s ago] {'IdProcesso': 458873, 'IdComposicaoPauta': 113132, 'IdVotoPauta': 38050, 'DescricaoObrigacao': 'NOTIFICAÇÃO do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, na pessoa de seu atual gestor, para que, em havendo processo ... (40 characters truncated) ... nteressada, providencie a sua remessa no prazo de 60 (sessenta) dias, em atenção ao disposto no art. 96, IV da Lei Complementar Estadual nº 464/2012.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'SECRETARIA DE ESTADO DA ADMINISTRAÇÃO', 'IdOrgaoResponsavel': 512, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:39:57,731 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 10 de 816
# 2025-07-27 16:40:03,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:03,230 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:03,231 INFO sqlalchemy.engine.Engine [cached since 55.35s ago] {'IdProcesso': 450074, 'IdComposicaoPauta': 113133, 'IdVotoPauta': 38045, 'DescricaoObrigacao': 'NOTIFICAÇÃO do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, na pessoa de seu atual gestor, para que, em havendo processo ... (40 characters truncated) ... nteressada, providencie a sua remessa no prazo de 60 (sessenta) dias, em atenção ao disposto no art. 96, IV da Lei Complementar Estadual nº 464/2012.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 23, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RN - IPERN', 'IdOrgaoResponsavel': 299, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:03,324 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:08,945 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:08,947 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:08,947 INFO sqlalchemy.engine.Engine [cached since 61.07s ago] {'IdProcesso': 505850, 'IdComposicaoPauta': 113161, 'IdVotoPauta': 38048, 'DescricaoObrigacao': 'assinatura do prazo de 18 (dezoito) meses, a contar da intimação desta decisão, ao município de São Bento do Norte-RN, e ao atual gestor, o Sr. João  ... (17 characters truncated) ...  para saneamento da infração continuada em discussão, sob pena de multa diária, a ambos, no valor de R$ 1.000,00, por cada contrato irregular mantido', 'DeFazer': 1, 'Prazo': '18 meses', 'DataCumprimento': datetime.datetime(2025, 7, 25, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SAO BENTO DO NORTE', 'IdOrgaoResponsavel': 455, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'João Maria Montenegro da Silva', 'DocumentoResponsavelMultaCominatoria': '48148750459', 'IdPessoaMultaCominatoria': 9734, 'ValorMultaCominatoria': 1000.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["Jo\\u00e3o Maria Montenegro da Silva"]'}
# 2025-07-27 16:40:09,023 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:14,910 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:14,912 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:14,912 INFO sqlalchemy.engine.Engine [cached since 67.03s ago] {'IdProcesso': 505850, 'IdComposicaoPauta': 113161, 'IdVotoPauta': 38048, 'DescricaoObrigacao': 'Apresentar um plano para enfrentamento e eliminação da irregularidade em questão, contendo cronograma que deve observar o prazo máximo fixado no item “b” para solução definitiva.', 'DeFazer': 1, 'Prazo': '60 dias', 'DataCumprimento': datetime.datetime(2024, 3, 26, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SAO BENTO DO NORTE', 'IdOrgaoResponsavel': 455, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'João Maria Montenegro da Silva', 'DocumentoResponsavelMultaCominatoria': '48148750459', 'IdPessoaMultaCominatoria': 9734, 'ValorMultaCominatoria': 1000.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["Jo\\u00e3o Maria Montenegro da Silva"]'}
# 2025-07-27 16:40:15,002 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:20,627 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:20,628 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:20,629 INFO sqlalchemy.engine.Engine [cached since 72.75s ago] {'IdProcesso': 505850, 'IdComposicaoPauta': 113161, 'IdVotoPauta': 38048, 'DescricaoObrigacao': 'Proibição ao Município São Bento do Norte-RN, e ao gestor responsável, o Sr. João Maria Montenegro, de realizarem novas contratações temporárias até o saneamento da irregularidade.', 'DeFazer': 0, 'Prazo': 'até o saneamento da irregularidade', 'DataCumprimento': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SAO BENTO DO NORTE', 'IdOrgaoResponsavel': 455, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'João Maria Montenegro da Silva', 'DocumentoResponsavelMultaCominatoria': '48148750459', 'IdPessoaMultaCominatoria': 9734, 'ValorMultaCominatoria': 1000.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 1, 'SolidariosMultaCominatoria': '["Jo\\u00e3o Maria Montenegro da Silva", "Claudio Henrique Gomes Pereira"]'}
# 2025-07-27 16:40:20,696 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:26,753 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:26,755 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:26,755 INFO sqlalchemy.engine.Engine [cached since 78.88s ago] {'IdProcesso': 485010, 'IdComposicaoPauta': 113221, 'IdVotoPauta': 38157, 'DescricaoObrigacao': 'Que o atual Prefeito do Município de Tibua do Sul instaure processos administrativos disciplinares individuais, que tenham por escopo a apuração da l ... (172 characters truncated) ...  de Oliveira, Cleidson Costa de Lima e Wellington de Oliveira Junior, sendo-lhes assegurado o contraditório, a ampla defesa e o devido processo legal', 'DeFazer': 1, 'Prazo': '120 dias úteis', 'DataCumprimento': datetime.datetime(2024, 7, 18, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TIBAU DO SUL', 'IdOrgaoResponsavel': 494, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Prefeitura Municipal de Tibau do Sul, por seu atual gerstor', 'DocumentoResponsavelMultaCominatoria': '08168775000182', 'IdPessoaMultaCominatoria': 12396, 'ValorMultaCominatoria': 500.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:26,829 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:31,903 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:31,904 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:31,904 INFO sqlalchemy.engine.Engine [cached since 84.03s ago] {'IdProcesso': 485010, 'IdComposicaoPauta': 113221, 'IdVotoPauta': 38157, 'DescricaoObrigacao': 'Que seja fixado o prazo de 120 (cento e vinte) dias úteis para a conclusão dos aludidos processos administrativos, devendo o gestor responsável, em até 5 (cinco) dias úteis, após a finalização do referido prazo, comunicar o TCE sobre a conclusão dos trabalhos e as providências adotadas.', 'DeFazer': 1, 'Prazo': '120 dias úteis', 'DataCumprimento': datetime.datetime(2024, 7, 3, 0, 0), 'OrgaoResponsavel': 'Prefeitura Municipal de Tibau do Sul', 'IdOrgaoResponsavel': 494, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Antonio Modesto Rodrigues de Macedo', 'DocumentoResponsavelMultaCominatoria': '29720435453', 'IdPessoaMultaCominatoria': 21573, 'ValorMultaCominatoria': 500.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:31,988 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:37,730 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:37,732 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:37,732 INFO sqlalchemy.engine.Engine [cached since 89.85s ago] {'IdProcesso': 550929, 'IdComposicaoPauta': 118524, 'IdVotoPauta': 42909, 'DescricaoObrigacao': 'obrigação de fazer para que o responsável pela PREFEITURA MUNICIPAL DE NATAL/RN comprove a deflagração de novo processo de contratação que tenha como objeto a gestão integrada dos resíduos sólidos do município de Natal, a ser conduzido pela própria URBANA ou pela Secretaria que entender pertinente', 'DeFazer': 1, 'Prazo': '60 dias corridos', 'DataCumprimento': datetime.datetime(2025, 3, 22, 0, 0), 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE NATAL', 'IdOrgaoResponsavel': 554, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Joseildes Medeiros da Silva', 'DocumentoResponsavelMultaCominatoria': '22127909453', 'IdPessoaMultaCominatoria': 61280, 'ValorMultaCominatoria': 1000.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:37,824 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:42,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:42,655 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:42,656 INFO sqlalchemy.engine.Engine [cached since 94.78s ago] {'IdProcesso': 550929, 'IdComposicaoPauta': 118524, 'IdVotoPauta': 42909, 'DescricaoObrigacao': 'Determinar a instauração de novo processo de controle externo por parte da Diretoria de Controle de Infraestrutura e Meio Ambiente (DIA), para a fisc ... (181 characters truncated) ... calização da execução dos contratos atualmente em vigência, devendo utilizar como subsídios os apontamentos e questões suscitadas nos presentes autos', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Diretoria de Controle de Infraestrutura e Meio Ambiente (DIA)', 'IdOrgaoResponsavel': 554, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:42,748 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:45,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:45,625 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:45,625 INFO sqlalchemy.engine.Engine [cached since 97.75s ago] {'IdProcesso': 567322, 'IdComposicaoPauta': 118552, 'IdVotoPauta': 42362, 'DescricaoObrigacao': 'Constituição de processo autônomo para apuração de responsabilidade do Sr. Manoel dos Santos Bernardo, em razão das irregularidades assinaladas no Relatório de Auditoria nº 105/2022 – DAM/FGO.', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'Prefeitura Municipal de João Câmara', 'IdOrgaoResponsavel': 395, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:45,698 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:49,520 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:49,521 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:49,522 INFO sqlalchemy.engine.Engine [cached since 101.6s ago] {'IdProcesso': 589848, 'IdComposicaoPauta': 118567, 'IdVotoPauta': 42966, 'DescricaoObrigacao': 'Intimar a Sra. Silvana Azevedo da Costa para fazer cessar todo e qualquer pagamento decorrente do ato em tela, e comprovar documentalmente o cumprimento desta obrigação ou a impossibilidade de fazê-lo.', 'DeFazer': 1, 'Prazo': '72 horas', 'DataCumprimento': datetime.datetime(2025, 1, 25, 0, 0), 'OrgaoResponsavel': 'Prefeitura Municipal de Jardim do Seridó', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:49,605 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:54,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:54,261 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:54,262 INFO sqlalchemy.engine.Engine [cached since 106.4s ago] {'IdProcesso': 586873, 'IdComposicaoPauta': 118575, 'IdVotoPauta': 43004, 'DescricaoObrigacao': 'Entregar, por meio do portal do gestor, as Contas Anuais de Gestão do exercício de 2022', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 4, 3, 0, 0), 'OrgaoResponsavel': 'CONSÓRCIO PÚBLICO INTERMUNICIPAL DE SANEAMENTO BÁSICO DA REGIÃO DO MATO GRANDE', 'IdOrgaoResponsavel': 1311, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Manoel dos Santos Bernardo', 'DocumentoResponsavelMultaCominatoria': '02897647426', 'IdPessoaMultaCominatoria': 48861, 'ValorMultaCominatoria': 100.0, 'PeriodoMultaCominatoria': 'diário', 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:54,329 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:40:59,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:40:59,557 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:40:59,558 INFO sqlalchemy.engine.Engine [cached since 111.7s ago] {'IdProcesso': 586873, 'IdComposicaoPauta': 118575, 'IdVotoPauta': 43004, 'DescricaoObrigacao': 'Em caso da impossibilidade de apresentação das contas determinada no item II desse dispositivo, deverá o(a) atual gestor(a) do Consórcio Público Inte ... (73 characters truncated) ... ar justo impedimento, demonstrando que tomou todas as medidas fixadas no art. 22, parágrafo único, incisos I, II e III, da Resolução nº 012/2016-TCE.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 3, 31, 0, 0), 'OrgaoResponsavel': 'CONSÓRCIO PÚBLICO INTERMUNICIPAL DE SANEAMENTO BÁSICO DA REGIÃO DO MATO GRANDE', 'IdOrgaoResponsavel': 1311, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:40:59,670 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:41:02,668 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:41:02,669 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:41:02,669 INFO sqlalchemy.engine.Engine [cached since 114.8s ago] {'IdProcesso': 586873, 'IdComposicaoPauta': 118575, 'IdVotoPauta': 43004, 'DescricaoObrigacao': 'Suspensão do fornecimento de Certidão de Adimplência do órgão jurisdicionado junto ao Tribunal de Contas enquanto permanecer a omissão no envio das Contas Anuais de Gestão.', 'DeFazer': 0, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'CONSÓRCIO PÚBLICO INTERMUNICIPAL DE SANEAMENTO BÁSICO DA REGIÃO DO MATO GRANDE', 'IdOrgaoResponsavel': 1311, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:41:02,739 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 16:41:06,679 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:41:06,681 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 16:41:06,681 INFO sqlalchemy.engine.Engine [cached since 118.8s ago] {'IdProcesso': 453418, 'IdComposicaoPauta': 118580, 'IdVotoPauta': 42778, 'DescricaoObrigacao': 'Notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO ESTADO DO RN', 'IdOrgaoResponsavel': 308, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 16:41:06,745 INFO sqlalchemy.engine.Engine COMMIT
# ...
# 2025-07-27 18:07:49,650 INFO sqlalchemy.engine.Engine [cached since 5322s ago] {'IdProcesso': 529641, 'IdComposicaoPauta': 120106, 'IdVotoPauta': 44071, 'DescricaoObrigacao': 'Intimar o Regime Próprio de Previdência Social do Município de Coronel João Pessoa (CORONELPREV), por meio do seu atual gestor, para que encaminhe os documentos indicados na Informação do Corpo Instrutivo e no Parecer do Ministério Público de Contas.', 'DeFazer': 1, 'Prazo': '30 dias úteis', 'DataCumprimento': datetime.datetime(2025, 7, 14, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DE CORONEL JOÃO PESSOA', 'IdOrgaoResponsavel': 1260, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Angra de Almeida Gama Saturno', 'DocumentoResponsavelMultaCominatoria': '05335768495', 'IdPessoaMultaCominatoria': 48185, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:07:49,717 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 18:07:53,941 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:07:53,943 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:07:53,945 INFO sqlalchemy.engine.Engine [cached since 5326s ago] {'IdProcesso': 529641, 'IdComposicaoPauta': 120106, 'IdVotoPauta': 44071, 'DescricaoObrigacao': 'DETERMINAR ao Regime Próprio de Previdência Social do Município de Coronel João Pessoa (CORONELPREV) que, até o trânsito em julgado da presente decisão, mantenha o pagamento dos proventos ao aposentado, sem solução de continuidade', 'DeFazer': 1, 'Prazo': 'até o trânsito em julgado da presente decisão', 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DE CORONEL JOÃO PESSOA', 'IdOrgaoResponsavel': 1260, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:07:54,017 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 18:08:00,105 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:00,107 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:00,108 INFO sqlalchemy.engine.Engine [cached since 5332s ago] {'IdProcesso': 532244, 'IdComposicaoPauta': 120136, 'IdVotoPauta': 44374, 'DescricaoObrigacao': 'Fazer cessar a aposentadoria concedida à ANA CÉLIA FERREIRA, em razão da não comprovação do tempo de efetivo exercício na função de magistério, indis ... (96 characters truncated) ... ral (com redação conferida pela EC nº 20/1998), bem como a não satisfação dos requisitos necessários para inativação com fulcro em outro dispositivo.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 9, 13, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DOS SERVIDORES DO MUNICÍPIO DE NATAL', 'IdOrgaoResponsavel': 642, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:00,169 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 810 de 816
# 2025-07-27 18:08:03,710 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:03,713 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:03,715 INFO sqlalchemy.engine.Engine [cached since 5336s ago] {'IdProcesso': 512094, 'IdComposicaoPauta': 120143, 'IdVotoPauta': 43035, 'DescricaoObrigacao': 'Intimação do Fundo de Previdência de Messias Targino, por meio de seu atual gestor, para que adote as providências necessárias à efetivação da compensação financeira junto ao Regime Geral de Previdência Social (RGPS).', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDENCIA MUNICIPAL DOS SERVIDORES PUBLICOS MUNICIPAIS DE MESSIAS TARGINO', 'IdOrgaoResponsavel': 1264, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:03,779 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: NaTType does not support strftime
# 2025-07-27 18:08:12,117 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:12,121 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:12,123 INFO sqlalchemy.engine.Engine [cached since 5344s ago] {'IdProcesso': 540578, 'IdComposicaoPauta': 120163, 'IdVotoPauta': 44389, 'DescricaoObrigacao': 'Determinação à autoridade responsável pelo RPPS de Riachuelo/RN para: 1) Fazer constar, no ato aposentador, a menção ao artigo 40, § 5º, da CF, e inc ... (409 characters truncated) ... a Legis-TCE/RN toda a legislação correlata à fixação do vencimento básico e demais reajustes remuneratórios referentes ao cargo da parte interessada.', 'DeFazer': 1, 'Prazo': '60 dias úteis', 'DataCumprimento': datetime.datetime(2025, 9, 13, 0, 0), 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO MUNICÍPIO DE RIACHUELO', 'IdOrgaoResponsavel': 1211, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:12,186 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 18:08:15,502 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:15,505 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:15,506 INFO sqlalchemy.engine.Engine [cached since 5348s ago] {'IdProcesso': 541350, 'IdComposicaoPauta': 120167, 'IdVotoPauta': 44242, 'DescricaoObrigacao': 'autoridade competente, responsável pelo Instituto de Previdência dos Servidores Municipais de São Paulo do Potengi – IPREVSAPP, corrigir o ato aposentador, a fim de que conste expressamente o fundamento jurídico que ampara a concessão do quinquênio', 'DeFazer': 1, 'Prazo': None, 'DataCumprimento': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO MUNICÍPIO DE RIACHUELO', 'IdOrgaoResponsavel': 1211, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:15,594 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-27 18:08:23,588 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:23,591 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:23,593 INFO sqlalchemy.engine.Engine [cached since 5356s ago] {'IdProcesso': 571228, 'IdComposicaoPauta': 120218, 'IdVotoPauta': 44432, 'DescricaoObrigacao': 'Retificar a imprecisão relatada, conforme os termos do voto do Conselheiro Relator e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 9, 14, 0, 0), 'OrgaoResponsavel': 'Instituto Previdenciário do Município de Macau/RN (MACAUPREV)', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 1, 'NomeResponsavelMultaCominatoria': 'Atual gestor do MACAUPREV', 'DocumentoResponsavelMultaCominatoria': '11549099000100', 'IdPessoaMultaCominatoria': 34035, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:23,684 INFO sqlalchemy.engine.Engine COMMIT
# Erro ao processar obrigação: NaTType does not support strftime
# Erro ao processar obrigação: list index out of range
# 2025-07-27 18:08:36,035 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 18:08:36,036 INFO sqlalchemy.engine.Engine INSERT INTO [Obrigacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoObrigacao], [DeFazer], [Prazo], [DataCumprimento], [OrgaoResponsavel], [IdOrgaoResponsavel], [TemMultaCominatoria], [NomeResponsavelMultaCominatoria], [DocumentoResponsavelMultaCominatoria], [IdPessoaMultaCominatoria], [ValorMultaCominatoria], [PeriodoMultaCominatoria], [EMultaCominatoriaSolidaria], [SolidariosMultaCominatoria]) OUTPUT inserted.[IdObrigacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoObrigacao)s, %(DeFazer)s, %(Prazo)s, %(DataCumprimento)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(TemMultaCominatoria)s, %(NomeResponsavelMultaCominatoria)s, %(DocumentoResponsavelMultaCominatoria)s, %(IdPessoaMultaCominatoria)s, %(ValorMultaCominatoria)s, %(PeriodoMultaCominatoria)s, %(EMultaCominatoriaSolidaria)s, %(SolidariosMultaCominatoria)s)
# 2025-07-27 18:08:36,038 INFO sqlalchemy.engine.Engine [cached since 5368s ago] {'IdProcesso': 570157, 'IdComposicaoPauta': 120221, 'IdVotoPauta': 44431, 'DescricaoObrigacao': 'O Instituto Previdenciário do Município de Macau/RN (MACAUPREV), por seu atual gestor, deve proceder à retificação da imprecisão relatada, conforme os termos do voto do Conselheiro Relator e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial.', 'DeFazer': 1, 'Prazo': '90 dias', 'DataCumprimento': datetime.datetime(2025, 9, 14, 0, 0), 'OrgaoResponsavel': 'Fundo de Seguridade Social de Macau', 'IdOrgaoResponsavel': None, 'TemMultaCominatoria': 0, 'NomeResponsavelMultaCominatoria': None, 'DocumentoResponsavelMultaCominatoria': None, 'IdPessoaMultaCominatoria': None, 'ValorMultaCominatoria': None, 'PeriodoMultaCominatoria': None, 'EMultaCominatoriaSolidaria': 0, 'SolidariosMultaCominatoria': 'null'}
# 2025-07-27 18:08:36,119 INFO sqlalchemy.engine.Engine COMMIT

# %%
len(errors)
# Out:
# 67

# %%
errors
# Out:
# [(nan,
#   NERObrigacao(descricao_obrigacao='remetido à Diretoria de Atos de Pessoal para que identifique a existência de processo de pensão correlato. Por fim, caso assim não seja possível, que seja notificado o Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte para providenciar a remessa do processo de pensão ou comunicar a inexistência de dependente, para fins de arquivamento.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='encaminhamento dos autos à Diretoria de Expediente – DE, para que seja retirado o caráter sigiloso dos presentes autos'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='devem os autos seguir para a Diretoria de Atos e Execuções – DAE para que seja realizada a cientificação do Representante, nos termos do art. 12, caput da Resolução n.º 16/2020-TCE'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinar à SECEX, que elabore e divulgue Nota Técnica Recomendatória aos municípios do RN, destacando a imprescindibilidade da observância do entendimento firmado pelo STF no Tema 548 de repercussão geral, o dever constitucional de assegurar o atendimento em creches para crianças de 0 a 3 anos e a obrigatoriedade dos municípios realizarem anualmente levantamento da demanda por vagas na educação infantil, com divulgação ampla desses resultados, inclusive listas de espera.'),
#   'NaTType does not support strftime'),
#  (549017.0,
#   NERObrigacao(descricao_obrigacao='determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após do trânsito em julgado desta decisão, comprove a implantação do valor correspondente à classe “G”, da LCE nº 737/2023, nos proventos percebidos pela servidora'),
#   'list index out of range'),
#  (549017.0,
#   NERObrigacao(descricao_obrigacao='no caso de descumprimento da presente Decisão, a imposição de multa diária para cada autoridade acima referenciada, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado nos item “b”, com base no art. 110, da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora'),
#   'list index out of range'),
#  (555430.0,
#   NERObrigacao(descricao_obrigacao='Após o trânsito em julgado da decisão, determinando a intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, fixando em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (549018.0,
#   NERObrigacao(descricao_obrigacao='Expedição de determinação ao atual Prefeito de Lajes Pintadas, para que, no mesmo prazo da alínea b, insira no Sistema Legis deste Tribunal as leis que disponham sobre os vencimentos do magistério, bem como as demais legislações correlatas, inclusive, aquela que disciplina as vantagens concedidas aos servidores do Município e os respectivos planos de cargos e salários.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='determinar que, com a publicação desta decisão, o processo seja encaminhado à Diretoria de Instrução Processual e Controle de Decisões (DIP) para cumprimento.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='notificação do gestor responsável pelo NATALPREV, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (505832.0,
#   NERObrigacao(descricao_obrigacao='proibição ao Município de Maxaranguape de realizar novas contratações temporárias até o saneamento definitivo da irregularidade, sob pena de multa de R$ 1.000,00 (um mil reais) por cada contratação realizada após essa decisão'),
#   "1 validation error for Obrigacao\nperiodo_multa_cominatoria\n  Input should be 'diário', 'semanal' or 'mensal' [type=literal_error, input_value='por cada contratação realizada', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.11/v/literal_error"),
#  (536737.0,
#   NERObrigacao(descricao_obrigacao='determinando a intimação do IPERN para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta) reais por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinado ao atual gestor do Instituto de Previdência de Senador Eloi de Souza/RN a obrigação de não fazer, consistente no ato de se abster de utilizar os recursos alocados em aplicações financeiras de investimentos já capitalizados, de médio e longo prazo, bem como aqueles advindos de seus respectivos rendimentos, para cobrir eventual déficit do pagamento de benefícios previdenciários, enquanto o montante de ativos garantidores do plano permanecer inferior à provisão matemática de benefícios concedidos (PMBC), sob pena de multa de R$ 5.000,00 (cinco mil reais) por cada ato de descumprimento, nos termos do art. 107, inciso II, alínea `f` da LCE nº 464/2012'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinado ao atual gestor da Prefeitura Municipal de Senador Eloi de Souza/RN a obrigação de fazer, consistente no ato de realizar a cobertura da insuficiência financeira do RPPS com recursos próprios do município, na hipótese dos recursos regularmente arrecadados das contribuições ordinárias e extraordinárias não serem suficientes para o pagamento dos benefícios previdenciários, em atenção ao disposto no artigo 2º, § 1º, da Lei 9717/98, sob pena de multa de R$ 5.000,00 (cinco  mil reais) por cada ato de descumprimento, nos termos do art. 107, inciso II, alínea `f` da LCE nº 464/2012'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinado aos atuais gestores da Prefeitura Municipal e do Instituto de Previdência do Município de Senador Elói de Souza/RN que, no prazo de sessenta (60) dias úteis, apresentem um plano de ação visando à amortização do déficit atuarial e à adequação da relação entre os ativos garantidores e as provisões matemáticas dos benefícios concedidos. O plano deverá, necessariamente, contemplar um estudo atuarial com avaliação das sugestões indicadas na fundamentação deste voto (parágrafo 44), sob pena da aplicação de multa pessoal e diária aos responsáveis no valor de R$ 1.000,00 (mil reais), com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `b`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='pela notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='processo ser remetido à Diretoria de Atos de Pessoal para que identifique a existência de processo de pensão correlato'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='que seja notificado o Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte para providenciar a remessa do processo de pensão ou comunicar a inexistência de dependente, para fins de arquivamento'),
#   'NaTType does not support strftime'),
#  (533280.0,
#   NERObrigacao(descricao_obrigacao='Expedição de determinação à atual Prefeita do Município de São Vicente para que se abstenha de pagar qualquer valor remuneratório com base na Lei Municipal nº 650/2020, sob pena de aplicação de nova multa por descumprimento e ressarcimento dos valores eventualmente pagos a maior'),
#   'list index out of range'),
#  (506171.0,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário, no seu atual gestor, após o trânsito em julgado, no prazo de 60 (sessenta) dias, para que regularize a situação noticiada nos autos'),
#   'list index out of range'),
#  (506171.0,
#   NERObrigacao(descricao_obrigacao='descumprimento da presente decisão, a imposição de multa diária ao gestor responsável, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado no item `c`, com base no artigo 110, da Lei Complementar Estadual nº 464/2012, valor este passível de revisão e limitado ao teto previsto no artigo 323, inciso II, alínea `f`, do Regimento Interno desta Casa, a ser apurado por ocasião de eventual subsistência de mora'),
#   'list index out of range'),
#  (541089.0,
#   NERObrigacao(descricao_obrigacao='expedição de determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta decisão, adote as seguintes correções na fundamentação do ato, composição e implantação do benefício, com implementação correta das vantagens para regularização do ato concessivo, tudo conforme a fundamentação desta proposta de voto, notadamente para: i. Desconsiderar o tempo de 3.240 (três mil duzentos e quarenta) dias do tempo de serviço privado para fins do ADTS, que passará a ser de 20% (vinte por cento), correspondentes aos 7.722 (sete mil setecentos e vinte e dois) dias prestados no serviço público e não mais em 30% (trinta por cento), como consta na atualidade.'),
#   'list index out of range'),
#  (502284.0,
#   NERObrigacao(descricao_obrigacao='A expedição de determinação ao Órgão Previdenciário responsável pela concessão do benefício, para que, no prazo de 60 (sessenta) dias úteis após o trânsito em julgado desta decisão, adote as seguintes correções na fundamentação do ato e composição do benefício, com implementação correta das vantagens para regularização do ato concessivo, tudo conforme a fundamentação desta proposta de voto, notadamente para:\ni. Retificar o ato aposentador para o “Nível IV”;\nii. Desconsiderar o tempo de serviço laborado no Conselho Regional de Engenharia, Arquitetura e Agronomia do RN para fins do ADTS, a saber 3.351 dias, o que enseja um percentual correto de ADTS em 21% (vinte e um por cento), promovendo novo enquadramento conforme LCE nº 722/2022 com base neste percentual.'),
#   'list index out of range'),
#  (502284.0,
#   NERObrigacao(descricao_obrigacao='no caso de descumprimento da presente Decisão, a imposição de multa diária, desde já fixada no valor de R$ 50,00 (cinquenta reais) por dia que superar o interregno fixado no “b”, com base no art. 110, da Lei Complementar Estadual nº 464/2012, sem prejuízo da aplicação da sanção prevista no art. 107, II, “f”, da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='notificação do gestor responsável pelo NATALPREV, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (505849.0,
#   NERObrigacao(descricao_obrigacao='Proibição ao Município de Pendências de realizar novas contratações temporárias até o saneamento definitivo da irregularidade, sob pena de multa de R$ 1.000,00 (um mil reais) por cada contratação realizada após essa decisão'),
#   "1 validation error for Obrigacao\nperiodo_multa_cominatoria\n  Input should be 'diário', 'semanal' or 'mensal' [type=literal_error, input_value='por cada contratação realizada', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.11/v/literal_error"),
#  (545618.0,
#   NERObrigacao(descricao_obrigacao='promovida a intimação da atual gestão da Prefeitura Municipal de Paraú/RN, a fim de que instaure a TOMADA DE CONTAS ESPECIAL, por meio do seu Órgão de Controle Interno, com vistas à identificação dos responsáveis e quantificação do dano decorrente da ausência de repasse pelo município de Paraú ao Banco Bradesco S.A dos valores descontados em folha de pagamento de seus servidores referente ao convênio firmado para concessão de empréstimo consignado, observando os seguintes pontos: \n1) Se houve por parte do gestor público a conduta de usar a remuneração dos servidores, especificamente a parte referente aos empréstimos consignados, para o gozo da Administração em outras finalidades previstas, ou não, na programação orçamentária do município; \n2) Se essa conduta houver sido utilizada, que o Órgão de Controle Interno apure qual a destinação dada pelo Município por parte da folha de pagamento dos servidores municipais; \n3) Identificação, comprovação e registro contábil do valor referente aos recursos públicos cuja destinação não foi comprovada, sendo que os valores cuja destinação não houver sido comprovada, devem ser evidenciados na contabilidade como direitos a receber do Município sob a responsabilidade dos agentes que causaram o dano ao erário, devendo o processo de Tomada de Contas ser encaminhado a este Tribunal para julgamento, a contar da sua conclusão, nos termos do art. 65, parágrafo único da Lei Complementar Estadual 464/2012;\nAINDA pela fixação do prazo de 180 (cento e oitenta) dias para a conclusão da Tomada de Contas Especial e que seu resultado seja encaminhado ao Tribunal de Contas do Estado após sua finalização, na forma prevista pelo parágrafo único do art. 65 da Lei Complementar nº 464/2012, observando-se que o seu descumprimento sem motivo justo caracteriza grave infração à norma legal e sujeita a autoridade administrativa omissa às sanções legais.'),
#   'list index out of range'),
#  (538545.0,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário estadual, no seu atual gestor, após o trânsito em julgado desta decisão, no prazo de 60 (sessenta) dias, para que regularize a situação noticiada nos autos, sob pena de sanção pecuniária prevista no artigo 107, inciso II, alínea `f`, da Lei Complementar Estadual nº 464/2012.'),
#   'list index out of range'),
#  (523483.0,
#   NERObrigacao(descricao_obrigacao='expedição de determinação ao atual Prefeito da Prefeitura Municipal de Pendências/RN para que providencie, no prazo de 30 (trinta) dias, a alimentação das informações necessárias no Portal da Transparência, suprindo as omissões ora apontadas, sob pena de multa diária, desde já fixada no valor de R$ 100,00 (cem reais) por dia que superar o interregno aqui fixado, com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `b`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora e de suspensão do fornecimento de Certidão de Adimplência Municipal, a teor do artigo 33, inciso II, da Resolução nº 011/2016 – TCE/RN.'),
#   'list index out of range'),
#  (570068.0,
#   NERObrigacao(descricao_obrigacao='intimar o Fundo de Seguridade de Macau do Estado do Rio Grande do Norte (MACAUPREV), por meio do seu Presidente, a fim de que adote as providências necessárias à adequação do ato aposentatório em destaque, de acordo com a informação do corpo técnico, devidamente acatada pelo parquet especial, no prazo de 30 dias úteis, sob pena de aplicação da multa prevista no art. 323, inciso II, alínea f'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='notificação do gestor responsável pelo IPERN, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='intimando o IPERN para que no prazo de 60 (sessenta) dias retifique o ato, retirando-lhe a vantagem transitória Gratificação de Risco de Vida, incorporada de modo contrário ao texto da República e também à Constituição deste Estado, sob pena de multa nos termos do art. 107, II, “f”, da Lei Complementar nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Após o trânsito em julgado da decisão, pela intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, desde já fixada em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'NaTType does not support strftime'),
#  (505853.0,
#   NERObrigacao(descricao_obrigacao='proibição ao Município de Jandaíra de realizar novas contratações temporárias até o saneamento definitivo da irregularidade, sob pena de multa de R$ 1.000,00 (um mil reais) por cada contratação realizada após essa decisão;'),
#   "1 validation error for Obrigacao\nperiodo_multa_cominatoria\n  Input should be 'diário', 'semanal' or 'mensal' [type=literal_error, input_value='por cada contratação realizada', input_type=str]\n    For further information visit https://errors.pydantic.dev/2.11/v/literal_error"),
#  (nan,
#   NERObrigacao(descricao_obrigacao='no prazo de 90 (noventa) dias a Prefeitura Municipal de Sítio Novo-RN remeta a este Tribunal as conclusões pormenorizadas de todas as situações irregulares de acúmulo de cargos públicos e que comprove o saneamento integral das irregularidades'),
#   'NaTType does not support strftime'),
#  (599786.0,
#   NERObrigacao(descricao_obrigacao='determinar, de forma imediata e em sede de medida cautelar, ao atual gestor da Prefeitura Municipal de Senador Eloi de Souza/RN, a obrigação de fazer, consistente na adoção de providências necessárias à regularização do débito previdenciário apontado na presente Representação (podendo fazê-lo por meio do pagamento integral ou pela celebração de parcelamento, desde que observadas as formalidades legais aplicáveis), no prazo de 90 (noventa) dias úteis, a contar da intimação desta decisão, haja vista a recente troca da gestão'),
#   'list index out of range'),
#  (599786.0,
#   NERObrigacao(descricao_obrigacao='que o atual gestor da Prefeitura Municipal de Senador Eloi de Souza/RN demonstre nos autos o cumprimento da obrigação de fazer ora determinada (item “d” acima), nos 05 (cinco) dias úteis após ultimado o prazo previsto, sob pena da aplicação de multa pessoal e diária ao responsável no valor de R$ 500,00 (quinhentos reais), com base no art. 110 da Lei Complementar Estadual nº 464/2012, valor esse passível de revisão, limitado ao teto previsto no art. 323, inciso II, alínea `b`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='após o trânsito em julgado, pela determinação à autoridade responsável pelo Instituto de Previdência dos Servidores do Estado do RN – IPERN, para que, prazo de 60 dias úteis, conforme o inteiro teor desta Decisão, adote as providências abaixo descritas, sob pena de responsabilidade da autoridade administrativa:\n• atualizar o ato aposentador, a apostila de cálculos e a implantação dos proventos em relação à nova classe e ao valor das parcelas pertinentes à remuneração pecuniária e à gratificação de título, conforme a classe do cargo da parte interessada, à luz do quanto disposto nas Leis Complementares Estaduais nº 203 e 206, de 2001, e da sentença proferida no processo judicial nº 0805379-63.2014.8.20.0001.'),
#   'NaTType does not support strftime'),
#  (567264.0,
#   NERObrigacao(descricao_obrigacao='assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1º, inciso VII, da mesma Lei Complementar, para que o Instituto de Previdência dos Servidores do Município de São Paulo do Potengi, se pronuncie a respeito das irregularidades identificadas, conforme termos do voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'list index out of range'),
#  (555381.0,
#   NERObrigacao(descricao_obrigacao='assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1º, inciso VII, da mesma Lei Complementar, para que o Órgão Previdenciário responsável, acoste aos autos, a comprovação das irregularidades constatadas, conforme termos do voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'list index out of range'),
#  (555661.0,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário estadual, no seu atual gestor, após o trânsito em julgado desta decisão, no prazo de 60 (sessenta) dias, para que regularize a situação noticiada nos autos, sob pena de sanção pecuniária prevista no artigo 107, inciso II, alínea `f`, da Lei Complementar Estadual nº 464/2012.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1.º, inciso VII, da mesma Lei Complementar, para que o IPERN proceda à retificação das imprecisões acima relatadas, conforme termos do voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='intimação do IPERN para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, desde já fixada em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='A diretoria de expediente deve: (A) ATUALIZAR o cadastro informatizado destes autos, no campo órgão envolvido, como CÂMARA MUNICIPAL DE SÃO JOSÉ DO CAMPESTRE; (B) INCLUIR o Sr. JAILSON JOSÉ DA SILVA como pessoa relacionada ao processo, tudo no intuito de facilitar futuras diligências/pesquisas administrativas ou rotinas de monitoramentos.'),
#   'NaTType does not support strftime'),
#  (594800.0,
#   NERObrigacao(descricao_obrigacao='Ademais, pela assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1º, inciso VII, da mesma Lei Complementar, para que o Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte - IPERN, por seu atual gestor, nos termos do art. 101, parágrafo único, da Lei Complementar Estadual nº 464/12, proceda a retificação das imprecisões ora identificadas e envio da documentação pertinente, conforme termos deste voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, prevista no artigo 107, inciso II, alínea `f`, da Lei Complementar Estadual nº 464/2012, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'list index out of range'),
#  (548154.0,
#   NERObrigacao(descricao_obrigacao='assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1º, inciso VII, da mesma Lei Complementar, para que o Órgão Previdenciário responsável acoste aos autos, a comprovação das irregularidades constatadas, conforme termos deste voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'list index out of range'),
#  (533807.0,
#   NERObrigacao(descricao_obrigacao='impor obrigação de fazer, assinando o prazo de 60 (sessenta) dias úteis para que a atual Secretária de Estado das Mulheres, da Juventude, da Igualdade Racial e dos Direitos Humanos, Sra. Olga Aguiar de Melo, ou quem estiver no exercício do cargo ao tempo do cumprimento desta obrigação de fazer, entregue, por meio do portal do gestor, as contas anuais de gestão do exercício de 2019, sob pena da mesma incorrer em multa nos moldes do art. 107, da LCE nº 464/2012, c/c o art. 21, da Resolução nº 012/2016-TCE, e representação ao Ministério Público Estadual.'),
#   'list index out of range'),
#  (533807.0,
#   NERObrigacao(descricao_obrigacao='em caso de impossibilidade de apresentação das contas, que a atual Secretária de Estado das Mulheres, da Juventude, da Igualdade Racial e dos Direitos Humanos, Sra. Olga Aguiar de Melo, ou quem estiver no exercício do cargo ao tempo do cumprimento desta obrigação de fazer, comprove justo impedimento, demonstrando que tomou todas as medidas determinadas no art. 22, parágrafo único, da Resolução nº 012/2016-TCE em face da Secretária em 2019, por ter sido esta a responsável pela consecução da documentação referente às contas anuais de gestão do exercício em que exerceu o referido cargo.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='NOTIFICAÇÃO do Instituto de Previdência Social dos Servidores do Município de Natal - NATALPREV, estipulando o prazo de 60 (sessenta) dias, nos termos do artigo 96, inciso IV, da Lei Complementar nº 464/2012, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte a esta Corte de Contas ou comunique a inexistência de dependentes, sob pena de imputação de multa a autoridade responsável, nos termos do artigo 107, inciso II, alínea “f”, da Lei Complementar nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Notificação do Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte, para que providencie, se for o caso, a remessa do respectivo processo de pensão por morte, consoante prescreve o art. 96, IV, da LCE nº 464/2012, ou comunique a inexistência de dependente, para fins de arquivamento.'),
#   'NaTType does not support strftime'),
#  (555263.0,
#   NERObrigacao(descricao_obrigacao='intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, desde já fixada em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea "f", do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (473378.0,
#   NERObrigacao(descricao_obrigacao='Quanto à conclusão desse Certame, sua efetivação deve ser comprovada nos autos pela gestora responsável, por meio da juntada do respectivo ato formal, em até 10 (dez) dias após o transcurso do prazo fixado para seu cumprimento, sob pena de multa pessoal e diária de R$ 500,00 (quinhentos reais) ao Exmo. Sr. Secretário de Estado da Administração, Pedro Lopes de Araújo Neto.'),
#   'list index out of range'),
#  (554758.0,
#   NERObrigacao(descricao_obrigacao='Após o trânsito em julgado da decisão, determino a intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Após o trânsito em julgado da decisão, determino a intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'NaTType does not support strftime'),
#  (555198.0,
#   NERObrigacao(descricao_obrigacao='intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='DETERMINAÇÃO ao órgão previdenciário, no seu atual gestor, após o trânsito em julgado, no prazo de 60 (sessenta) dias, para que regularize a situação noticiada nos autos, corrigindo o ato aposentador, a apostila de cálculo e a implantação dos proventos, no sentido de excluir a citada vantagem transitória, sob pena de sanção pecuniária prevista no artigo 107, inciso II, alínea `f`, da Lei Complementar Estadual nº 464/2012.'),
#   'NaTType does not support strftime'),
#  (555216.0,
#   NERObrigacao(descricao_obrigacao='Após o trânsito em julgado da decisão, determinando a intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (555216.0,
#   NERObrigacao(descricao_obrigacao='Esclarecendo ao órgão de origem que a denegação ora declarada não enseja a suspensão do pagamento dos proventos de aposentadoria da interessada, mas tão somente demanda a sua correção consoante as determinações expostas anteriormente neste decisão.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinar ao Instituto de Previdência do Estado do Rio Grande do Norte - IPERN, no prazo de sessenta dias úteis, que adote as providências necessárias à retificação do ato aposentador ou que recorra desta decisão, se assim for do seu interesse, bem como intimar a parte interessada para alegar o que entender de direito, em harmonia com o princípio do contraditório e da ampla defesa.'),
#   'NaTType does not support strftime'),
#  (555391.0,
#   NERObrigacao(descricao_obrigacao='determinando a intimação do órgão de origem para que, em 60 (sessenta) dias, adote as medidas regularizadoras cabíveis, sob pena de estabelecimento de multa diária em face do gestor responsável, que desde já fixo em R$ 50,00 (cinquenta reais) por cada dia de atraso que exceder ao prazo acima consignado, valor este passível de revisão e limitado ao teto previsto no art. 323, inciso II, alínea `f`, do Regimento Interno, a ser apurado por ocasião de eventual subsistência de mora.'),
#   'list index out of range'),
#  (574037.0,
#   NERObrigacao(descricao_obrigacao='pela NOTIFICAÇÃO ao Instituto de Previdência dos Servidores do Estado do Rio Grande do Norte - IPERN, no seu atual gestor, estipulando o prazo de 60 (sessenta) dias, nos termos do artigo 96, inciso IV, da Lei Complementar nº 464/2012, para que providencie a remessa do respectivo processo de pensão por morte a esta Corte de Contas para análise do feito, sob pena de imputação de multa a autoridade competente, nos termos do artigo 107, inciso II, alínea “f”, da Lei Complementar Estadual nº 464/2012 c/c o artigo 323, inciso II, alínea `f`, do Novel Regimento Interno desta Casa.'),
#   'list index out of range'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='Determinar a divulgação do referido relatório, por meio do Portal do Gestor, aos responsáveis pelos Regimes Próprios de Previdência Social e aos gestores dos Municípios instituidores, para conhecimento dos parâmetros de contratação formulados pela Unidade Técnica'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='autoridade competente, responsável pelo Instituto de Previdência dos Servidores Municipais de São Paulo do Potengi – IPREVSAPP, corrigir o ato aposentador, a fim de que conste expressamente o fundamento jurídico que ampara a concessão do quinquênio.'),
#   'NaTType does not support strftime'),
#  (nan,
#   NERObrigacao(descricao_obrigacao='assinatura de prazo de 90 (noventa) dias, a contar do trânsito em julgado da decisão, com base no artigo 1º, inciso VII, da mesma Lei Complementar, para que o Instituto Previdenciário do Município de Macau/RN (MACAUPREV), por seu atual gestor, nos termos do art. 101, parágrafo único, da Lei Complementar Estadual nº 464/12, proceda à retificação da imprecisão acima relatada, conforme termos deste voto e todas as observações presentes nas manifestações do Corpo Técnico e do Parquet Especial, sob pena de aplicação ao responsável de sanção administrativa, prevista no artigo 107, inciso II, alínea `f`, da Lei Complementar Estadual nº 464/2012, devendo o processo, posteriormente, ser devolvido a este Tribunal de Contas.'),
#   'NaTType does not support strftime'),
#  (570157.0,
#   NERObrigacao(descricao_obrigacao='INTIMAÇÃO, em consonância com os artigos 200 e 219, inciso III, do Regimento Interno do Tribunal de Contas da parte interessada, a fim de que tomem conhecimento desta Decisão e, se for o caso, apresentem recurso no prazo regimental, bem como providenciem as adequações necessárias afim de retificar à concessão'),
#   'list index out of range')]
