# %% [markdown]
# # Extraction of models from DeciContas.br Dataset

# %%
import os
import json
import pymssql

import pandas as pd
import numpy as np


from pprint import pprint
from langchain_openai import  AzureChatOpenAI, ChatOpenAI
from dotenv import load_dotenv
from sqlalchemy import (
    create_engine, Column, Integer, String, Float, Date, Boolean, Text, JSON
)
from sqlalchemy.orm import declarative_base, sessionmaker

from tools.prompt import generate_few_shot_ner_prompts, extract_obrigacao, extract_recomendacao, insert_obrigacao, insert_recomendacao
from tools.schema import (
    NERDecisao,
    Obrigacao,
    Recomendacao
)

from tools.models import (
    Base, ObrigacaoORM, RecomendacaoORM
)

from datetime import timedelta


load_dotenv()


gpt4turbo = AzureChatOpenAI(
    deployment_name="gpt-4-turbo",
    model_name="gpt-4",
)

'''
gpt4turbo = ChatOpenAI(
    model="gpt-4-turbo",
    temperature=0.0
)
'''

extractor_gpt4turbo = gpt4turbo.with_structured_output(NERDecisao, include_raw=False, method="json_schema")
extractor_obrigacao_gpt4turbo = gpt4turbo.with_structured_output(
    Obrigacao, include_raw=False, method="json_schema")
extractor_recomendacao_gpt4turbo = gpt4turbo.with_structured_output(
    Recomendacao, include_raw=False, method="json_schema")



def get_connection(db: str = 'processo'):
    server = os.getenv("SQL_SERVER_HOST")
    user = os.getenv("SQL_SERVER_USER")
    password = os.getenv("SQL_SERVER_PASS")
    port = os.getenv("SQL_SERVER_PORT", "1433")  # default MSSQL port
    database = db

    return pymssql.connect(server, user, password, database, port)
# Out:
# c:\Users\05911205424\Documents\Dev\cgad\venv\Lib\site-packages\langchain_openai\chat_models\base.py:1927: UserWarning: Cannot use method='json_schema' with model gpt-4 since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(

# %%
import importlib
importlib.reload(__import__('tools.schema'))
# Out:
# <module 'tools' from 'c:\\Users\\05911205424\\Documents\\Dev\\cgad\\etl\\tools\\__init__.py'>

# %% [markdown]
# # From DB Processo

# %%
meses = (10,11)
sql_decisoes = f'''
SELECT *
FROM processo.dbo.vw_ia_votos_acordaos_decisoes d
WHERE YEAR(DataSessao) = 2025
AND MONTH(DataSessao) IN {meses}
AND NOT EXISTS(
	SELECT *
	FROM BdDIP.dbo.Obrigacao o 
	WHERE d.IdComposicaoPauta = o.IdComposicaoPauta
	AND d.idVotoPauta = o.idVotoPauta 
)
AND NOT EXISTS(
	SELECT *
	FROM BdDIP.dbo.Recomendacao r 
	WHERE d.IdComposicaoPauta = r.IdComposicaoPauta
	AND d.idVotoPauta = r.idVotoPauta 
)


'''
df_decisoes = pd.read_sql(sql_decisoes, get_connection())
df_decisoes['ner_decisao'] = ''
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_13108\2427677665.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_decisoes = pd.read_sql(sql_decisoes, get_connection())

# %%
len(df_decisoes)
# Out:
# 436

# %%
resultados = []
errors = []
for index, row in df_decisoes.iterrows():
    if index % 10 == 0 and index > 0:
        print(f"Processando instância {index} de {len(df_decisoes)}")
        df_decisoes.to_pickle("decisoes_ner_4T2025.pkl")

    try:
        prompt_with_few_shot = generate_few_shot_ner_prompts(row['texto_acordao'])
        
        result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
        df_decisoes.at[index, 'ner_decisao'] = result
        resultados.append(result)
    except Exception as e:
        errors.append({
            'index': index,
            'error': str(e),
            'row': row.to_dict()
        })
# Out:
# Processando instância 10 de 436
# Processando instância 20 de 436
# Processando instância 30 de 436
# Processando instância 40 de 436
# Processando instância 50 de 436
# Processando instância 60 de 436
# Processando instância 70 de 436
# Processando instância 80 de 436
# Processando instância 90 de 436
# Processando instância 100 de 436
# Processando instância 110 de 436
# Processando instância 120 de 436
# Processando instância 130 de 436
# Processando instância 140 de 436
# Processando instância 150 de 436
# Processando instância 160 de 436
# Processando instância 170 de 436
# Processando instância 180 de 436
# Processando instância 190 de 436
# Processando instância 200 de 436
# Processando instância 210 de 436
# Processando instância 220 de 436
# Processando instância 230 de 436
# Processando instância 240 de 436
# Processando instância 250 de 436
# Processando instância 260 de 436
# Processando instância 270 de 436
# Processando instância 280 de 436
# Processando instância 290 de 436
# Processando instância 300 de 436
# Processando instância 310 de 436
# Processando instância 320 de 436
# Processando instância 330 de 436
# Processando instância 340 de 436
# Processando instância 350 de 436
# Processando instância 360 de 436
# Processando instância 370 de 436
# Processando instância 380 de 436
# Processando instância 390 de 436
# Processando instância 400 de 436
# Processando instância 410 de 436
# Processando instância 420 de 436
# Processando instância 430 de 436

# %%
import re

def slugify(s):
    s = s.lower()
    s = re.sub(r'[^\w\s-]', '', s)
    s = re.sub(r'[\s]+', '_', s)
    return s

df_decisoes.columns = [slugify(col) for col in df_decisoes.columns]
df_decisoes.to_pickle("decisoes_ner_4T2025.pkl")

# %% [markdown]
# ## Carregando pickle

# %%
df_decisoes = pd.read_pickle("decisoes_ner_4T2025.pkl")

# %%
len(df_decisoes)
# Out:
# 436

# %%
sql_orgaos = f'''
SELECT p.idprocesso,
CONCAT(p.numero_processo, '/', p.ano_processo) as processo,
o.nome as orgao_responsavel, 
o.IdOrgao as id_orgao_responsavel,
gp.Nome as nome_responsavel,
gp.Documento as documento_responsavel,
gp.TipoPessoa  as tipo_responsavel,
gp.IdPessoa as id_pessoa
FROM processo.dbo.Processos p
INNER JOIN processo.dbo.Orgaos o ON p.IdOrgaoEnvolvido = o.IdOrgao 
INNER JOIN processo.dbo.Pro_ProcessosResponsavelDespesa pprd ON pprd.IdProcesso = p.IdProcesso 
INNER JOIN processo.dbo.GenPessoa gp ON gp.IdPessoa = pprd.IdPessoa 
WHERE p.idprocesso IN ({', '.join([f"{proc}" for proc in df_decisoes['idprocesso'].unique()])})
'''
df_orgaos = pd.read_sql(sql_orgaos, get_connection())
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_10784\4281826205.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_orgaos = pd.read_sql(sql_orgaos, get_connection())

# %%
df_decisoes = df_decisoes.merge(df_orgaos, how='left', left_on='idprocesso', right_on='idprocesso', suffixes=('', '_y'))

# %%
engine = create_engine(
    f"mssql+pymssql://{os.getenv("SQL_SERVER_USER")}:{os.getenv("SQL_SERVER_PASS")}@{os.getenv("SQL_SERVER_HOST")}/{os.getenv("SQL_SERVER_DB")}",
    echo=True
)
#engine = create_engine("sqlite:///dataset/sqlite/obrigacoes.db", echo=True)
SessionLocal = sessionmaker(bind=engine)

# %%
df_decisoes.columns
# Out:
# Index(['idvoto', 'monocratica', 'codigo_tipo_processo', 'descricao',
#        'tipovoto', 'votoescolhido', 'idinformacao_voto', 'info_arquivo_voto',
#        'idcomposicaopauta', 'codigocamara', 'numero_sessao', 'ano_sessao',
#        'datasessao', 'datadecisaomonocratica', 'dataencerramentosessao',
#        'numeroresultado', 'anoresultado', 'resultadotipo', 'idapreciacao',
#        'idtiporecurso', 'idtipovotacao', 'decisao', 'idvotopauta',
#        'idvotodecisao', 'nomerelator', 'setor', 'ementa', 'assunto',
#        'numeroprocesso', 'anoprocesso', 'nomerelatorprocesso', 'idprocesso',
#        'interessado', 'orgaoorigem', 'divergente_de_idvoto',
#        'isvotodivergente', 'idvotoconcordado', 'relatorio',
#        'fundamentacaovoto', 'conclusao', 'artigo', 'texto_acordao',
#        'setorvoto', 'descricaotipovoto', 'ner_decisao', 'processo',
#        'orgao_responsavel', 'id_orgao_responsavel', 'nome_responsavel',
#        'documento_responsavel', 'tipo_responsavel', 'id_pessoa'],
#       dtype='object')

# %%
obrigacoes = [(d.idcomposicaopauta, d.idvoto, d.idvotopauta, d.datasessao, d['ner_decisao'].obrigacoes) 
              for _,d in df_decisoes[['idcomposicaopauta', 'idvotopauta', 'idvoto', 'datasessao', 'ner_decisao']].iterrows() if d['ner_decisao'].obrigacoes != []]
df_ob = pd.DataFrame(obrigacoes, columns=['idcomposicaopauta', 'idvoto', 'idvotopauta', 'datasessao', 'obrigacoes'])
df_ob['idvotopauta'] = df_ob['idvotopauta'].astype('int64')

# %%
recomendacoes = [(d.idcomposicaopauta, d.idvoto, d.idvotopauta, d.datasessao, d['ner_decisao'].recomendacoes) 
              for _,d in df_decisoes[['idcomposicaopauta', 'idvotopauta', 'idvoto', 'datasessao', 'ner_decisao']].iterrows() if d['ner_decisao'].recomendacoes != []]
df_rec = pd.DataFrame(recomendacoes, columns=['idcomposicaopauta', 'idvoto', 'idvotopauta', 'datasessao', 'recomendacoes'])
df_rec['idvotopauta'] = df_rec['idvotopauta'].astype('int64')

# %%
group_cols = [
        'idprocesso', 'numeroprocesso', 'anoprocesso', 'idcomposicaopauta', 
        'idvotopauta', 'numero_sessao', 'ano_sessao', 'datasessao', 'relatorio',
        'fundamentacaovoto', 'conclusao', 'texto_acordao', 'orgao_responsavel', 'id_orgao_responsavel',
]
person_cols = ['nome_responsavel', 'documento_responsavel', 'tipo_responsavel', 'id_pessoa']

df_decisoes_aug = df_decisoes.groupby(group_cols, dropna=False).apply(
    lambda x: pd.Series({'responsaveis': x[person_cols].apply(
        lambda y: y.dropna().to_dict(), axis=1
    ).tolist()})
).reset_index()

# %%
# Out:
# C:\Users\05911205424\AppData\Local\Temp\ipykernel_10784\1014293047.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decisoes_aug = df_decisoes.groupby(group_cols, dropna=False).apply(

# %%
df_ob = df_ob[['idcomposicaopauta', 'idvotopauta', 'obrigacoes']].merge(df_decisoes_aug, on=['idcomposicaopauta', 'idvotopauta'], how='left')
df_ob['datasessao'] = pd.to_datetime(df_ob['datasessao'], errors='coerce')
df_ob['n_obrigacoes'] = df_ob['obrigacoes'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
df_rec = df_rec[['idcomposicaopauta', 'idvotopauta', 'recomendacoes']].merge(df_decisoes_aug, on=['idcomposicaopauta', 'idvotopauta'], how='left')
df_rec['datasessao'] = pd.to_datetime(df_rec['datasessao'], errors='coerce')
df_rec['n_recomendacoes'] = df_rec['recomendacoes'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
def remover_obrigacoes_duplicadas(obrigacoes_list):
    """
    Remove obrigações duplicadas de uma lista de NERObrigacao.

    Args:
        obrigacoes_list (list): A lista de objetos NERObrigacao.

    Returns:
        list: Uma nova lista com as obrigações únicas.
    """
    obrigacoes_vistas = set()
    obrigacoes_sem_duplicatas = []
    
    for obrigacao in obrigacoes_list:
        # Pega a descrição, remove espaços em branco e a converte para lowercase
        # para garantir que strings como 'Texto ' e 'texto' sejam tratadas como a mesma.
        descricao_limpa = obrigacao.descricao_obrigacao.strip().lower()
        
        if descricao_limpa not in obrigacoes_vistas:
            obrigacoes_vistas.add(descricao_limpa)
            obrigacoes_sem_duplicatas.append(obrigacao)
            
    return obrigacoes_sem_duplicatas

def remover_recomendacoes_duplicadas(recomendacoes_list):
    """
    Remove recomendações duplicadas de uma lista de NERRecomendacao.

    Args:
        recomendacoes_list (list): A lista de objetos NERRecomendacao.

    Returns:
        list: Uma nova lista com as recomendações únicas.
    """
    recomendacoes_vistas = set()
    recomendacoes_sem_duplicatas = []
    
    for recomendacao in recomendacoes_list:
        descricao_limpa = recomendacao.descricao_recomendacao.strip().lower()
        
        if descricao_limpa not in recomendacoes_vistas:
            recomendacoes_vistas.add(descricao_limpa)
            recomendacoes_sem_duplicatas.append(recomendacao)
            
    return recomendacoes_sem_duplicatas

# %%
from sqlalchemy.exc import IntegrityError
from sqlalchemy.orm import Session
# Assuming these are your imports

errors = []
k = 0

for _, row in df_ob.iterrows():
    print(f"Processando instância {row.name} de {len(df_ob)}")

    # Remove duplicatas da lista de obrigações antes de iniciar o loop
    obrigacoes_unicas = remover_obrigacoes_duplicadas(row['obrigacoes'])

    for obrigacao in obrigacoes_unicas:
        db_session = SessionLocal() # Create the session inside the loop to ensure a fresh connection for each row
        try:
            result_obrigacao = extract_obrigacao(row, obrigacao)
            insert_obrigacao(db_session, result_obrigacao, row)
            db_session.commit() # Commit the transaction here
        except IntegrityError:
            # This block handles the duplicate key error specifically
            print(f"Registro duplicado. Não será inserido: {row['idprocesso']}")
            db_session.rollback() # Rollback the transaction to clear the session state
        except Exception as e:
            # This block handles all other potential errors
            print(f"Erro ao processar obrigação: {e}")
            db_session.rollback() # Rollback on other errors as well
            errors.append((row['idprocesso'], obrigacao, str(e)))
        finally:
            db_session.close() # Always close the session to release the connection

# %%
from sqlalchemy.exc import IntegrityError
from sqlalchemy.orm import Session
import traceback
# Assuming these are your imports

errors = []
k = 0

for _, row in df_rec.iterrows():
    print(f"Processando instância {row.name} de {len(df_rec)}")
    # Remove duplicatas da lista de recomendações antes de iniciar o loop
    recomendacoes_unicas = remover_recomendacoes_duplicadas(row['recomendacoes'])

    for recomendacao in recomendacoes_unicas:
        db_session = SessionLocal() # Create the session inside the loop to ensure a fresh connection for each row
        try:
            result_recomendacao = extract_recomendacao(row, recomendacao)
            insert_recomendacao(db_session, result_recomendacao, row)
            db_session.commit() # Commit the transaction here
        except IntegrityError:
            # This block handles the duplicate key error specifically
            print(f"Registro duplicado. Não será inserido: {row['idprocesso']}")
            db_session.rollback() # Rollback the transaction to clear the session state
        except Exception as e:
            # This block handles all other potential errors
            print(f"Erro ao processar recomendação: {e}")
            traceback.print_exc()
            db_session.rollback() # Rollback on other errors as well
            errors.append((row['idprocesso'], recomendacao, str(e)))
        finally:
            db_session.close() # Always close the session to release the connection
# Out:
# Processando instância 0 de 57
# 2025-11-18 15:26:21,410 INFO sqlalchemy.engine.Engine select @@version
# 2025-11-18 15:26:21,410 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine [generated in 0.00070s] {}
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine [generated in 0.00081s] {}
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2025-11-18 15:26:21,425 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# 2025-11-18 15:26:21,437 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:21,439 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:21,439 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {'IdProcesso': 587005, 'IdComposicaoPauta': 121852, 'IdVotoPauta': 39439, 'DescricaoRecomendacao': 'RECOMENDAÇÃO à gestão atual da localidade, a cargo da Sra. RAIMUNDA NILDA DA SILVA CRUZ, bem como ao atual responsável pela SETUDE, a cargo do Sr. GI ... (46 characters truncated) ... os necessários (art. 76 do código civil), para conhecimento das falhas apontadas na presente e no parecer 36/2024 e adoção das providências cabíveis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Sra. RAIMUNDA NILDA DA SILVA CRUZ e Sr. GILNEY MICHELL DELMIRO DE GÓIS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'Cancelado': None}
# 2025-11-18 15:26:21,443 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 1 de 57
# 2025-11-18 15:26:22,655 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:22,655 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:22,655 INFO sqlalchemy.engine.Engine [cached since 1.218s ago] {'IdProcesso': 578380, 'IdComposicaoPauta': 123418, 'IdVotoPauta': 39345, 'DescricaoRecomendacao': 'recomendação para os fins de aprimoramento dos controles aziendais e anotação a ser efetivada pela diretoria de instrução processual e controle de decisões (art. 431, IV, c, do regimento interno).', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': None, 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CANGUARETAMA', 'IdOrgaoResponsavel': 356, 'Cancelado': None}
# 2025-11-18 15:26:22,660 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 2 de 57
# 2025-11-18 15:26:23,862 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:23,863 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:23,864 INFO sqlalchemy.engine.Engine [cached since 2.425s ago] {'IdProcesso': 578380, 'IdComposicaoPauta': 123418, 'IdVotoPauta': 39345, 'DescricaoRecomendacao': 'recomendação para os fins de aprimoramento dos controles aziendais e anotação a ser efetivada pela diretoria de instrução processual e controle de decisões (art. 431, IV, c, do regimento interno).', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': None, 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CANGUARETAMA', 'IdOrgaoResponsavel': 356, 'Cancelado': None}
# 2025-11-18 15:26:23,866 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 3 de 57
# 2025-11-18 15:26:25,064 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:25,065 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:25,065 INFO sqlalchemy.engine.Engine [cached since 3.626s ago] {'IdProcesso': 578380, 'IdComposicaoPauta': 123418, 'IdVotoPauta': 39345, 'DescricaoRecomendacao': 'recomendação para os fins de aprimoramento dos controles aziendais e anotação a ser efetivada pela diretoria de instrução processual e controle de decisões (art. 431, IV, c, do regimento interno).', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'JOÃO WILSON DE ANDRADE RIBEIRO FILHO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CANGUARETAMA', 'IdOrgaoResponsavel': 356, 'Cancelado': None}
# 2025-11-18 15:26:25,071 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 4 de 57
# 2025-11-18 15:26:26,500 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:26,500 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:26,500 INFO sqlalchemy.engine.Engine [cached since 5.063s ago] {'IdProcesso': 586014, 'IdComposicaoPauta': 123346, 'IdVotoPauta': 43942, 'DescricaoRecomendacao': 'recomendação à FUNDASE a fim de que implemente procedimentos internos para formalizar justificativas detalhadas sempre que houver necessidade de alteração da ordem cronológica de pagamentos, obedecendo ao disposto nos parágrafos 1º e 3° do artigo 141 da Lei Federal n. 14.133/2021.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'HERCULANO RICARDO CAMPOS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'FUNDAÇÃO DE ATENDIMENTO SOCIOEDUCATIVO DO ESTADO DO RN', 'IdOrgaoResponsavel': 264, 'Cancelado': None}
# 2025-11-18 15:26:26,500 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 5 de 57
# 2025-11-18 15:26:27,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:27,981 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:27,982 INFO sqlalchemy.engine.Engine [cached since 6.543s ago] {'IdProcesso': 586014, 'IdComposicaoPauta': 123346, 'IdVotoPauta': 43942, 'DescricaoRecomendacao': 'recomendação à FUNDASE a fim de que implemente procedimentos internos para formalizar justificativas detalhadas sempre que houver necessidade de alteração da ordem cronológica de pagamentos, obedecendo ao disposto nos parágrafos 1º e 3° do artigo 141 da Lei Federal n. 14.133/2021.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'HERCULANO RICARDO CAMPOS - ATUAL PRESIDENTE DA FUNDASE', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'FUNDAÇÃO DE ATENDIMENTO SOCIOEDUCATIVO DO ESTADO DO RN', 'IdOrgaoResponsavel': 264, 'Cancelado': None}
# 2025-11-18 15:26:27,985 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 6 de 57
# 2025-11-18 15:26:30,203 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:30,204 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:30,204 INFO sqlalchemy.engine.Engine [cached since 8.766s ago] {'IdProcesso': 586014, 'IdComposicaoPauta': 123346, 'IdVotoPauta': 43942, 'DescricaoRecomendacao': 'recomendação à FUNDASE a fim de que implemente procedimentos internos para formalizar justificativas detalhadas sempre que houver necessidade de alteração da ordem cronológica de pagamentos, obedecendo ao disposto nos parágrafos 1º e 3° do artigo 141 da Lei Federal n. 14.133/2021.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'HERCULANO RICARDO CAMPOS - ATUAL PRESIDENTE DA FUNDASE', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'FUNDAÇÃO DE ATENDIMENTO SOCIOEDUCATIVO DO ESTADO DO RN', 'IdOrgaoResponsavel': 264, 'Cancelado': None}
# 2025-11-18 15:26:30,206 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 7 de 57
# 2025-11-18 15:26:31,500 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:31,500 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:31,501 INFO sqlalchemy.engine.Engine [cached since 10.06s ago] {'IdProcesso': 313887, 'IdComposicaoPauta': 123412, 'IdVotoPauta': 45140, 'DescricaoRecomendacao': 'recomendar ao atual gestor do Município de Serra Negra do Norte que: (i) proceda à correção das falhas apontadas, com a adequação dos veículos e dos  ... (103 characters truncated) ... ote providências junto à Secretaria Municipal de Tributação para que seja observada a legislação tributária, notadamente, no que diz respeito ao ISS.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Desconhecido', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Desconhecido', 'IdOrgaoResponsavel': None, 'Cancelado': None}
# 2025-11-18 15:26:31,502 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 8 de 57
# 2025-11-18 15:26:32,625 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:32,625 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:32,625 INFO sqlalchemy.engine.Engine [cached since 11.19s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que adote as medidas necessárias à melhoria da qualidade das informações contábeis;', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:32,625 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-18 15:26:33,763 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:33,763 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:33,764 INFO sqlalchemy.engine.Engine [cached since 12.33s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que adote providências para estruturar o sistema de tributação do município, para atendimento ao disposto no artigo 11 da Lei de Responsabilidade Fiscal;', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:33,771 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-18 15:26:34,990 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:34,990 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:34,990 INFO sqlalchemy.engine.Engine [cached since 13.56s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que institua medidas para coibir a assunção indiscriminada de obrigações não suportadas pela disponibilidade financeira do exercício.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:34,990 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 9 de 57
# 2025-11-18 15:26:36,217 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:36,218 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:36,218 INFO sqlalchemy.engine.Engine [cached since 14.78s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que adote as medidas necessárias à melhoria da qualidade das informações contábeis;', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:36,220 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-18 15:26:37,389 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:37,389 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:37,390 INFO sqlalchemy.engine.Engine [cached since 15.95s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que adote providências para estruturar o sistema de tributação do município, para atendimento ao disposto no artigo 11 da Lei de Responsabilidade Fiscal;', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:37,392 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-18 15:26:38,507 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:38,507 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:38,508 INFO sqlalchemy.engine.Engine [cached since 17.07s ago] {'IdProcesso': 384234, 'IdComposicaoPauta': 123061, 'IdVotoPauta': 44963, 'DescricaoRecomendacao': 'Que institua medidas para coibir a assunção indiscriminada de obrigações não suportadas pela disponibilidade financeira do exercício.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GETÚLIO LUCIANO RIBEIRO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE VÁRZEA', 'IdOrgaoResponsavel': 497, 'Cancelado': None}
# 2025-11-18 15:26:38,510 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 10 de 57
# 2025-11-18 15:26:39,721 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:39,722 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:39,722 INFO sqlalchemy.engine.Engine [cached since 18.28s ago] {'IdProcesso': 384697, 'IdComposicaoPauta': 123362, 'IdVotoPauta': 45697, 'DescricaoRecomendacao': 'Recomendar ao Chefe do Poder Executivo de Luís Gomes/RN a adoção de medidas para melhorar a qualidade e a tempestividade das informações contábeis enviadas a esta Corte.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'FRANCISCO TADEU NUNES', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE LUIS GOMES', 'IdOrgaoResponsavel': 404, 'Cancelado': None}
# 2025-11-18 15:26:39,726 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 11 de 57
# 2025-11-18 15:26:40,908 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:40,909 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:40,909 INFO sqlalchemy.engine.Engine [cached since 19.47s ago] {'IdProcesso': 544509, 'IdComposicaoPauta': 123239, 'IdVotoPauta': 45926, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao gestor responsável pelo NATALPREV, para que adote as providências necessárias para elaborar a Certidão de Tempo de Contribuição da parte interessada', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'MARIA DAS NEVES PEREIRA DOS SANTOS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DOS SERVIDORES DO MUNICÍPIO DE NATAL', 'IdOrgaoResponsavel': 642, 'Cancelado': None}
# 2025-11-18 15:26:40,916 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 12 de 57
# 2025-11-18 15:26:42,117 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:42,118 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:42,118 INFO sqlalchemy.engine.Engine [cached since 20.68s ago] {'IdProcesso': 544509, 'IdComposicaoPauta': 123239, 'IdVotoPauta': 45926, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao gestor responsável pelo NATALPREV, para que adote as providências necessárias para elaborar a Certidão de Tempo de Contribuição da parte interessada', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'MARIA DAS NEVES PEREIRA DOS SANTOS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DOS SERVIDORES DO MUNICÍPIO DE NATAL', 'IdOrgaoResponsavel': 642, 'Cancelado': None}
# 2025-11-18 15:26:42,122 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 13 de 57
# 2025-11-18 15:26:43,313 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:43,314 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:43,315 INFO sqlalchemy.engine.Engine [cached since 21.88s ago] {'IdProcesso': 544509, 'IdComposicaoPauta': 123239, 'IdVotoPauta': 45926, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao gestor responsável pelo NATALPREV, para que adote as providências necessárias para elaborar a Certidão de Tempo de Contribuição da parte interessada', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'MARIA DAS NEVES PEREIRA DOS SANTOS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA SOCIAL DOS SERVIDORES DO MUNICÍPIO DE NATAL', 'IdOrgaoResponsavel': 642, 'Cancelado': None}
# 2025-11-18 15:26:43,316 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 14 de 57
# 2025-11-18 15:26:44,485 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:44,486 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:44,486 INFO sqlalchemy.engine.Engine [cached since 23.05s ago] {'IdProcesso': 384361, 'IdComposicaoPauta': 123285, 'IdVotoPauta': 45931, 'DescricaoRecomendacao': 'recomendar ao atual Chefe do Poder Executivo de São Vicente que adote medidas necessárias à melhoria da qualidade e da confiabilidade das informações contábeis', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'JOSIFRAN LINS DE MEDEIROS', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SÃO VICENTE', 'IdOrgaoResponsavel': 484, 'Cancelado': None}
# 2025-11-18 15:26:44,490 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 15 de 57
# 2025-11-18 15:26:45,905 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:45,906 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:45,906 INFO sqlalchemy.engine.Engine [cached since 24.47s ago] {'IdProcesso': 558019, 'IdComposicaoPauta': 123380, 'IdVotoPauta': 45942, 'DescricaoRecomendacao': 'recomendação ao representante legal do Consórcio Intermunicipal Multifinalitário da Associação dos Municípios do Litoral Agreste Potiguar do Rio Gran ... (121 characters truncated) ... ra e orçamentária similares àquele apurado durante o exercício de 2016, nos termos do dever de informação disciplinado na Resolução nº 011/2016 – TC.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Raniere Cesar Amâncio da Silva', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'CONSÓRCIO INTERMUNICIPAL MULTIFINALITARIO POTIGUAR', 'IdOrgaoResponsavel': 1294, 'Cancelado': None}
# 2025-11-18 15:26:45,910 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 16 de 57
# 2025-11-18 15:26:47,278 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:47,279 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:47,279 INFO sqlalchemy.engine.Engine [cached since 25.84s ago] {'IdProcesso': 558019, 'IdComposicaoPauta': 123380, 'IdVotoPauta': 45942, 'DescricaoRecomendacao': 'recomendação ao representante legal do Consórcio Intermunicipal Multifinalitário da Associação dos Municípios do Litoral Agreste Potiguar do Rio Gran ... (121 characters truncated) ... ra e orçamentária similares àquele apurado durante o exercício de 2016, nos termos do dever de informação disciplinado na Resolução nº 011/2016 – TC.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Raniere Cesar Amâncio da Silva', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'CONSÓRCIO INTERMUNICIPAL MULTIFINALITARIO POTIGUAR', 'IdOrgaoResponsavel': 1294, 'Cancelado': None}
# 2025-11-18 15:26:47,281 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 17 de 57
# 2025-11-18 15:26:48,481 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:48,482 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:48,482 INFO sqlalchemy.engine.Engine [cached since 27.04s ago] {'IdProcesso': 292782, 'IdComposicaoPauta': 123189, 'IdVotoPauta': 45935, 'DescricaoRecomendacao': 'expedição de recomendações ao governo do estado e à atual gestão da EMGERN, conforme o item III do parecer do Parquet, tudo com o escopo de aprimoramento dos controles aziendais.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'NELSON TAVARES FILHO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'EMPRESA GESTORA DE ATIVOS DO RN', 'IdOrgaoResponsavel': 842, 'Cancelado': None}
# 2025-11-18 15:26:48,565 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 18 de 57
# 2025-11-18 15:26:50,629 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:50,629 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:50,630 INFO sqlalchemy.engine.Engine [cached since 29.19s ago] {'IdProcesso': 292782, 'IdComposicaoPauta': 123189, 'IdVotoPauta': 45935, 'DescricaoRecomendacao': 'expedição de recomendações ao governo do estado e à atual gestão da EMGERN, conforme o item III do parecer do Parquet, tudo com o escopo de aprimoramento dos controles aziendais.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'NELSON TAVARES FILHO, Edward Smith de Araujo, YLMARA GOMES RODRIGUES RAMPINELLI', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'EMPRESA GESTORA DE ATIVOS DO RN', 'IdOrgaoResponsavel': 842, 'Cancelado': None}
# 2025-11-18 15:26:50,702 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 19 de 57
# 2025-11-18 15:26:52,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:52,176 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:52,176 INFO sqlalchemy.engine.Engine [cached since 30.74s ago] {'IdProcesso': 292782, 'IdComposicaoPauta': 123189, 'IdVotoPauta': 45935, 'DescricaoRecomendacao': 'expedição de recomendações ao governo do estado e à atual gestão da EMGERN, conforme o item III do parecer do Parquet, tudo com o escopo de aprimoramento dos controles aziendais.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'NELSON TAVARES FILHO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'EMPRESA GESTORA DE ATIVOS DO RN', 'IdOrgaoResponsavel': 842, 'Cancelado': None}
# 2025-11-18 15:26:52,207 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 20 de 57
# 2025-11-18 15:26:53,586 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:53,587 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:53,588 INFO sqlalchemy.engine.Engine [cached since 32.15s ago] {'IdProcesso': 292782, 'IdComposicaoPauta': 123189, 'IdVotoPauta': 45935, 'DescricaoRecomendacao': 'expedição de recomendações ao governo do estado e à atual gestão da EMGERN, conforme o item III do parecer do Parquet, tudo com o escopo de aprimoramento dos controles aziendais.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'NELSON TAVARES FILHO', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'EMPRESA GESTORA DE ATIVOS DO RN', 'IdOrgaoResponsavel': 842, 'Cancelado': None}
# 2025-11-18 15:26:53,593 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 21 de 57
# 2025-11-18 15:26:55,413 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:55,414 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:55,415 INFO sqlalchemy.engine.Engine [cached since 33.98s ago] {'IdProcesso': 541456, 'IdComposicaoPauta': 123240, 'IdVotoPauta': 45929, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao gestor responsável pelo IPERN, para que adote as providências necessárias para: • elaborar novo ato aposentador retirando a menção ao ... (124 characters truncated) ... laborar nova apostila de cálculos e implantação dos proventos, excluindo a percepção da Vantagem Pessoal da Lei nº 6.192/1991 pela parte interessada.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'MARIA GORETTI BARROSO COSTA XAVIER DA SILVA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'INSTITUTO DE PREVIDÊNCIA DOS SERVIDORES DO RN', 'IdOrgaoResponsavel': 308, 'Cancelado': None}
# 2025-11-18 15:26:55,426 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 22 de 57
# 2025-11-18 15:26:56,992 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:56,993 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:56,994 INFO sqlalchemy.engine.Engine [cached since 35.56s ago] {'IdProcesso': 526728, 'IdComposicaoPauta': 123600, 'IdVotoPauta': 46242, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Chefe do Poder Executivo Municipal', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TIBAU DO SUL', 'IdOrgaoResponsavel': 494, 'Cancelado': None}
# 2025-11-18 15:26:57,023 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 23 de 57
# 2025-11-18 15:26:58,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:26:58,469 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:26:58,470 INFO sqlalchemy.engine.Engine [cached since 37.03s ago] {'IdProcesso': 526728, 'IdComposicaoPauta': 123600, 'IdVotoPauta': 46242, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Valdenicio Jose da costa', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TIBAU DO SUL', 'IdOrgaoResponsavel': 494, 'Cancelado': None}
# 2025-11-18 15:26:58,537 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 24 de 57
# 2025-11-18 15:27:00,164 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:00,165 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:00,165 INFO sqlalchemy.engine.Engine [cached since 38.73s ago] {'IdProcesso': 354212, 'IdComposicaoPauta': 123253, 'IdVotoPauta': 45985, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GUTEMBERG PEREIRA DA ROCHA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SAO TOME', 'IdOrgaoResponsavel': 483, 'Cancelado': None}
# 2025-11-18 15:27:00,236 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 25 de 57
# 2025-11-18 15:27:01,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:01,681 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:01,682 INFO sqlalchemy.engine.Engine [cached since 40.24s ago] {'IdProcesso': 354212, 'IdComposicaoPauta': 123253, 'IdVotoPauta': 45985, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Gutemberg Pereira da Rocha', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Prefeitura Municipal de São Tomé', 'IdOrgaoResponsavel': 483, 'Cancelado': None}
# 2025-11-18 15:27:01,795 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 26 de 57
# 2025-11-18 15:27:03,530 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:03,531 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:03,532 INFO sqlalchemy.engine.Engine [cached since 42.09s ago] {'IdProcesso': 378015, 'IdComposicaoPauta': 123288, 'IdVotoPauta': 45981, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao Governo do Estado do RN, por meio de notificação a ser enviada à Exma. Sra. Governadora do Estado, para que seja suspensa a concessão de horas suplementares de todas as Secretarias Estaduais, acaso ainda existentes, em estrito cumprimento ao art. 22, parágrafo único, da LRF.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Exma. Sra. Governadora do Estado', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Governo do Estado do RN', 'IdOrgaoResponsavel': 532, 'Cancelado': None}
# 2025-11-18 15:27:03,582 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 27 de 57
# 2025-11-18 15:27:05,078 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:05,079 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:05,079 INFO sqlalchemy.engine.Engine [cached since 43.64s ago] {'IdProcesso': 378015, 'IdComposicaoPauta': 123288, 'IdVotoPauta': 45981, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao Governo do Estado do RN, por meio de notificação a ser enviada à Exma. Sra. Governadora do Estado, para que seja suspensa a concessão de horas suplementares de todas as Secretarias Estaduais, acaso ainda existentes, em estrito cumprimento ao art. 22, parágrafo único, da LRF.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Exma. Sra. Governadora do Estado', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Governo do Estado do RN', 'IdOrgaoResponsavel': 532, 'Cancelado': None}
# 2025-11-18 15:27:05,107 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 28 de 57
# 2025-11-18 15:27:06,502 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:06,503 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:06,504 INFO sqlalchemy.engine.Engine [cached since 45.07s ago] {'IdProcesso': 378015, 'IdComposicaoPauta': 123288, 'IdVotoPauta': 45981, 'DescricaoRecomendacao': 'RECOMENDAÇÃO ao Governo do Estado do RN, por meio de notificação a ser enviada à Exma. Sra. Governadora do Estado, para que seja suspensa a concessão de horas suplementares de todas as Secretarias Estaduais, acaso ainda existentes, em estrito cumprimento ao art. 22, parágrafo único, da LRF.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': None, 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Governo do Estado do RN', 'IdOrgaoResponsavel': 532, 'Cancelado': None}
# 2025-11-18 15:27:06,528 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 29 de 57
# 2025-11-18 15:27:08,325 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
# 2025-11-18 15:27:35,205 INFO sqlalchemy.engine.Engine [cached since 73.77s ago] {'IdProcesso': 414123, 'IdComposicaoPauta': 123484, 'IdVotoPauta': 46172, 'DescricaoRecomendacao': 'recomendar ao atual e aos seguintes Chefes do Executivo do município de Jaçanã para que adotem medidas aptas ao melhoramento da transparência e da efetividade na prestação de contas do Município, e qualidade e confiabilidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Esdras Fernades Farias', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Prefeitura Municipal de Jaçanã', 'IdOrgaoResponsavel': 390, 'Cancelado': None}
# 2025-11-18 15:27:35,299 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 46 de 57
# 2025-11-18 15:27:36,671 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:36,672 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:36,673 INFO sqlalchemy.engine.Engine [cached since 75.24s ago] {'IdProcesso': 526586, 'IdComposicaoPauta': 123453, 'IdVotoPauta': 46137, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'ADRIANO GOMES DE OLIVEIRA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SANTANA DO SERIDO', 'IdOrgaoResponsavel': 482, 'Cancelado': None}
# 2025-11-18 15:27:36,692 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 47 de 57
# 2025-11-18 15:27:38,130 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:38,131 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:38,131 INFO sqlalchemy.engine.Engine [cached since 76.69s ago] {'IdProcesso': 526586, 'IdComposicaoPauta': 123453, 'IdVotoPauta': 46137, 'DescricaoRecomendacao': 'Expedir recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Adriano Gomes de Oliveira', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Prefeitura Municipal de Santana do Seridó', 'IdOrgaoResponsavel': 482, 'Cancelado': None}
# 2025-11-18 15:27:38,176 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 48 de 57
# 2025-11-18 15:27:39,764 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:39,764 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:39,765 INFO sqlalchemy.engine.Engine [cached since 78.33s ago] {'IdProcesso': 414135, 'IdComposicaoPauta': 123482, 'IdVotoPauta': 46171, 'DescricaoRecomendacao': 'RECOMENDAR ao Chefe do Poder Executivo para que adote das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'GENILSON MEDEIROS MAIA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE SÃO FERNANDO', 'IdOrgaoResponsavel': 462, 'Cancelado': None}
# 2025-11-18 15:27:39,793 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 49 de 57
# 2025-11-18 15:27:41,230 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:41,231 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:41,231 INFO sqlalchemy.engine.Engine [cached since 79.79s ago] {'IdProcesso': 384437, 'IdComposicaoPauta': 123525, 'IdVotoPauta': 46176, 'DescricaoRecomendacao': 'Recomendar ao Chefe do Poder Executivo do Município de Pedra Grande/RN que adote as medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Marcos Luiz Pereira', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE PEDRA GRANDE', 'IdOrgaoResponsavel': 439, 'Cancelado': None}
# 2025-11-18 15:27:41,292 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 50 de 57
# 2025-11-18 15:27:42,835 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:42,835 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:42,836 INFO sqlalchemy.engine.Engine [cached since 81.4s ago] {'IdProcesso': 384437, 'IdComposicaoPauta': 123525, 'IdVotoPauta': 46176, 'DescricaoRecomendacao': 'Recomendar ao Chefe do Poder Executivo do Município de Pedra Grande/RN que adote as medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'MARCOS LUIZ PEREIRA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE PEDRA GRANDE', 'IdOrgaoResponsavel': 439, 'Cancelado': None}
# 2025-11-18 15:27:42,903 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 51 de 57
# 2025-11-18 15:27:44,215 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:44,215 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:44,216 INFO sqlalchemy.engine.Engine [cached since 82.78s ago] {'IdProcesso': 384437, 'IdComposicaoPauta': 123525, 'IdVotoPauta': 46176, 'DescricaoRecomendacao': 'Recomendar ao Chefe do Poder Executivo do Município de Pedra Grande/RN que adote as medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Marcos Luiz Pereira', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'Prefeitura Municipal de Pedra Grande', 'IdOrgaoResponsavel': 439, 'Cancelado': None}
# 2025-11-18 15:27:44,249 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 52 de 57
# 2025-11-18 15:27:45,760 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:45,761 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:45,761 INFO sqlalchemy.engine.Engine [cached since 84.32s ago] {'IdProcesso': 526728, 'IdComposicaoPauta': 123600, 'IdVotoPauta': 46242, 'DescricaoRecomendacao': 'recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Valdenicio Jose da costa', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TIBAU DO SUL', 'IdOrgaoResponsavel': 494, 'Cancelado': None}
# 2025-11-18 15:27:45,857 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 53 de 57
# 2025-11-18 15:27:47,364 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:47,365 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:47,366 INFO sqlalchemy.engine.Engine [cached since 85.93s ago] {'IdProcesso': 526728, 'IdComposicaoPauta': 123600, 'IdVotoPauta': 46242, 'DescricaoRecomendacao': 'recomendação ao Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Valdenicio Jose da costa', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TIBAU DO SUL', 'IdOrgaoResponsavel': 494, 'Cancelado': None}
# 2025-11-18 15:27:47,452 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 54 de 57
# 2025-11-18 15:27:48,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:48,952 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:48,953 INFO sqlalchemy.engine.Engine [cached since 87.52s ago] {'IdProcesso': 414251, 'IdComposicaoPauta': 123665, 'IdVotoPauta': 46293, 'DescricaoRecomendacao': 'Expedir recomendação ao atual Chefe do Poder Executivo Municipal para adoção das medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': None, 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE CAMPO REDONDO', 'IdOrgaoResponsavel': 367, 'Cancelado': None}
# 2025-11-18 15:27:49,031 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 55 de 57
# 2025-11-18 15:27:50,532 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:50,533 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:50,533 INFO sqlalchemy.engine.Engine [cached since 89.1s ago] {'IdProcesso': 354477, 'IdComposicaoPauta': 123689, 'IdVotoPauta': 46297, 'DescricaoRecomendacao': 'Recomendar ao Chefe do Poder Executivo do Município de Taipu/RN que adote as medidas necessárias à melhoria da qualidade das informações contábeis.', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'Ariosvaldo Bandeira Junior', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE TAIPU', 'IdOrgaoResponsavel': 485, 'Cancelado': None}
# 2025-11-18 15:27:50,544 INFO sqlalchemy.engine.Engine COMMIT
# Processando instância 56 de 57
# 2025-11-18 15:27:52,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-18 15:27:52,292 INFO sqlalchemy.engine.Engine INSERT INTO [Recomendacao] ([IdProcesso], [IdComposicaoPauta], [IdVotoPauta], [DescricaoRecomendacao], [PrazoCumprimentoRecomendacao], [DataCumprimentoRecomendacao], [NomeResponsavel], [IdPessoaResponsavel], [OrgaoResponsavel], [IdOrgaoResponsavel], [Cancelado]) OUTPUT inserted.[IdRecomendacao] VALUES (%(IdProcesso)s, %(IdComposicaoPauta)s, %(IdVotoPauta)s, %(DescricaoRecomendacao)s, %(PrazoCumprimentoRecomendacao)s, %(DataCumprimentoRecomendacao)s, %(NomeResponsavel)s, %(IdPessoaResponsavel)s, %(OrgaoResponsavel)s, %(IdOrgaoResponsavel)s, %(Cancelado)s)
# 2025-11-18 15:27:52,293 INFO sqlalchemy.engine.Engine [cached since 90.86s ago] {'IdProcesso': 606355, 'IdComposicaoPauta': 123675, 'IdVotoPauta': 46311, 'DescricaoRecomendacao': 'RECOMENDAÇÃO a(o) Chefe do Poder Executivo para que adote medidas necessárias à melhoria da qualidade das informações contábeis', 'PrazoCumprimentoRecomendacao': None, 'DataCumprimentoRecomendacao': None, 'NomeResponsavel': 'ROSSANE MARQUES LIMA PATRIOTA', 'IdPessoaResponsavel': None, 'OrgaoResponsavel': 'PREFEITURA MUNICIPAL DE IELMO MARINHO', 'IdOrgaoResponsavel': 385, 'Cancelado': None}
# 2025-11-18 15:27:52,325 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# # From File

# %%
all_decisions = pd.read_csv("dataset/all_decisions.csv")
all_decisions['year'] = pd.to_datetime(all_decisions['datasessao']).dt.year
all_decisions_2023 = all_decisions[all_decisions['year'] >= 2023]

# %%
len(all_decisions_2023), len(all_decisions)

# %%
resultados = []
errors = []
for index, row in all_decisions_2023.iterrows():
    if index % 10 == 0 and index > 0:
        print(f"Processando instância {index} de {len(all_decisions_2023)}")
        all_decisions_2023.to_csv("dataset/all_decisions_2023_ner.csv", index=True)

    try:
        prompt_with_few_shot = generate_few_shot_ner_prompts(row['texto_acordao'])
        
        result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
        all_decisions_2023.at[index, 'ner_decisao'] = result
        resultados.append(result)
    except Exception as e:
        errors.append({
            'index': index,
            'error': str(e),
            'row': row.to_dict()
        })

# %%
for e in errors:
    prompt_with_few_shot = generate_few_shot_ner_prompts(e['row']['texto_acordao'])
    result = extractor_gpt4turbo.invoke(prompt_with_few_shot)
    all_decisions_2023.at[e['index'], 'ner_decisao'] = result
    resultados.append(result)

# %%
all_decisions_2023.to_pickle("dataset/all_decisions_2023_ner.pkl")

# %% [markdown]
# # Creating Obrigacao database in local sqlite

# %%
Base = declarative_base()
engine = create_engine(
    f"mssql+pymssql://{os.getenv("SQL_SERVER_USER")}:{os.getenv("SQL_SERVER_PASS")}@{os.getenv("SQL_SERVER_HOST")}/{os.getenv("SQL_SERVER_DB")}",
    echo=True
)
#engine = create_engine("sqlite:///dataset/sqlite/obrigacoes.db", echo=True)
SessionLocal = sessionmaker(bind=engine)

# %%
class ObrigacaoORM(Base):
    __tablename__ = "Obrigacao"

    IdObrigacao = Column(Integer, primary_key=True, index=True)
    IdProcesso = Column(Integer, nullable=False)
    IdComposicaoPauta = Column(Integer, nullable=False)
    IdVotoPauta = Column(Integer, nullable=False)
    DescricaoObrigacao = Column(Text, nullable=False)
    DeFazer = Column(Boolean, default=True)
    Prazo = Column(String, nullable=True)
    DataCumprimento = Column(Date, nullable=True)
    OrgaoResponsavel = Column(String, nullable=True)
    IdOrgaoResponsavel = Column(Integer, nullable=True)
    TemMultaCominatoria = Column(Boolean, default=False)
    NomeResponsavelMultaCominatoria = Column(String, nullable=True)
    DocumentoResponsavelMultaCominatoria = Column(String, nullable=True)
    IdPessoaMultaCominatoria = Column(Integer, nullable=True)
    ValorMultaCominatoria = Column(Float, nullable=True)
    PeriodoMultaCominatoria = Column(String, nullable=True)
    EMultaCominatoriaSolidaria = Column(Boolean, default=False)
    SolidariosMultaCominatoria = Column(JSON, nullable=True)

# %%
class RecomendacaoORM(Base):
    __tablename__ = "Recomendacao"

    IdRecomendacao = Column(Integer, primary_key=True, index=True)
    IdProcesso = Column(Integer, nullable=False)
    IdComposicaoPauta = Column(Integer, nullable=False)
    IdVotoPauta = Column(Integer, nullable=False)
    DescricaoRecomendacao = Column(Text, nullable=True)
    PrazoCumprimentoRecomendacao = Column(String, nullable=True)
    DataCumprimentoRecomendacao = Column(Date, nullable=True)
    NomeResponsavel = Column(String, nullable=True)
    IdPessoaResponsavel = Column(Integer, nullable=True)
    OrgaoResponsavel = Column(String, nullable=True)
    IdOrgaoResponsavel = Column(Integer, nullable=True)

    def __repr__(self):
        return f"<Recomendacao(IdRecomendacao={self.IdRecomendacao}, descricao_recomendacao='{self.descricao_recomendacao[:30]}...')>"

# %%
#Base.metadata.drop_all(bind=engine)
Base.metadata.create_all(bind=engine)
# Out:
# 2025-07-27 16:37:03,274 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-27 16:37:03,274 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(%(table_type_1)s AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(%(table_type_2)s AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(%(table_name_1)s AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(%(table_schema_1)s AS NVARCHAR(max))
# 2025-07-27 16:37:03,275 INFO sqlalchemy.engine.Engine [cached since 10.51s ago] {'table_type_1': 'BASE TABLE', 'table_type_2': 'VIEW', 'table_name_1': 'Obrigacao', 'table_schema_1': 'dbo'}
# 2025-07-27 16:37:03,313 INFO sqlalchemy.engine.Engine
# CREATE TABLE [Obrigacao] (
# 	[IdObrigacao] INTEGER NOT NULL IDENTITY,
# 	[IdProcesso] INTEGER NOT NULL,
# 	[IdComposicaoPauta] INTEGER NOT NULL,
# 	[IdVotoPauta] INTEGER NOT NULL,
# 	[DescricaoObrigacao] VARCHAR(max) NOT NULL,
# 	[DeFazer] BIT NULL,
# 	[Prazo] VARCHAR(max) NULL,
# 	[DataCumprimento] DATE NULL,
# 	[OrgaoResponsavel] VARCHAR(max) NULL,
# 	[IdOrgaoResponsavel] INTEGER NULL,
# 	[TemMultaCominatoria] BIT NULL,
# 	[NomeResponsavelMultaCominatoria] VARCHAR(max) NULL,
# 	[DocumentoResponsavelMultaCominatoria] VARCHAR(max) NULL,
# 	[IdPessoaMultaCominatoria] INTEGER NULL,
# 	[ValorMultaCominatoria] FLOAT NULL,
# 	[PeriodoMultaCominatoria] VARCHAR(max) NULL,
# 	[EMultaCominatoriaSolidaria] BIT NULL,
# 	[SolidariosMultaCominatoria] NVARCHAR(max) NULL,
# 	PRIMARY KEY ([IdObrigacao])
# )
#
#
# 2025-07-27 16:37:03,313 INFO sqlalchemy.engine.Engine [no key 0.00038s] {}
# 2025-07-27 16:37:03,390 INFO sqlalchemy.engine.Engine CREATE INDEX [ix_Obrigacao_IdObrigacao] ON [Obrigacao] ([IdObrigacao])
# 2025-07-27 16:37:03,391 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2025-07-27 16:37:03,430 INFO sqlalchemy.engine.Engine COMMIT
